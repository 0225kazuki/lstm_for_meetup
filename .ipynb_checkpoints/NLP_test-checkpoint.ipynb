# %% [markdown]
# # NLP test

# %%
import sqlite3
import matplotlib.pyplot as plt
import pickle
import sklearn
import numpy as np
import pandas as pd
import collections
import sqlite3
import re
% matplotlib inline

# %%
# obj 生成
conn = sqlite3.connect('reviews.sqlite3')
cur = conn.cursor()

cur.execute("select content from spams")
obj = cur.fetchall()

conn.commit()
conn.close()

# %%
# 形態素解析Mecab + neologd版
import MeCab

mecab = MeCab.Tagger ('-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd')

# art="080-3322-9382に電話かけてください"
res = []
for art in obj:
    art = art[0]
    mecab.parse("")
    res.append((len(mecab.parse(art).split())-1)/2)

# %%
plt.figure()
plt.bar(np.arange(len(res)),res)
plt.ylim(0,200)
plt.show()

# %%
print(np.mean(np.array(res)),np.std(np.array(res)),np.min(np.array(res)),np.max(np.array(res)))
# Out:
# 31.1362605747 38.4226533099 0.0 1410.0

# %%
whitelist = "\n「」。、あいうえおかきくけこさしすせそたちつてとなにぬねのはひふへほまみむめもやゐゆゑよらりるれろわをんがぎぐげござじずぜぞだぢづでどばびぶべぼぱぴぷぺぽぁぃぅぇぉゃゅょっゎ"
whitelist = set(whitelist)

# %%
'''
形態素解析Mecab + neologd版
all_dataはsentenceごとのひらがな分かち書き
whitelistの単語のみ許容
sentece末尾に終端文字を入れる
'''

import MeCab
import jaconv

mecab = MeCab.Tagger ('-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd')   #for mac
# mecab = MeCab.Tagger ('-d /usr/lib/mecab/dic/mecab-ipadic-neologd') # for ubuntu

sentence_num = 10000

all_data = []
for art in obj[:sentence_num]:
    art = art[0]
    
    mecab.parse("")    
    node = mecab.parseToNode(art)
    
    tmp_data = []
    while node:
        #単語を取得
        word = node.surface
        #品詞を取得
        pos = node.feature.split(",")

        # 記号とwhitelist以外の単語を弾く
        if pos[0] != '記号':
            word = jaconv.kata2hira(pos[-2])
            if (set(word) - whitelist) == set():
                tmp_data.append(jaconv.kata2hira(pos[-2]))
            
        #次の単語に進める
        node = node.next
        
    # 終端文字挿入
    tmp_data.append("E")
    
    all_data.append(tmp_data)

# %%
all_data
# Out:
# [['とうとう',
#   'みんしん',
#   'は',
#   'たてまえ',
#   'さえ',
#   'も',
#   'ほうかい',
#   'し',
#   'た',
#   'の',
#   'か',
#   'じぶん',
#   'の',
#   'かんがえ',
#   'に',
#   'じしん',
#   'が',
#   'もて',
#   'ない',
#   'とう',
#   'に',
#   'めいしょう',
#   'かえろ',
#   'よ',
#   'E'],
#  ['じえいたい', 'ぐんたい', 'みとめ', 'て', 'よい', 'はやく', 'みとめよ', 'う', 'E'],
#  ['がいじん',
#   'なんて',
#   'もの',
#   'が',
#   'そんざい',
#   'する',
#   'みん',
#   'しんとう',
#   'が',
#   'あんぜんほしょう',
#   'かたっ',
#   'て',
#   'はずかしく',
#   'ない',
#   'の',
#   'か',
#   'よ',
#   'E'],
#  ['まだ', 'みたい', 'な', 'こと', 'いっ', 'て', 'て', 'びっくり', 'だ', 'わ', 'E'],
#  ['おんけんほしゅ',
#   'わろた',
#   'おまえ',
#   'ら',
#   'みんきょう',
#   'がったい',
#   'の',
#   'きょくさせいとう',
#   'だろ',
#   'う',
#   'が',
#   'みんきょう',
#   'がったい',
#   'で',
#   'とくあ',
#   'だ',
#   'E'],
#  ['いま',
#   'まで',
#   'みんしんとう',
#   'が',
#   'どういう',
#   'かぜ',
#   'に',
#   'しゅちょう',
#   'し',
#   'て',
#   'こっかい',
#   'を',
#   'くうてん',
#   'さ',
#   'せ',
#   'て',
#   'き',
#   'た',
#   'か',
#   'わすれ',
#   'た',
#   'の',
#   'ぶれ',
#   'てる',
#   'どころ',
#   'の',
#   'はなし',
#   'じゃ',
#   'ない',
#   'ばっち',
#   'を',
#   'つけ',
#   'たい',
#   'だけ',
#   'の',
#   'ぎいん',
#   'なんか',
#   'いら',
#   'ねぇ',
#   'E'],
#  ['いま',
#   'の',
#   'しじしゃ',
#   'が',
#   'そんな',
#   'こと',
#   'のぞん',
#   'で',
#   'ん',
#   'の',
#   'あたらしい',
#   'しじしゃ',
#   'が',
#   'その',
#   'ほうほう',
#   'で',
#   'え',
#   'られる',
#   'と',
#   'おもっ',
#   'て',
#   'ん',
#   'の',
#   'E'],
#  ['だっ',
#   'たら',
#   'まず',
#   'みんしんとう',
#   'から',
#   'ありたよしふ',
#   'を',
#   'はたき',
#   'ださ',
#   'ない',
#   'と',
#   'E'],
#  ['とうない', 'まとめ', 'て', 'から', 'に', 'し', 'て', 'くん', 'ない', 'か', 'な', 'E'],
#  ['さいしょ', 'から', 'です', 'やん', 'あさひ', 'は', 'なに', 'を', 'ゆう', 'て', 'ん', 'の', 'E'],
#  ['なにをいまさら', 'くん', 'ら', 'の', 'しゃぜ', 'です', 'やん', 'E'],
#  ['もはや', 'へんこう', 'を', 'かくし', 'も', 'し', 'なく', 'なっ', 'た', 'か', 'E'],
#  ['いや',
#   'さいしょ',
#   'から',
#   'てっとうてつび',
#   'あべせいけん',
#   'ふしじ',
#   'を',
#   'どうどう',
#   'と',
#   'かかげ',
#   'て',
#   'ただ',
#   'ろ',
#   'E'],
#  ['ふしじ', 'は', 'いい', 'が', 'だれ', 'を', 'しじ', 'する', 'ん', 'だ', 'E'],
#  ['じぶん', 'ら', 'の', 'おもい', 'どうり', 'が', 'せいぎ', 'ふるく', 'て', 'ふるく', 'て', 'E'],
#  ['はあ', 'なにいってんだこいつ', 'まえ', 'から', 'ふしじ', 'ひょうめい', 'なんて', 'できる', 'だろ', 'E'],
#  ['いま',
#   'まで',
#   'ず',
#   'うう',
#   'う',
#   'うう',
#   'っと',
#   'いい',
#   'たい',
#   'ほうだい',
#   'し',
#   'てる',
#   'だろ',
#   'E'],
#  ['けんりょく', 'の', 'しぶつか', 'それ', 'は', 'あん', 'たら', 'ます', 'ごみ', 'じゃ', 'ね', 'E'],
#  ['あさひ',
#   'は',
#   'しゅうしいっかん',
#   'あべ',
#   'ふ',
#   'しじ',
#   'だっ',
#   'た',
#   'だろ',
#   'なん',
#   'たっ',
#   'て',
#   'それ',
#   'が',
#   'しゃぜ',
#   'な',
#   'ん',
#   'だ',
#   'から',
#   'E'],
#  ['に', 'の', 'と', 'おなじ', 'こと', 'いっ', 'てる', 'E'],
#  ['ようやく',
#   'じゃ',
#   'ない',
#   'だろ',
#   'あさひしんぶん',
#   'が',
#   'そんざい',
#   'する',
#   'こと',
#   'が',
#   'ふけんぜん',
#   'で',
#   'は',
#   'E'],
#  ['あさひしんぶん',
#   'ふしじ',
#   'を',
#   'どうどう',
#   'と',
#   'ひょうめい',
#   'できる',
#   'けんぜん',
#   'な',
#   'にほんしゃかい',
#   'です',
#   'が',
#   'なに',
#   'か',
#   'E'],
#  ['まいにち', 'いっ', 'て', 'ます', 'やん', 'のうない', 'とうそう', 'せってい', 'きも', 'すぎ', 'E'],
#  ['ちょんもめん', 'と', 'しこう', 'ろじっく', 'が', 'まったく', 'おなじ', 'な', 'ん', 'だ', 'な', 'E'],
#  ['いや',
#   'ちゅうりつ',
#   'を',
#   'よそおわ',
#   'ず',
#   'かくさ',
#   'ず',
#   'に',
#   'どうどう',
#   'と',
#   'ひょうめい',
#   'し',
#   'て',
#   'から',
#   'やれ',
#   'や',
#   'E'],
#  ['あかひしんぶん', 'なんか', 'もともと', 'しじ', 'すら', 'さ', 'れ', 'て', 'ない', 'もん', 'な', 'E'],
#  ['ばか', 'だ', 'な', 'こんな', 'こと', 'かか', 'なきゃ', 'いい', 'のに', 'E'],
#  ['あさひ',
#   'の',
#   'きしゃ',
#   'の',
#   'この',
#   'ようち',
#   'さ',
#   'そりゃ',
#   'とうだいせい',
#   'が',
#   'くん',
#   'わけ',
#   'だ',
#   'わ',
#   'E'],
#  ['あさひ', 'の', 'きしゃ', 'って', 'こんな', 'の', 'しか', 'い', 'ない', 'の', 'か', 'E'],
#  ['また', 'やん', 'の', 'か', 'よ', 'E'],
#  ['および', 'で', 'ない', 'ひと', 'が', 'で', 'て', 'き', 'ちゃっ', 'た', 'よ', 'E'],
#  ['こいつ', 'は', 'せいきょく', 'しか', 'かんがえ', 'て', 'な', 'E'],
#  ['おまえ',
#   'それ',
#   'まえ',
#   'に',
#   'も',
#   'やっ',
#   'たろ',
#   'やっ',
#   'て',
#   'いま',
#   'どう',
#   'なっ',
#   'てる',
#   'の',
#   'E'],
#  ['ま', 'た', 'おなじ', 'こと', 'いっ', 'てる', 'E'],
#  ['おまえ', 'じゃ', 'むり', 'だ', 'E'],
#  ['なんかい', 'め', 'だ', 'E'],
#  ['ほら',
#   'また',
#   'かつ',
#   'こと',
#   'が',
#   'じこ',
#   'もくてき',
#   'か',
#   'し',
#   'てる',
#   'うそっぱち',
#   'で',
#   'も',
#   'まにふぇすと',
#   'だして',
#   'た',
#   'みんしゅ',
#   'じだい',
#   'より',
#   'も',
#   'たいか',
#   'し',
#   'てん',
#   'な',
#   'E'],
#  ['やとう', 'が', 'いっぽん', 'か', 'する', 'わけ', 'だろ', 'ばか', 'じゃ', 'の', 'E'],
#  ['これだけ',
#   'にっぽん',
#   'が',
#   'すいたい',
#   'し',
#   'た',
#   'のに',
#   'まだ',
#   'あほ',
#   'みたい',
#   'な',
#   'こと',
#   'やり',
#   'たい',
#   'の',
#   'か',
#   'E'],
#  ['きたな',
#   'さわ',
#   'は',
#   'せいきょく',
#   'が',
#   'だいいち',
#   'な',
#   'だけ',
#   'だ',
#   'から',
#   'ほんき',
#   'で',
#   'そう',
#   'おもっ',
#   'て',
#   'いる',
#   'ん',
#   'だろ',
#   'う',
#   'な',
#   'だれ',
#   'だ',
#   'よ',
#   'いまだに',
#   'こんな',
#   'に',
#   'とうひょう',
#   'し',
#   'てん',
#   'の',
#   'は',
#   'E'],
#  ['もくてき',
#   'の',
#   'ため',
#   'に',
#   'は',
#   'しゅだん',
#   'を',
#   'えらば',
#   'ず',
#   'そして',
#   'もくてき',
#   'を',
#   'わすれる',
#   'E'],
#  ['なんか',
#   'はっそう',
#   'が',
#   'ふるい',
#   'と',
#   'いう',
#   'か',
#   'まとはずれ',
#   'と',
#   'いう',
#   'か',
#   'せそう',
#   'が',
#   'よめ',
#   'なく',
#   'なっ',
#   'たら',
#   'せいじか',
#   'は',
#   'おわり',
#   'だ',
#   'な',
#   'E'],
#  ['みんしんとう',
#   'と',
#   'きょうさんとう',
#   'の',
#   'きょうとう',
#   'で',
#   'せいこう',
#   'まちがい',
#   'なし',
#   'しっぱい',
#   'でし',
#   'た',
#   'E'],
#  ['もう',
#   'それ',
#   'くりかえし',
#   'た',
#   'けっか',
#   'きそん',
#   'の',
#   'やとう',
#   'に',
#   'だれ',
#   'も',
#   'きたい',
#   'し',
#   'なく',
#   'なっ',
#   'た',
#   'の',
#   'が',
#   'げんじょう',
#   'だろ',
#   'う',
#   'に',
#   'E'],
#  ['じみん',
#   'に',
#   'ふまん',
#   'が',
#   'ある',
#   'から',
#   'って',
#   'じゃあ',
#   'みんしん',
#   'や',
#   'きょうさんとう',
#   'に',
#   'いれる',
#   'か',
#   'おまえ',
#   'ん',
#   'と',
#   'この',
#   'じゆうとう',
#   'とか',
#   'もってのほか',
#   'だろ',
#   'ばいこくど',
#   'が',
#   'E'],
#  ['さん', 'とか', 'しい', 'さん', 'と', 'れんほう', 'さん', 'とか', 'いる', 'かぎり', 'そりゃ', 'E'],
#  ['どう', 'かんがえ', 'て', 'も', 'ともだおれ', 'いがい', 'の', 'けつまつ', 'ない', 'だろ', 'E'],
#  ['おざわ', 'ぬき', 'で', 'ね', 'E'],
#  ['せいさく', 'が', 'はんじみん', 'E'],
#  ['それでも', 'まとま', 'れ', 'ない', 'やとう', 'E'],
#  ['せいさく', 'で', 'かたら', 'なきゃ', 'いみ', 'が', 'ない', 'って', 'いう', 'E'],
#  ['せいこうたいけん', 'が', 'わすれ', 'られ', 'ない', 'ひと', 'が', 'ここ', 'に', 'も', 'E'],
#  ['やとう', 'ぜんぶ', 'あわせ', 'た', 'しじりつ', 'って', 'いくつ', 'でし', 'た', 'っけ', 'E'],
#  ['やとう',
#   'を',
#   'ひとつ',
#   'に',
#   'って',
#   'きょうさんとう',
#   'に',
#   'いっぽん',
#   'か',
#   'する',
#   'しか',
#   'ない',
#   'だろ',
#   'きょうさんとう',
#   'が',
#   'とうめい',
#   'かえる',
#   'わけ',
#   'ない',
#   'から',
#   'E'],
#  ['がくしゅう', 'のうりょく', 'ない', 'の', 'か', 'この', 'ばか', 'は', 'E'],
#  ['いま', 'の', 'やとう', 'に', 'うけざら', 'に', 'なる', 'とこ', 'が', 'ある', 'か', 'よ', 'E'],
#  ['しぶとい', 'はんにち', 'すぱい', 'だ', 'な', 'E'],
#  ['せいじ', 'を', 'しろ', 'せいじ', 'を', 'うけざら', 'とか', 'じゃなくて', 'さ', 'E'],
#  ['おざわ',
#   'と',
#   'きょうさん',
#   'が',
#   'くん',
#   'で',
#   'だとう',
#   'じみん',
#   'とか',
#   'わらいばなし',
#   'に',
#   'も',
#   'なら',
#   'ん',
#   'わ',
#   'E'],
#  ['たし', 'て', 'も', 'に', 'なら', 'ない', 'よ', 'ね', 'E'],
#  ['ばかさよ', 'はっきょう', 'みんす', 'かいめつ', 'E'],
#  ['これ', 'で', 'さよく', 'は', 'せんきょせん', 'たたかう', 'つもり', 'な', 'ん', 'だ', 'E'],
#  ['こんな', 'もん', 'さ', 'ばかさよ', 'とう', 'なんて', 'えらぶ', 'わけ', 'ない', 'わ', 'E'],
#  ['どれ',
#   'だけ',
#   'せいけん',
#   'こうげき',
#   'し',
#   'て',
#   'も',
#   'じぶんたち',
#   'の',
#   'しじりつ',
#   'が',
#   'つながら',
#   'ない',
#   'やとう',
#   'はずかしい',
#   'と',
#   'おもわ',
#   'ない',
#   'の',
#   'か',
#   'ね',
#   'E'],
#  ['この',
#   'き',
#   'に',
#   'およん',
#   'で',
#   'も',
#   'とにかく',
#   'みんしん',
#   'だけ',
#   'は',
#   'もる',
#   'ん',
#   'だ',
#   'ね',
#   'E'],
#  ['みんしん',
#   'たかい',
#   'な',
#   'これ',
#   'じゃ',
#   'せんきょ',
#   'で',
#   'いい',
#   'しょうぶ',
#   'する',
#   'ん',
#   'じゃ',
#   'ない',
#   'の',
#   'E'],
#  ['うけざら', 'が', 'ない', 'みんしんとう', 'きょうさんとう', 'しん', 'で', 'も', 'E'],
#  ['みんしんとう', 'E'],
#  ['まだ', 'みんす', 'を', 'しじ', 'し', 'てる', 'やつ', 'って', 'E'],
#  ['ひとをのろわばあなふたつ', 'E'],
#  ['ばいこく',
#   'じみん',
#   'げらく',
#   'の',
#   'けいこう',
#   'は',
#   'いい',
#   'ん',
#   'だ',
#   'けど',
#   'いや',
#   'ほんと',
#   'とって',
#   'かわれる',
#   'まとも',
#   'な',
#   'やとう',
#   'が',
#   'ない',
#   'E'],
#  ['そもそも', 'うけざら', 'ない', 'やん', 'E'],
#  ['ないかくしじりつ',
#   'が',
#   'すこし',
#   'あがっ',
#   'て',
#   'き',
#   'た',
#   'じゃん',
#   'さげ',
#   'すぎ',
#   'た',
#   'から',
#   'りばうんど',
#   'とおか',
#   'まえ',
#   'の',
#   'じじつうしん',
#   'ふつか',
#   'まえ',
#   'の',
#   'きょうどうつうしん',
#   'E'],
#  ['これだけ',
#   'がんばっ',
#   'て',
#   'ついきゅう',
#   'し',
#   'て',
#   'も',
#   'さがる',
#   'みんしんとう',
#   'は',
#   'おもしろい',
#   'な',
#   'どんだけ',
#   'きらわ',
#   'れ',
#   'てる',
#   'ん',
#   'だ',
#   'よ',
#   'E'],
#  ['この',
#   'すれ',
#   'さよく',
#   'に',
#   'ふつごう',
#   'だ',
#   'から',
#   'のび',
#   'ない',
#   'な',
#   'さよく',
#   'どう',
#   'やっ',
#   'て',
#   'せんきょせん',
#   'たたかう',
#   'つもり',
#   'よ',
#   'E'],
#  ['こん',
#   'かいさん',
#   'そう',
#   'せんきょ',
#   'し',
#   'たら',
#   'じみんとう',
#   'あっしょう',
#   'って',
#   'こと',
#   'だけ',
#   'は',
#   'わかっ',
#   'た',
#   'わ',
#   'E'],
#  ['かん', 'せい', 'だんごう', 'による', 'けっか', 'E'],
#  ['これ', 'どう', 'すん', 'の', 'E'],
#  ['たいへん', 'だ', 'E'],
#  ['これ',
#   'こそ',
#   'まさに',
#   'お',
#   'ともだち',
#   'ゆうぐう',
#   'な',
#   'ん',
#   'だ',
#   'けど',
#   'ますこみ',
#   'は',
#   'だんまり',
#   'です',
#   'か',
#   'E'],
#  ['えこ', 'えこ', 'さぎ', 'が', 'ばれ', 'まし', 'た', 'ね', 'E'],
#  ['やっぱり', 'げんぱつ', 'かどう', 'さ', 'せ', 'ない', 'と', 'むり', 'か', 'E'],
#  ['これ',
#   'は',
#   'みんす',
#   'の',
#   'せきにん',
#   'だろ',
#   'かいとりかかく',
#   'を',
#   'たかく',
#   'せってい',
#   'し',
#   'すぎ',
#   'だ',
#   'わ',
#   'E'],
#  ['これ', 'こそ', 'はしご', 'はずし', 'だ', 'わ', 'E'],
#  ['みんしゅとう',
#   'が',
#   'もじどおり',
#   'お',
#   'ともだち',
#   'の',
#   'ため',
#   'に',
#   'おしすすめ',
#   'た',
#   'せいさく',
#   'だ',
#   'もん',
#   'なぁ',
#   'E'],
#  ['そもそも',
#   'さいしょ',
#   'に',
#   'せってい',
#   'し',
#   'た',
#   'かいとりかかく',
#   'が',
#   'こう',
#   'すぎ',
#   'な',
#   'ん',
#   'だ',
#   'よ',
#   'E'],
#  ['ほじょきん',
#   'だけ',
#   'で',
#   'は',
#   'きょうそう',
#   'が',
#   'おこら',
#   'ず',
#   'ぎょうかい',
#   'が',
#   'くさっ',
#   'て',
#   'いく',
#   'いい',
#   'みほん',
#   'だ',
#   'な',
#   'E'],
#  ['きんじょ',
#   'の',
#   'はたけ',
#   'が',
#   'いちめん',
#   'たいようこうぱねる',
#   'に',
#   'かわっ',
#   'た',
#   'ものの',
#   'ひかり',
#   'の',
#   'はんしゃ',
#   'とか',
#   'で',
#   'きんじょ',
#   'の',
#   'かべ',
#   'が',
#   'こげる',
#   'とか',
#   'しつない',
#   'に',
#   'まぶしい',
#   'ひかり',
#   'が',
#   'はいっ',
#   'て',
#   'くる',
#   'と',
#   'くじょう',
#   'が',
#   'さっとう',
#   'し',
#   'て',
#   'よくしゅう',
#   'に',
#   'てっきょ',
#   'さ',
#   'れ',
#   'て',
#   'て',
#   'わろた',
#   'E'],
#  ['ぎょうせい', 'が', 'むせきにん', 'すぎる', 'E'],
#  ['とりあえず', 'いつも', 'の', 'E'],
#  ['やっぱり', 'げんぱつ', 'や', 'な', 'E'],
#  ['ぱねる', 'ある', 'いえ', 'は', 'かも', 'か', 'さぎし', 'さっとう', 'E'],
#  ['かんなおと',
#   'の',
#   'おき',
#   'みやげ',
#   'が',
#   'なん',
#   'じゅう',
#   'ねん',
#   'も',
#   'もつ',
#   'わけ',
#   'ない',
#   'だろ',
#   'さいしょ',
#   'の',
#   'すうねん',
#   'で',
#   'うり',
#   'にげ',
#   'し',
#   'なかっ',
#   'た',
#   'きぎょう',
#   'は',
#   'ばか',
#   'E'],
#  ['ありがとうみんしゅとう', 'E'],
#  ['とうしょ', 'から', 'わかっ', 'て', 'た', 'だろ', 'こう', 'なる', 'の', 'E'],
#  ['ほじょきん', 'びじねす', 'E'],
#  ['みんしゅとう', 'が', 'お', 'ともだち', 'に', 'そんたく', 'し', 'た', 'けっか', 'でしょ', 'う', 'E'],
#  ['そらそうよ', 'E'],
#  ['てれび', 'を', 'みる', 'と', 'ばかに', 'なる', 'から', 'E'],
#  ['そのうち', 'てれび', 'って', 'せだい', 'ばかり', 'に', 'なる', 'な', 'E'],
#  ['みんぽう', 'の', 'ちじょうは', 'は', 'まず', 'み', 'ない', 'な', 'E'],
#  ['てれび',
#   'み',
#   'てる',
#   'と',
#   'うそ',
#   'ばっか',
#   'で',
#   'ほんとうに',
#   'なかみ',
#   'すっからかん',
#   'の',
#   'ばか',
#   'に',
#   'なる',
#   'E'],
#  ['へんこうほうどう',
#   'ばっか',
#   'だ',
#   'し',
#   'くだらない',
#   'おわらい',
#   'とか',
#   'みる',
#   'かち',
#   'ない',
#   'わ',
#   'E'],
#  ['いみ',
#   'の',
#   'ない',
#   'ところ',
#   'で',
#   'ちょうせんじん',
#   'を',
#   'もちあげる',
#   'とか',
#   'てれびきょく',
#   'に',
#   'ちょうせんじん',
#   'が',
#   'いる',
#   'の',
#   'が',
#   'ばればれ',
#   'E'],
#  ['きまっ',
#   'た',
#   'じかん',
#   'に',
#   'しか',
#   'みれ',
#   'ない',
#   'てれび',
#   'すき',
#   'な',
#   'とき',
#   'に',
#   'みれる',
#   'ねっと',
#   'E'],
#  ['そりゃそうだ',
#   'ろ',
#   'てれび',
#   'は',
#   'うそ',
#   'や',
#   'すてま',
#   'ばんぐみ',
#   'だらけ',
#   'だ',
#   'から',
#   'な',
#   'E'],
#  ['いや',
#   'どう',
#   'かんがえ',
#   'て',
#   'も',
#   'てれび',
#   'の',
#   'ほう',
#   'が',
#   'わかい',
#   'やつら',
#   'から',
#   'はなれ',
#   'て',
#   'おこなっ',
#   'てる',
#   'だろ',
#   'E'],
#  ['しゃいんしょくどう', 'で', 'めし', 'くっ', 'てる', 'とき', 'しか', 'み', 'ない', 'わ', 'E'],
#  ['もはや', 'いえ', 'に', 'てれび', 'ない', 'し', 'E'],
#  ['いやならみるな', 'を', 'じっこう', 'し', 'てる', 'まで', 'E'],
#  ['この',
#   'ちょうし',
#   'で',
#   'ますごみ',
#   'ども',
#   'の',
#   'ちから',
#   'が',
#   'おちる',
#   'ほう',
#   'が',
#   'しゃかい',
#   'の',
#   'ため',
#   'に',
#   'なる',
#   'な',
#   'E'],
#  ['しんじつ', 'は', 'ねっと', 'に', 'ある', 'から', 'な', 'E'],
#  ['むかし',
#   'って',
#   'てれび',
#   'み',
#   'た',
#   'さ',
#   'に',
#   'いえ',
#   'に',
#   'かえっ',
#   'て',
#   'たり',
#   'し',
#   'た',
#   'よ',
#   'な',
#   'いま',
#   'じゃ',
#   'E'],
#  ['てれび',
#   'みる',
#   'に',
#   'せよ',
#   'りあるたいむ',
#   'で',
#   'みる',
#   'こと',
#   'は',
#   'おおはば',
#   'に',
#   'へっ',
#   'た',
#   'な',
#   'ほとんど',
#   'ろくが',
#   'し',
#   'た',
#   'の',
#   'み',
#   'てる',
#   'わ',
#   'E'],
#  ['ひまつぶし',
#   'に',
#   'も',
#   'なら',
#   'ず',
#   'がいあく',
#   'で',
#   'しか',
#   'ない',
#   'と',
#   'みな',
#   'きづい',
#   'て',
#   'しまっ',
#   'た',
#   'E'],
#  ['さん', 'じゅうだい', 'も', 'おとこ', 'は', 'ねっと', 'ゆうせい', 'だろ', 'E'],
#  ['でも', 'ねっと', 'の', 'の', 'ほとんど', 'は', 'しんぶん', 'な', 'ん', 'だ', 'よ', 'ね', 'E'],
#  ['に', 'なっ', 'てる', 'から', 'な', 'てれび', 'は', 'E'],
#  ['ねっとじょう',
#   'で',
#   'とっく',
#   'に',
#   'みやぶら',
#   'れ',
#   'てる',
#   'うそ',
#   'を',
#   'えんえんと',
#   'たれ',
#   'ながす',
#   'てれび',
#   'E'],
#  ['てれび', 'って', 'しょっぴんぐ', 'ばかり', 'E'],
#  ['こないだ',
#   'ひさしぶり',
#   'に',
#   'てれび',
#   'み',
#   'たら',
#   'あいて',
#   'の',
#   'ほけん',
#   'や',
#   'けんこうしょくひん',
#   'の',
#   'ばっか',
#   'し',
#   'て',
#   'て',
#   'わろた',
#   'E'],
#  ['せんのう',
#   'じだい',
#   'も',
#   'やっと',
#   'おわり',
#   'か',
#   'やきゅう',
#   'や',
#   'おわらい',
#   'あたり',
#   'の',
#   'ふしぜん',
#   'な',
#   'もちあげ',
#   'が',
#   'なくなる',
#   'な',
#   'E'],
#  ['ねっと',
#   'より',
#   'てれび',
#   'の',
#   'が',
#   'おもしろけれ',
#   'ば',
#   'もどる',
#   'でしょ',
#   'いう',
#   'ほど',
#   'てれび',
#   'じたい',
#   'から',
#   'はなれ',
#   'てる',
#   'わけ',
#   'じゃ',
#   'ない',
#   'E'],
#  ['さいきん',
#   'じゃ',
#   'てれび',
#   'より',
#   'どうが',
#   'み',
#   'てる',
#   'ほう',
#   'が',
#   'おもしろい',
#   'もん',
#   'な',
#   'じっさい',
#   'E'],
#  ['どこ', 'の', 'くに', 'の', 'てれびきょく', 'か', 'わから', 'ない', 'E'],
#  ['ますごみ', 'なんか', 'み', 'ねえ', 'よ', 'E'],
#  ['てれび', 'おい', 'て', 'ない', 'わ', 'E'],
#  ['うっ',
#   'すい',
#   'ねた',
#   'で',
#   'しゃく',
#   'うめ',
#   'てる',
#   'の',
#   'が',
#   'みえ',
#   'みえ',
#   'な',
#   'の',
#   'が',
#   'ばれ',
#   'た',
#   'E'],
#  ['てれび', 'は', 'すきっぷ', 'でき', 'ない', 'から', 'たえ', 'れ', 'ない', 'E'],
#  ['れんほう', 'あうと', 'E'],
#  ['これ', 'が', 'せかい', 'の', 'じょうしき', 'だ', 'E'],
#  ['れんほう', 'そっと', 'じ', 'すれ', 'E'],
#  ['にじゅうこくせき', 'すぱい', 'が', 'せかい', 'の', 'じょうしき', 'だっ', 'た', 'か', 'E'],
#  ['わがくに', 'は', 'どう', 'する', 'の', 'か', 'な', 'E'],
#  ['じょうしき', 'で', 'かんがえ', 'たら', 'こう', 'だ', 'よ', 'な', 'E'],
#  ['ひがいしゃ',
#   'めんし',
#   'て',
#   'さべつ',
#   'とか',
#   'わらえる',
#   'よ',
#   'れんほう',
#   'にっぽん',
#   'なめ',
#   'られ',
#   'すぎ',
#   'E'],
#  ['うむ', 'よい', 'こと', 'だ', 'E'],
#  ['ほうりつ',
#   'まもっ',
#   'て',
#   'ない',
#   'やつ',
#   'が',
#   'さべつ',
#   'とか',
#   'に',
#   'すりかえ',
#   'て',
#   'いばっ',
#   'てる',
#   'の',
#   'が',
#   'すごい',
#   'よ',
#   'な',
#   'E'],
#  ['じっさい',
#   'すぱい',
#   'だ',
#   'し',
#   'がいかん',
#   'だ',
#   'ぞ',
#   'にっぽん',
#   'の',
#   'どこ',
#   'に',
#   'でも',
#   'はいりこん',
#   'でる',
#   'だろ',
#   'にっぽんじん',
#   'の',
#   'ふり',
#   'し',
#   'て',
#   'な',
#   'E'],
#  ['にっぽんこくみん',
#   'を',
#   'あざむい',
#   'た',
#   'つみ',
#   'は',
#   'ちょうえき',
#   'いち',
#   'ぜろ',
#   'ねん',
#   'が',
#   'だとう',
#   'E'],
#  ['れんほう', 'すぱい', 'きんこ', 'じゅうねん', 'E'],
#  ['だって', 'さ', 'れんほう', 'さん', 'どう', 'おもう', 'E'],
#  ['せかい', 'で', 'は', 'うんぬん', 'E'],
#  ['これ', 'が', 'あたりまえ', 'な', 'ん', 'だ', 'よ', 'E'],
#  ['がいかん', 'あつかい', 'に', 'なっ', 'て', 'しかるべき', 'だ', 'よ', 'な', 'E'],
#  ['こっかいぎいん', 'なんて', 'もってのほか', 'だ', 'な', 'E'],
#  ['せいじか', 'こうむいん', 'くらい', 'は', 'にじゅうこくせき', 'きんし', 'に', 'し', 'ない', 'と', 'E'],
#  ['にっぽん', 'も', 'みならう', 'べき', 'だ', 'な', 'E'],
#  ['ふつうのくに', 'なら', 'そう', 'なる', 'わな', 'わっと', 'E'],
#  ['これ', 'が', 'ふつう', 'ほんと', 'に', 'にっぽん', 'は', 'すぱい', 'てんごく', 'だ', 'わ', 'E'],
#  ['じじつ', 'じゃ', 'ねえ', 'か', 'E'],
#  ['E'],
#  ['じじつ',
#   'を',
#   'いわ',
#   'れ',
#   'て',
#   'なぜ',
#   'おこる',
#   'なに',
#   'が',
#   'へんけん',
#   'な',
#   'の',
#   'だ',
#   'せいけいたいこく',
#   'って',
#   'ほるほる',
#   'し',
#   'て',
#   'た',
#   'だろ',
#   'う',
#   'E'],
#  ['だいがく',
#   'ごうかく',
#   'いわい',
#   'が',
#   'せいけい',
#   'な',
#   'ん',
#   'でしょ',
#   'なに',
#   'を',
#   'はじる',
#   'こと',
#   'ある',
#   'E'],
#  ['で', 'せいかい', 'は', 'なに', 'な', 'の', 'です', 'E'],
#  ['E'],
#  ['こんな',
#   'の',
#   'が',
#   'ぶつぎ',
#   'を',
#   'かもす',
#   'って',
#   'こと',
#   'は',
#   'かんこくじん',
#   'も',
#   'せいけい',
#   'にたいして',
#   'うしろめたい',
#   'きもち',
#   'を',
#   'もっ',
#   'てる',
#   'って',
#   'こと',
#   'だ',
#   'よ',
#   'な',
#   'E'],
#  ['ばいしゅん', 'と', 'こたえ', 'なかっ', 'た', 'だけ', 'まし', 'じゃ', 'ない', 'か', 'E'],
#  ['しばきたい', 'しゅつどう', 'や', 'な', 'E'],
#  ['いや',
#   'がる',
#   'こども',
#   'に',
#   'むり',
#   'に',
#   'せいけい',
#   'さ',
#   'せ',
#   'たり',
#   'たんじょうび',
#   'の',
#   'ぷれぜんと',
#   'に',
#   'おや',
#   'が',
#   'しゅじゅつ',
#   'だい',
#   'を',
#   'だす',
#   'くに',
#   'が',
#   'なに',
#   'を',
#   'いっ',
#   'てる',
#   'ん',
#   'だ',
#   'せいかい',
#   'だろ',
#   'E'],
#  ['なんで', 'きれる', 'ん', 'だ', 'よ', 'E'],
#  ['かいぞうにんげん', 'E'],
#  ['かんこく',
#   'の',
#   'びじん',
#   'こんてすと',
#   'の',
#   'しゃしん',
#   'を',
#   'み',
#   'たら',
#   'だれ',
#   'でも',
#   'おどろく',
#   'ぞ',
#   'E'],
#  ['せいけい', 'し', 'て', 'も', 'うまれ', 'て', 'くる', 'こども', 'は', 'ちょん', 'がお', 'E'],
#  ['はは',
#   'むすめ',
#   'で',
#   'せいけい',
#   'する',
#   'って',
#   'きい',
#   'てる',
#   'よ',
#   'に',
#   'て',
#   'なきゃ',
#   'まずい',
#   'と',
#   'する',
#   'しんけい',
#   'も',
#   'もっ',
#   'てる',
#   'らしい',
#   'E'],
#  ['じしんまんまん',
#   'に',
#   'こたえ',
#   'てる',
#   'たいがい',
#   'の',
#   'ひと',
#   'は',
#   'そう',
#   'こたえる',
#   'だろ',
#   'E'],
#  ['よく', 'わかっ', 'てん', 'じゃん', 'E'],
#  ['なんで', 'ちょうせんじん', 'って', 'ほんとう', 'の', 'こと', 'いう', 'と', 'おこる', 'の', 'E'],
#  ['これ',
#   'は',
#   'かなりや',
#   'べ',
#   'な',
#   'えみ',
#   'ついに',
#   'おおの',
#   'くん',
#   'も',
#   'ねとうよ',
#   'の',
#   'なかまいり',
#   'か',
#   'E'],
#  ['せいけい', 'の', 'きげんはかんこく', 'E'],
#  ['かんこく', 'と', 'いえ', 'ば', 'せいけい', 'と', 'ばいしゅん', 'が', 'しゅようさんぎょう', 'だろ', 'E'],
#  ['むち', 'でも', 'へんけん', 'で', 'も', 'ない', 'だろ', 'う', 'E'],
#  ['こんな', 'ばらえてぃ', 'の', 'いち', 'すら', 'のぞきみ', 'する', 'きもち', 'わるい', 'ちょうせんじん', 'E'],
#  ['にっぽん',
#   'で',
#   'かんこく',
#   'の',
#   'いんしょう',
#   'が',
#   'よく',
#   'ない',
#   'の',
#   'は',
#   'かんこく',
#   'じしん',
#   'に',
#   'もんだい',
#   'が',
#   'ある',
#   'と',
#   'は',
#   'かんがえ',
#   'ない',
#   'の',
#   'E'],
#  ['わろた', 'おおのくん', 'よう', 'わかっ', 'て', 'ん', 'じゃ', 'ない', 'か', 'E'],
#  ['もうそう', 'です', 'E'],
#  ['ねん', 'ばっか', 'じゃ', 'の', 'E'],
#  ['また', 'もっ', 'た', 'の', 'か', 'E'],
#  ['そもそも',
#   'かんこく',
#   'に',
#   'は',
#   'ねん',
#   'まえ',
#   'の',
#   'れきし',
#   'を',
#   'しるし',
#   'た',
#   'きろく',
#   'が',
#   'ない',
#   'だろ',
#   'E'],
#  ['ろくじゅうねん',
#   'くらい',
#   'の',
#   'れきし',
#   'の',
#   'くに',
#   'が',
#   'そこ',
#   'に',
#   'むかし',
#   'すん',
#   'で',
#   'た',
#   'の',
#   'は',
#   'べつ',
#   'の',
#   'みんぞく',
#   'だ',
#   'ぞ',
#   'で',
#   'ない',
#   'と',
#   'おまえら',
#   'の',
#   'れきし',
#   'が',
#   'E'],
#  ['ほう',
#   'それ',
#   'は',
#   'ほこらしい',
#   'な',
#   'ほこらしい',
#   'そこく',
#   'に',
#   'すぐ',
#   'に',
#   'えいじゅう',
#   'きこく',
#   'し',
#   'なさい',
#   'E'],
#  ['じしょう', 'に', 'し', 'て', 'も', 'もり', 'すぎ', 'で', 'は', 'なかろ', 'う', 'か', 'E'],
#  ['ぞっこく', 'の', 'れきし', 'しか', 'ねえ', 'じゃん', 'E'],
#  ['まけ', 'て', 'まけ', 'て', 'まけ', 'つづけ', 'た', 'れきし', 'な', 'E'],
#  ['ごせんねんのれきし',
#   'が',
#   'ある',
#   'くせ',
#   'に',
#   'あの',
#   'ていど',
#   'の',
#   'ぶんめい',
#   'しか',
#   'そだた',
#   'なかっ',
#   'た',
#   'って',
#   'ぎゃく',
#   'に',
#   'はず',
#   'べき',
#   'こと',
#   'だろ',
#   'ちゃんと',
#   'かんがえ',
#   'て',
#   'から',
#   'うそ',
#   'つけ',
#   'よ',
#   'E'],
#  ['はんとう',
#   'の',
#   'れきし',
#   'じっせいき',
#   'ちょうはくざん',
#   'が',
#   'かこ',
#   'にせんねん',
#   'かん',
#   'で',
#   'せかいさいだい',
#   'きゅう',
#   'と',
#   'も',
#   'いわ',
#   'れる',
#   'きょだい',
#   'ふんか',
#   'を',
#   'おこす',
#   'りせっと',
#   'せんじゅうねん',
#   'きったん',
#   'に',
#   'しんりゃく',
#   'さ',
#   'れる',
#   'しゅと',
#   'かいじょう',
#   'が',
#   'かんらく',
#   'じん',
#   'か',
#   'せんじゅうさんねん',
#   'から',
#   'せんじゅうきゅうねん',
#   'まで',
#   'けいぞく',
#   'し',
#   'て',
#   'しんりゃく',
#   'さ',
#   'れる',
#   'じん',
#   'か',
#   'じゅうにせいき',
#   'じょしん',
#   'の',
#   'しんにゅう',
#   'しんりゃく',
#   'きん',
#   'に',
#   'ちょうこう',
#   'まんしゅう',
#   'じん',
#   'か',
#   'せんにひゃくさんじゅういちねん',
#   'もうこ',
#   'に',
#   'しんりゃく',
#   'さ',
#   'れる',
#   'しゅと',
#   'かいじょう',
#   'が',
#   'かんらく',
#   'こくおう',
#   'こうかとう',
#   'に',
#   'とうぼう',
#   'ながいあいだ',
#   'むていこう',
#   'の',
#   'はんとう',
#   'は',
#   'もんごるぐん',
#   'に',
#   'じゅうりん',
#   'さ',
#   'れる',
#   'もんごるじん',
#   'か',
#   'せんにひゃくよんじゅうななねん',
#   'もうこ',
#   'に',
#   'さい',
#   'しんりゃく',
#   'さ',
#   'れる',
#   'しばらく',
#   'じゅうりん',
#   'が',
#   'つづく',
#   'もんごるじん',
#   'か',
#   'せんにひゃくごじゅうはちねん',
#   'そう',
#   'かん',
#   'ふ',
#   'を',
#   'おか',
#   'れる',
#   'よくねん',
#   'おうじ',
#   'を',
#   'ひとじち',
#   'に',
#   'こうふく',
#   'もんごるじん',
#   'か',
#   'こくない',
#   'に',
#   'は',
#   'おおく',
#   'の',
#   'もうこ',
#   'ぐんじん',
#   'が',
#   'ちゅうりゅう',
#   'もんごるじん',
#   'か',
#   'せんにひゃくななじゅうねん',
#   'とうねいふ',
#   'を',
#   'おか',
#   'れる',
#   'もんごるじん',
#   'か',
#   'はんたいは',
#   'が',
#   'さいしゅうとう',
#   'に',
#   'うつっ',
#   'て',
#   'てっていこうせん',
#   'せんにひゃくななじゅうさんねん',
#   'に',
#   'ちんあつ',
#   'もんごるじん',
#   'か',
#   'せんにひゃくななじゅうよんねん',
#   'と',
#   'せんにひゃくはちじゅういちねん',
#   'げんこう',
#   'はんとうじん',
#   'しゅりょく',
#   'で',
#   'にほんしんりゃく',
#   'が',
#   'ぜんめつ',
#   'もんごるじん',
#   'か',
#   'せんさんびゃくごじゅうろくねん',
#   'から',
#   'せんさんびゃくろくじゅうにねん',
#   'まで',
#   'の',
#   'べに',
#   'はば',
#   'ぞく',
#   'しんにゅう',
#   'により',
#   'しゅと',
#   'かいきょう',
#   'が',
#   'かんらく',
#   'しなじん',
#   'か',
#   'せんよんひゃくじゅうきゅうねん',
#   'おうえいのがいこう',
#   'いちまんななせんにん',
#   'で',
#   'つしま',
#   'を',
#   'しゅうげき',
#   'ふね',
#   'いえ',
#   'を',
#   'やき',
#   'じゅうみん',
#   'を',
#   'ぎゃくさつ',
#   'する',
#   'しかし',
#   'しょうすう',
#   'の',
#   'つしま',
#   'ぐん',
#   'に',
#   'げきたい',
#   'さ',
#   'れる',
#   'せんごひゃくきゅうじゅうにねん',
#   'と',
#   'せんごひゃくきゅうじゅうはちねん',
#   'ひでよし',
#   'の',
#   'からいり',
#   'しゅと',
#   'あやき',
#   'が',
#   'かんらく',
#   'たんき',
#   'で',
#   'やまと',
#   'か',
#   'は',
#   'むり',
#   'せんろっぴゃくにじゅうななねん',
#   'あときん',
#   'に',
#   'しんりゃく',
#   'さ',
#   'れる',
#   'ぴょんやん',
#   'を',
#   'こえ',
#   'しんりゃく',
#   'さ',
#   'れる',
#   'が',
#   'かんじょう',
#   'まで',
#   'は',
#   'こ',
#   'なかっ',
#   'た',
#   'しかし',
#   'こくおう',
#   'は',
#   'こうかとう',
#   'に',
#   'とうぼう',
#   'まんしゅう',
#   'じん',
#   'か',
#   'せんろっぴゃくさんじゅうろくねん',
#   'きよし',
#   'に',
#   'しんりゃく',
#   'さ',
#   'れる',
#   'しゅと',
#   'あやき',
#   'が',
#   'かんらく',
#   'しん',
#   'ぐん',
#   'が',
#   'す',
#   'はやく',
#   'こうかとう',
#   'へ',
#   'の',
#   'みち',
#   'を',
#   'しゃだん',
#   'でいねい',
#   'の',
#   'なか',
#   'ちょうせんおう',
#   'いんじょ',
#   'は',
#   'きよし',
#   'の',
#   'たいそう',
#   'に',
#   'こうふく',
#   'たいしんこくぞく',
#   'こく',
#   'と',
#   'なる',
#   'まんしゅう',
#   'じん',
#   'か',
#   'E'],
#  ['うりなら',
#   'の',
#   'れきし',
#   'は',
#   'はんまんねん',
#   'しょうこ',
#   'は',
#   'ない',
#   'けど',
#   'きゅう',
#   'せん',
#   'ねん',
#   'E'],
#  ['ねん', 'も', 'なに', 'やっ', 'て', 'た', 'ん', 'だ', 'よ', 'まなべ', 'よ', 'E'],
#  ['ばか', 'すぎ', 'E'],
#  ['ちょうせん',
#   'ご',
#   'ぜろ',
#   'ぜろ',
#   'ぜろ',
#   'ねん',
#   'って',
#   'いっ',
#   'て',
#   'も',
#   'なに',
#   'も',
#   'しょうこ',
#   'が',
#   'ない',
#   'E'],
#  ['うそ', 'の', 'れきし', 'を', 'しんじる', 'あほ', 'E'],
#  ['ねん',
#   'の',
#   'じかん',
#   'が',
#   'あっ',
#   'て',
#   'も',
#   'あれ',
#   'って',
#   'はずかしい',
#   'みんぞく',
#   'だ',
#   'な',
#   'E'],
#  ['ほんと', 'これ', 'ろんてん', 'ずらし', 'やめろ', 'よ', 'みんしん', 'は', 'E'],
#  ['せいろん',
#   'やん',
#   'と',
#   'いう',
#   'より',
#   'こくみん',
#   'が',
#   'ひっかかっ',
#   'てる',
#   'の',
#   'は',
#   'まさに',
#   'そこ',
#   'E'],
#  ['ほんとう', 'その', 'とおり', 'がんばれ', 'E'],
#  ['だせ', 'ない', 'の', 'は', 'それなり', 'の', 'りゆう', 'が', 'ある', 'E'],
#  ['ごちゃごちゃ',
#   'いわ',
#   'ず',
#   'に',
#   'こっかいぎいん',
#   'は',
#   'ぜんいん',
#   'こせきとうほん',
#   'を',
#   'だせ',
#   'それ',
#   'で',
#   'びょうどう',
#   'だ',
#   'E'],
#  ['こせきとうほん',
#   'かいじ',
#   'の',
#   'ひつようせい',
#   'こくせき',
#   'の',
#   'せんたく',
#   'ねんがっぴ',
#   'まさに',
#   'これ',
#   'こくせきせんたく',
#   'ねんがっぴ',
#   'が',
#   'じゅうよう',
#   'E'],
#  ['ほめ',
#   'られ',
#   'た',
#   'はなし',
#   'で',
#   'は',
#   'ない',
#   'が',
#   'けいけん',
#   'しゃ',
#   'だ',
#   'もん',
#   'なぁ',
#   'まあ',
#   'はつげん',
#   'に',
#   'いってい',
#   'の',
#   'おもみ',
#   'も',
#   'つわな',
#   'E'],
#  ['かんたん', 'に', 'ろんぱ', 'さ', 'れ', 'て', 'て', 'わろた', 'E'],
#  ['まさに', 'せいろん', 'E'],
#  ['ど',
#   'せいろん',
#   'で',
#   'わろた',
#   'ま',
#   'みんしん',
#   'は',
#   'このまま',
#   'ほうまつ',
#   'に',
#   'なれ',
#   'ば',
#   'いい',
#   'し',
#   'E'],
#  ['おっしゃる',
#   'とおり',
#   'です',
#   'な',
#   'ども',
#   'の',
#   'ぎゃくぎれ',
#   'は',
#   'みぐるしい',
#   'にも',
#   'ほど',
#   'が',
#   'ある',
#   'E'],
#  ['おのだ', 'が', 'いう', 'の', 'が', 'こうげきりょく', 'も', 'せっとくりょく', 'ある', 'E'],
#  ['はんざい',
#   'を',
#   'さべつ',
#   'とか',
#   'いいだし',
#   'て',
#   'ごまかす',
#   'せんごにほん',
#   'は',
#   'もう',
#   'おわり',
#   'で',
#   'E'],
#  ['まあ',
#   'なんで',
#   'この',
#   'ひと',
#   'と',
#   'おなじ',
#   'ていど',
#   'の',
#   'こうかい',
#   'が',
#   'でき',
#   'ない',
#   'の',
#   'か',
#   'と',
#   'は',
#   'おもう',
#   'わ',
#   'E'],
#  ['これ', 'にたいして', 'さべつしゅぎ', 'しゃ', 'と', 'は', 'いえないよ', 'さすが', 'に', 'E'],
#  ['いくにんも', 'の', 'はげ', 'を', 'だまし', 'た', 'E'],
#  ['かつお', 'の', 'しわざ', 'ね', 'E'],
#  ['わかめ', 'に', 'ささ', 'れる', 'こと', 'も', 'ない', 'だろ', 'E'],
#  ['なぜか', 'にっぽん', 'げんてい', 'E'],
#  ['にっぽん',
#   'はつ',
#   'の',
#   'めいわく',
#   'がいらいしゅ',
#   'として',
#   'は',
#   'くず',
#   'かずら',
#   'の',
#   'ほう',
#   'が',
#   'ゆうめい',
#   'E'],
#  ['わかめ', 'と', 'いっ', 'て', 'やれ', 'E'],
#  ['ひあり',
#   'による',
#   'こうげき',
#   'に',
#   'さらさ',
#   'れ',
#   'て',
#   'ます',
#   'かんちょう',
#   'このまま',
#   'で',
#   'は',
#   'わかめ',
#   'わかめ',
#   'だ',
#   'E'],
#  ['そんな', 'わかめ', 'E'],
#  ['これ', 'が', 'ふえる', 'わかめ', 'ちゃん', 'か', 'E'],
#  ['これ', 'は', 'さよく', 'はっきょう', 'し', 'ちゃう', 'E'],
#  ['ばくろ', 'E'],
#  ['そうそう', 'さすが', 'もとそうり', 'の', 'まご', 'E'],
#  ['じいちゃん',
#   'の',
#   'ふにんき',
#   'ぶり',
#   'も',
#   'そういう',
#   'ところ',
#   'は',
#   'あっ',
#   'た',
#   'よ',
#   'ね',
#   'E'],
#  ['せいろん', 'きた', 'ああああああああああ', 'E'],
#  ['さすが', 'に', 'かけ', 'に', 'は', 'こくみん', 'も', 'あきれ', 'てる', 'わ', 'E'],
#  ['と',
#   'てれび',
#   'に',
#   'で',
#   'てる',
#   'にんげん',
#   'が',
#   'いう',
#   'の',
#   'が',
#   'こっけい',
#   'で',
#   'わらえる',
#   'E'],
#  ['てれび', 'が', 'てれび', 'ひはん', 'する', 'なんて', 'は', 'かっきてき', 'だ', 'な', 'E'],
#  ['めでぃあ',
#   'も',
#   'そろそろ',
#   'なっ',
#   'て',
#   'き',
#   'た',
#   'なぁ',
#   'あべ',
#   'いじょう',
#   'に',
#   'あぐら',
#   'かい',
#   'て',
#   'き',
#   'た',
#   'れんちゅう',
#   'が',
#   'どう',
#   'なる',
#   'か',
#   'E'],
#  ['だって', 'どの', 'ばんぐみ', 'も', 'せいさくがいしゃ', 'が', 'いっしょ', 'だ', 'もん', 'E'],
#  ['おなじ',
#   'じかん',
#   'おなじ',
#   'たいみんぐ',
#   'おなじ',
#   'の',
#   'はつげん',
#   'せいさく',
#   'は',
#   'いずみほうそうせいさく',
#   'かいしゃ',
#   'E'],
#  ['えぼら', 'んんん', 'は', 'E'],
#  ['どや', 'がお', 'から', 'の', 'これ', 'は', 'はずかしい', 'E'],
#  ['こんな', 'ばか', 'の', 'きじ', 'を', 'きん', 'はらっ', 'て', 'よむ', 'やつ', 'E'],
#  ['すぺる', 'みす', 'より', 'えぼらしゅっけつねつ', 'と', 'の', 'こんどう', 'の', 'ほう', 'が', 'E'],
#  ['たにん',
#   'を',
#   'ばか',
#   'に',
#   'し',
#   'た',
#   'つもり',
#   'が',
#   'じぶん',
#   'の',
#   'ばか',
#   'を',
#   'さらし',
#   'た',
#   'だけ',
#   'という',
#   'いかにも',
#   'とうきょうしんぶん',
#   'の',
#   'きしゃ',
#   'らしく',
#   'ひんせい',
#   'げれつ',
#   'な',
#   'ほんしょう',
#   'が',
#   'だだもれ',
#   'だ',
#   'わ',
#   'E'],
#  ['とうきょうしんぶん',
#   'は',
#   'こいつ',
#   'だまら',
#   'せろ',
#   'よ',
#   'しゃ',
#   'の',
#   'あっか',
#   'する',
#   'だけ',
#   'だろ',
#   'E'],
#  ['こんな', 'あたま', 'でも', 'いれる', 'しんぶんしゃ', 'E'],
#  ['まるす', 'もちづき', 'E'],
#  ['すげ', 'かんこく', 'に', 'えぼら', 'はいっ', 'て', 'た', 'ん', 'だ', 'E'],
#  ['ばかはっけんき', 'の', 'めんぼくやくじょ', 'なり', 'E'],
#  ['この', 'きょうけん', 'いつ', 'まで', 'ほうち', 'すん', 'の', 'か', 'ね', 'E'],
#  ['これ',
#   'で',
#   'しんじつ',
#   'を',
#   'おいもとめる',
#   'の',
#   'かん',
#   'とか',
#   'ほんき',
#   'で',
#   'おもっ',
#   'て',
#   'そう',
#   'E'],
#  ['もちづき', 'は', 'そうとう', 'あたま', 'わるい', 'な', 'E'],
#  ['ばか', 'きしゃ', 'が', 'ぼけつ', 'ほっ', 'て', 'て', 'わろ', 'た', 'E'],
#  ['くっ',
#   'そ',
#   'どう',
#   'でも',
#   'いい',
#   'あげあしとり',
#   'を',
#   'し',
#   'た',
#   'あげく',
#   'それ',
#   'が',
#   'まちがっ',
#   'てる',
#   'とか',
#   'わらわせ',
#   'ん',
#   'な',
#   'E'],
#  ['ふるぼっこ', 'わろ', 'た', 'はんいるしんぶん', 'きらわ', 'れ', 'てる', 'なぁ', 'E'],
#  ['つり', 'せんげん', 'わっと', 'E'],
#  ['こいつ',
#   'が',
#   'ばか',
#   'じゃ',
#   'か',
#   'なんで',
#   'えぼらしゅっけつねつ',
#   'が',
#   'な',
#   'ん',
#   'だ',
#   'よ',
#   'わっと',
#   'E'],
#  ['えぼら', 'もちづき', 'わっと', 'E'],
#  ['かくにん', 'しろ', 'よ', 'ずぼら', 'E'],
#  ['えぼら', 'もちづき', 'の', 'たれ', 'E'],
#  ['きんねん', 'まれ', 'に', 'みる', 'すごうで', 'の', 'ぷろ', 'ぼけつ', 'ほりし', 'げん', 'る', 'E'],
#  ['こうどうりょく', 'の', 'ある', 'ばか', 'の', 'みほん', 'E'],
#  ['で', 'あせっ', 'て', 'ん', 'だ', 'な', 'E'],
#  ['さすが', 'はんにち', 'ますごみ', 'が', 'もちあげる', 'びんわん', 'きしゃ', 'だ', 'ね', 'E'],
#  ['これ', 'は', 'けっさく', 'だ', 'わ', 'E'],
#  ['えぼら', 'もちづき', 'E'],
#  ['あべ',
#   'にくし',
#   'で',
#   'ここ',
#   'まで',
#   'いく',
#   'と',
#   'かんぜん',
#   'に',
#   'きちがい',
#   'と',
#   'しか',
#   'E'],
#  ['この', 'おばさん', 'も', 'いちぶ', 'で', 'かりすま', 'に', 'なっ', 'てる', 'よ', 'E'],
#  ['つい', 'っ', 'た', 'が', 'のっとら', 'れ', 'た', 'ぼう', 'もうすぐ', 'くる', 'で', 'E'],
#  ['これ', 'は', 'ことし', 'いちばん', 'はずかしい', 'E'],
#  ['また', 'か', 'E'],
#  ['めちゃくちゃ', 'はずかしい', 'ねんちゃく', 'きしゃ', 'だ', 'な', 'E'],
#  ['また', 'ぱよく', 'が', 'でま', 'ばらまい', 'た', 'の', 'か', 'E'],
#  ['きゅう', 'の', 'ばか', 'だ', 'な', 'E'],
#  ['でも', 'やら', 'し', 'ちゃっ', 'た', 'じてん', 'で', 'ありた', 'の', 'まけ', 'だろ', 'E'],
#  ['じちたい',
#   'が',
#   'でも',
#   'の',
#   'きょか',
#   'だして',
#   'けいさつ',
#   'が',
#   'けいび',
#   'し',
#   'た',
#   'じてん',
#   'で',
#   'ざいにち',
#   'と',
#   'ありたよしふ',
#   'の',
#   'まけ',
#   'だろ',
#   'E'],
#  ['とどけで',
#   'し',
#   'た',
#   'でも',
#   'なら',
#   'けいさつ',
#   'は',
#   'ほご',
#   'する',
#   'ひつよう',
#   'が',
#   'ある',
#   'ん',
#   'だ',
#   'もん',
#   'わっと',
#   'こうぎ',
#   'し',
#   'たい',
#   'の',
#   'なら',
#   'とどけで',
#   'だして',
#   'やれ',
#   'ば',
#   'いいんじゃない',
#   'E'],
#  ['ちゅうりつ',
#   'の',
#   'たちば',
#   'から',
#   'みる',
#   'と',
#   'はんたいは',
#   'の',
#   'はんのう',
#   'を',
#   'みる',
#   'かぎり',
#   'でも',
#   'の',
#   'いみ',
#   'は',
#   'あっ',
#   'た',
#   'ん',
#   'じゃ',
#   'ない',
#   'です',
#   'か',
#   'ね',
#   'E'],
#  ['でも', 'を', 'やっ', 'た', 'きせい', 'じじつ', 'は', 'のこる', 'ねぇ', 'E'],
#  ['けいさつ', 'は', 'でも', 'の', 'みかた', 'は', 'てき', 'E'],
#  ['でもたい',
#   'ほご',
#   'の',
#   'ため',
#   'じゃなくて',
#   'ありた',
#   'たち',
#   'が',
#   'きょうぼうざい',
#   'で',
#   'たいほ',
#   'さ',
#   'れ',
#   'たら',
#   'こまる',
#   'と',
#   'おもっ',
#   'た',
#   'から',
#   'そうした',
#   'ん',
#   'じゃ',
#   'ね',
#   'ぜんれい',
#   'でき',
#   'たら',
#   'こまる',
#   'やつら',
#   'おおい',
#   'だろ',
#   'う',
#   'し',
#   'E'],
#  ['さいてい',
#   'えき',
#   'ほうめん',
#   'で',
#   'はじめ',
#   'や',
#   'がっ',
#   'た',
#   'ぶ',
#   'は',
#   'は',
#   'は',
#   'は',
#   'E'],
#  ['いやがらせ', 'し', 'て', 'かっ', 'た', 'とか', 'あほ', 'だろ', 'う', 'E'],
#  ['なに', 'やっ', 'て', 'ん', 'だ', 'こいつ', 'ら', 'E'],
#  ['ありた',
#   'ら',
#   'の',
#   'ふほうこうい',
#   'が',
#   'ある',
#   'こと',
#   'を',
#   'けいさつ',
#   'が',
#   'わかっ',
#   'て',
#   'たっと',
#   'こと',
#   'でしょ',
#   'う',
#   'ね',
#   'E'],
#  ['どちら',
#   'か',
#   'と',
#   'いう',
#   'と',
#   'でも',
#   'がわ',
#   'に',
#   'いぎ',
#   'が',
#   'あっ',
#   'た',
#   'な',
#   'よしふ',
#   'いっぱ',
#   'を',
#   'つり',
#   'だせ',
#   'た',
#   'から',
#   'E'],
#  ['でもたい',
#   'の',
#   'いない',
#   'ばしょ',
#   'で',
#   'ぼうがい',
#   'かつどう',
#   'やっ',
#   'て',
#   'しょうりせんげん',
#   'かよ',
#   'E'],
#  ['ありた', 'と', 'その', 'いそぎんちゃく', 'は', 'くやし', 'そう', 'じゃ', 'ない', 'か', 'E'],
#  ['それで', 'つぎ', 'の', 'せんきょ', 'に', 'かてる', 'つもり', 'な', 'ん', 'です', 'か', 'ねえ', 'E'],
#  ['ぱよく', 'はっきょう', 'ちゅう', 'E'],
#  ['きょか',
#   'さ',
#   'れ',
#   'た',
#   'でも',
#   'を',
#   'しゅうだん',
#   'で',
#   'ほうい',
#   'でも',
#   'は',
#   'いほう',
#   'じゃ',
#   'ね',
#   'E'],
#  ['げんろんのじゆう',
#   'を',
#   'しんがい',
#   'する',
#   'こっかいぎいん',
#   'が',
#   'いる',
#   'と',
#   'は',
#   'たまげ',
#   'た',
#   'なあ',
#   'E'],
#  ['は', 'とどけで', 'し', 'て', 'ない', 'ん', 'か', 'な', 'E'],
#  ['ぼうりょくしゅうだん',
#   'による',
#   'ことばがり',
#   'まさに',
#   'せんご',
#   'の',
#   'ちょうせんじん',
#   'の',
#   'しょぎょう',
#   'E'],
#  ['しば',
#   'きは',
#   'かんぜん',
#   'に',
#   'かながわけんけい',
#   'に',
#   'ほうい',
#   'さ',
#   'れ',
#   'てる',
#   'もよう',
#   'わっと',
#   'E'],
#  ['けいさつ',
#   'が',
#   'きょか',
#   'し',
#   'た',
#   'ごうほう',
#   'てき',
#   'な',
#   'でも',
#   'を',
#   'ぼうがい',
#   'する',
#   'の',
#   'は',
#   'いほう',
#   'と',
#   'いう',
#   'か',
#   'けんぽう',
#   'における',
#   'きほんてきじんけん',
#   'の',
#   'しゅうかいのじゆう',
#   'に',
#   'はんする',
#   'よう',
#   'な',
#   'き',
#   'が',
#   'する',
#   'ん',
#   'だ',
#   'が',
#   'E'],
#  ['はんにち', 'やくざ', 'が', 'おお', 'すぎる', 'よ', 'ね', 'E'],
#  ['これ', 'も', 'さんどう', 'し', 'た', 'だけ', 'って', 'にげる', 'ん', 'か', 'な', 'E'],
#  ['ほいほい',
#   'いりょくぎょうむぼうがい',
#   'が',
#   'せいりつ',
#   'かつ',
#   'どうこうほういはん',
#   'けいじ',
#   'ばつ',
#   'と',
#   'ぎょうせい',
#   'ぼうがい',
#   'で',
#   'きん',
#   'を',
#   'とれ',
#   'E'],
#  ['てろとうじゅんびざい', 'でし', 'E'],
#  ['しばきたい', 'は', 'てろ', 'を', 'やり', 'そう', 'だ', 'から', 'たいほ', 'し', 'ちゃえ', 'E'],
#  ['こわい',
#   'なあ',
#   'ぱよく',
#   'が',
#   'せいけん',
#   'とっ',
#   'たら',
#   'こう',
#   'やっ',
#   'て',
#   'げんろんだんあつ',
#   'する',
#   'ん',
#   'だろ',
#   'う',
#   'な',
#   'E'],
#  ['きょうぼうざい', 'が', 'しこう', 'さ', 'れ', 'た', 'のに', 'よく', 'やる', 'なあ', 'E'],
#  ['いりょくぎょうむぼうがい',
#   'の',
#   'ぎぎ',
#   'が',
#   'ある',
#   'しゅさいしゃ',
#   'は',
#   'ひがい',
#   'とどけ',
#   'を',
#   'だせ',
#   'げんば',
#   'の',
#   'けいさつ',
#   'に',
#   'しんこく',
#   'で',
#   'も',
#   'いい',
#   'E'],
#  ['みんしんとう',
#   'は',
#   'こくみん',
#   'の',
#   'けんり',
#   'で',
#   'ある',
#   'でも',
#   'を',
#   'ぼうりょく',
#   'で',
#   'ふうさつ',
#   'する',
#   'の',
#   'か',
#   'とんでも',
#   'ない',
#   'せいとう',
#   'だ',
#   'な',
#   'いんがい',
#   'じゃ',
#   'なく',
#   'こっかいない',
#   'で',
#   'しごと',
#   'し',
#   'て',
#   'がんばれよ',
#   'E'],
#  ['やつら',
#   'を',
#   'とおす',
#   'なっ',
#   'て',
#   'だいいちじせかいたいせん',
#   'の',
#   'ふらんす',
#   'だ',
#   'っけ',
#   'ほんと',
#   'すき',
#   'だ',
#   'ねぇ',
#   'せんそう',
#   'が',
#   'E'],
#  ['また', 'どうろ', 'ふさぎ', 'や', 'がっ', 'た', 'たいほ', 'しろ', 'よ', 'E'],
#  ['どうせ', 'じょし', 'だけ', 'に', 'おしえる', 'ん', 'だろ', 'E'],
#  ['よる', 'の', 'ほしゅう', 'じゅぎょう', 'E'],
#  ['わざとらしい', 'こと', 'きわまりない', 'E'],
#  ['いまさら',
#   'な',
#   'でも',
#   'うっかり',
#   'おき',
#   'に',
#   'むすめ',
#   'を',
#   'お',
#   'もちかえり',
#   'ちょうさ',
#   'し',
#   'ちゃう',
#   'んで',
#   'E'],
#  ['よる', 'の', 'とくべつきょうしつ', 'E'],
#  ['ひんこん',
#   'ちょうさ',
#   'の',
#   'あいて',
#   'を',
#   'ぶっしょく',
#   'ね',
#   'さすが',
#   'は',
#   'せいじん',
#   'わっと',
#   'E'],
#  ['よる', 'の', 'せい', 'かつ', 'しどう', 'E'],
#  ['で',
#   'なに',
#   'を',
#   'おしえ',
#   'て',
#   'い',
#   'た',
#   'ん',
#   'だ',
#   'それ',
#   'に',
#   'きょういんめんきょ',
#   'いる',
#   'ん',
#   'じゃ',
#   'の',
#   'E'],
#  ['じょし', 'に', 'かぎる', 'E'],
#  ['きもち', 'わるい', 'E'],
#  ['じじい', 'が', 'おこづかい', 'くれる', 'の', 'E'],
#  ['ひさいち', 'の', 'ひんこん', 'じょし', 'ちょうさ', 'か', 'よ', 'E'],
#  ['まぁ', 'あまくだり', 'な', 'わけ', 'だ', 'が', 'E'],
#  ['つぎ', 'は', 'ちゅうがくせい', 'か', 'よ', 'みはり', 'づけ', 'と', 'けっ', 'て', 'E'],
#  ['じぇいしい', 'は', 'あか', 'ん', 'やろ', 'E'],
#  ['よる', 'の', 'ぼらんてぃあ', 'その', 'まんま', 'だ', 'な', 'E'],
#  ['これ', 'は', 'じんかくしゃ', 'かっこ', 'E'],
#  ['よし',
#   'こんど',
#   'こそ',
#   'ひんこん',
#   'ちょうさ',
#   'だ',
#   'な',
#   'はやく',
#   'ちょうさほうこく',
#   'を',
#   'だし',
#   'て',
#   'くれ',
#   'よ',
#   'E'],
#  ['こいつ',
#   'に',
#   'しどう',
#   'さ',
#   'れ',
#   'てる',
#   'がくせい',
#   'から',
#   'なに',
#   'か',
#   'じょうほう',
#   'ない',
#   'の',
#   'E'],
#  ['いまさら',
#   'むり',
#   'し',
#   'て',
#   'も',
#   'たすく',
#   'よしみ',
#   'おやじ',
#   'って',
#   'の',
#   'は',
#   'けせ',
#   'ない',
#   'のに',
#   'ばか',
#   'な',
#   'すけべえ',
#   'だ',
#   'なあ',
#   'E'],
#  ['ろりこん', 'せい', 'じん', 'は', 'きょういく', 'に', 'からん', 'だら', 'だめ', 'E'],
#  ['しなさだめ', 'を', 'し', 'てる', 'と', 'しか', 'おもえ', 'ない', 'E'],
#  ['じゃく', 'すぎ', 'わろた', 'E'],
#  ['わがくに',
#   'は',
#   'にっぽん',
#   'に',
#   'ななひゃくななじゅっかい',
#   'も',
#   'しんりゃく',
#   'さ',
#   'れ',
#   'た',
#   'じゃく',
#   'え',
#   'っ',
#   'せかい',
#   'さい',
#   'じゃく',
#   'を',
#   'ほこれ',
#   'ちょうせんじん',
#   'E'],
#  ['よわ',
#   'すぎる',
#   'にも',
#   'ほど',
#   'が',
#   'ある',
#   'だろ',
#   'さい',
#   'じゃく',
#   'みんぞく',
#   'だ',
#   'な',
#   'E'],
#  ['ふくしゅう', 'を', 'わすれ', 'た', 'じゅけんせい', 'に', 'みらい', 'は', 'ない', 'E'],
#  ['よわっちい',
#   'みんぞく',
#   'だ',
#   'ね',
#   'そんなに',
#   'しんりゃく',
#   'さ',
#   'れ',
#   'て',
#   'なに',
#   'も',
#   'たいさく',
#   'し',
#   'なかっ',
#   'た',
#   'わけ',
#   'なさけない',
#   'みんぞく',
#   'だ',
#   'ね',
#   'E'],
#  ['れきし',
#   'を',
#   'みる',
#   'と',
#   'かんこくじん',
#   'って',
#   'つねに',
#   'やら',
#   'れ',
#   'っぱなし',
#   'の',
#   'みんぞく',
#   'だ',
#   'よ',
#   'ね',
#   'E'],
#  ['ちょんもめん', 'よわっ', 'E'],
#  ['ななひゃくななじゅっかい', 'の', 'どうぞう', 'は', 'よ', 'E'],
#  ['なな',
#   'なな',
#   'ぜろ',
#   'かい',
#   'も',
#   'しんりゃく',
#   'さ',
#   'れ',
#   'た',
#   'なんて',
#   'どんだけ',
#   'よわく',
#   'て',
#   'な',
#   'みんぞく',
#   'な',
#   'ん',
#   'だ',
#   'よ',
#   'E'],
#  ['わがくに',
#   'は',
#   'にっぽん',
#   'に',
#   'ななひゃくななじゅっかい',
#   'も',
#   'しんりゃく',
#   'さ',
#   'れ',
#   'まし',
#   'た',
#   'なんぞ',
#   'それ',
#   'とうごうしっちょうしょう',
#   'の',
#   'しんにゅう',
#   'もうそう',
#   'の',
#   'に',
#   'なる',
#   'ん',
#   'か',
#   'ねえ',
#   'そろそろ',
#   'ちゅうき',
#   'を',
#   'すぎ',
#   'て',
#   'んじゃ',
#   'ね',
#   'この',
#   'ひと',
#   'くすり',
#   'が',
#   'あっ',
#   'て',
#   'ない',
#   'ん',
#   'じゃ',
#   'おめが',
#   'E'],
#  ['すげ',
#   'え',
#   'よく',
#   'いわ',
#   'れる',
#   'かんこくじん',
#   'の',
#   'こだいもうそう',
#   'くせ',
#   'がよく',
#   'で',
#   'てる',
#   'しょうせつ',
#   'だ',
#   'な',
#   'E'],
#  ['ふくしゅう', 'を', 'わすれ', 'なく', 'て', 'も', 'みらい', 'が', 'ない', 'だろ', 'E'],
#  ['せん', 'かい', 'まで', 'あと', 'すこし', 'だ', 'な', 'がんばれにっぽん', 'E'],
#  ['ななひゃくななじゅっかい',
#   'も',
#   'しんりゃく',
#   'できる',
#   'なら',
#   'もはや',
#   'すなっくかんかく',
#   'で',
#   'ほろぼし',
#   'て',
#   'とうぜん',
#   'ななひゃくななじゅっかい',
#   'も',
#   'おもいとどまっ',
#   'て',
#   'たすけ',
#   'た',
#   'こと',
#   'に',
#   'かんしゃ',
#   'しろ',
#   'かす',
#   'すぎる',
#   'だろ',
#   'E'],
#  ['だい', 'いち', 'かい', 'め', 'の', 'しんりゃく', 'は', 'いつ', 'だっ', 'た', 'の', 'E'],
#  ['そもそも',
#   'にっぽん',
#   'が',
#   'ちょうせん',
#   'を',
#   'ななひゃくななじゅっかい',
#   'も',
#   'しんりゃく',
#   'に',
#   'せいこう',
#   'し',
#   'てる',
#   'なら',
#   'ちゅうごく',
#   'は',
#   'ちょうせん',
#   'を',
#   'まん',
#   'かい',
#   'ぐらい',
#   'しんりゃく',
#   'に',
#   'せいこう',
#   'し',
#   'てる',
#   'ん',
#   'じゃ',
#   'ない',
#   'か',
#   'ちせいがく',
#   'てき',
#   'に',
#   'かんがえれ',
#   'ば',
#   'わかる',
#   'E'],
#  ['ななひゃくななじゅっかい',
#   'も',
#   'ゆび',
#   'を',
#   'くわえ',
#   'て',
#   'しんりゃく',
#   'さ',
#   'れる',
#   'の',
#   'を',
#   'み',
#   'て',
#   'た',
#   'の',
#   'か',
#   'ちょうせん',
#   'さる',
#   'は',
#   'くそ',
#   'じゃく',
#   'じゃ',
#   'か',
#   'わらわせる',
#   'な',
#   'へたれ',
#   'すぎる',
#   'だろ',
#   'E'],
#  ['おりんぴっく', 'より', 'はやい', 'だ', 'な', 'おい', 'E'],
#  ['わがくに',
#   'って',
#   'だいかんみんこく',
#   'を',
#   'さし',
#   'て',
#   'いる',
#   'な',
#   'せんきゅうひゃくよんじゅうはちね',
#   'はちがつじゅうさんにち',
#   'けんこく',
#   'だ',
#   'から',
#   'ろくじゅうきゅうねん',
#   'で',
#   'にっぽん',
#   'に',
#   'ななひゃくななじゅっかい',
#   'しんりゃく',
#   'さ',
#   'れ',
#   'た',
#   'ん',
#   'だ',
#   'ねん',
#   'じゅういっかい',
#   'だ',
#   'E'],
#  ['えっ',
#   'それ',
#   'じゃ',
#   'ちょうせんじん',
#   'は',
#   'たんなる',
#   'あほ',
#   'って',
#   'こと',
#   'に',
#   'なる',
#   'ぞ',
#   'E'],
#  ['ななひゃくななじゅっかい',
#   'って',
#   'こく',
#   'の',
#   'ほど',
#   'を',
#   'なし',
#   'て',
#   'むい',
#   'です',
#   'やん',
#   'E'],
#  ['よわ', 'すぎ', 'だろ', 'E'],
#  ['じゃこ', 'か', 'よ', 'E'],
#  ['あと', 'なな', 'かい', 'で', 'ぷげら', 'E'],
#  ['みずから', 'むのう', 'を', 'さらし', 'て', 'どう', 'する', 'E'],
#  ['どれ', 'だけ', 'よわっちい', 'の', 'よ', 'E'],
#  ['いち',
#   'ど',
#   'も',
#   'ていこう',
#   'せ',
#   'ず',
#   'に',
#   'やら',
#   'れ',
#   'っぱなし',
#   'へたれ',
#   'じゃ',
#   'ね',
#   'E'],
#  ['ふくしゅう',
#   'と',
#   'き',
#   'た',
#   'か',
#   'うっ',
#   'て',
#   'いい',
#   'の',
#   'は',
#   'うた',
#   'れる',
#   'かくご',
#   'が',
#   'ある',
#   'やっこ',
#   'だけ',
#   'だ',
#   'E'],
#  ['まじ', 'きち', 'すぎ', 'て', 'くさ', 'E'],
#  ['ななひゃくななじゅっかい',
#   'も',
#   'しんりゃく',
#   'さ',
#   'れ',
#   'た',
#   'こと',
#   'を',
#   'はじろ',
#   'よ',
#   'な',
#   'で',
#   'なん',
#   'まん',
#   'にん',
#   'しん',
#   'だ',
#   'って',
#   'E'],
#  ['ななひゃくななじゅっかい', 'の', 'せんせき', 'は', 'どんな', 'かんじ', 'な', 'の', 'E'],
#  ['どんだけ',
#   'ふるぼっこ',
#   'さ',
#   'れ',
#   'て',
#   'ん',
#   'だ',
#   'よ',
#   'ぎねす',
#   'に',
#   'いれろ',
#   'せかい',
#   'で',
#   'さい',
#   'じゃく',
#   'の',
#   'みんぞく',
#   'ってな',
#   'E'],
#  ['この', 'じんどう', 'し', 'ちゃっ', 'た', 'の', 'E'],
#  ['また', 'うしろ', 'から', 'うっ', 'てる', 'E'],
#  ['みかた', 'を', 'はいご', 'から', 'しゃげき', 'する', 'やっこ', 'E'],
#  ['べつに',
#   'しょっく',
#   'じゃ',
#   'よ',
#   'な',
#   'んで',
#   'いしば',
#   'は',
#   'ひと',
#   'の',
#   'きもち',
#   'を',
#   'かって',
#   'に',
#   'だいべん',
#   'し',
#   'て',
#   'ん',
#   'だ',
#   'よ',
#   'きもち',
#   'わるい',
#   'E'],
#  ['ぺらぺら', 'しゃべる', 'な', 'えみ', 'め', 'は', 'から', 'E'],
#  ['この', 'ひと', 'わたりどり', 'やん', 'しんよう', 'でけ', 'へん', 'わ', 'E'],
#  ['みかた',
#   'を',
#   'せなか',
#   'から',
#   'うつ',
#   'ちくしょう',
#   'ひはん',
#   'が',
#   'あくい',
#   'やく',
#   'じゃ',
#   'ない',
#   'から',
#   'さっさと',
#   'りとう',
#   'しろ',
#   'よ',
#   'E'],
#  ['ほんらい',
#   'えんご',
#   'しゃげき',
#   'する',
#   'べき',
#   'やつ',
#   'に',
#   'うしろ',
#   'から',
#   'うた',
#   'れ',
#   'た',
#   'よう',
#   'な',
#   'もん',
#   'だ',
#   'な',
#   'E'],
#  ['あべ',
#   'の',
#   'かざむき',
#   'が',
#   'わるく',
#   'なっ',
#   'て',
#   'から',
#   'とたんに',
#   'じょうぜつ',
#   'に',
#   'なっ',
#   'た',
#   'な',
#   'きゅう',
#   'に',
#   'やる',
#   'こと',
#   'かわっ',
#   'た',
#   'わけ',
#   'で',
#   'も',
#   'ない',
#   'のに',
#   'こういう',
#   'やつ',
#   'が',
#   'いちばん',
#   'しんよう',
#   'でき',
#   'ない',
#   'E'],
#  ['うしろ',
#   'から',
#   'ぶて',
#   'ば',
#   'じぶん',
#   'の',
#   'しじ',
#   'が',
#   'あがる',
#   'と',
#   'おもっ',
#   'てる',
#   'の',
#   'か',
#   'E'],
#  ['よみうり',
#   'よめ',
#   'も',
#   'きりとり',
#   'じゃ',
#   'ん',
#   'あほ',
#   'か',
#   'しつぎ',
#   'で',
#   'よみうり',
#   'で',
#   'しつもん',
#   'し',
#   'てる',
#   'ん',
#   'だ',
#   'から',
#   'よみうり',
#   'よめ',
#   'て',
#   'いっ',
#   'た',
#   'だけ',
#   'だろ',
#   'う',
#   'E'],
#  ['あさひしんぶん', 'の', 'きじ', 'で', 'くさ', 'E'],
#  ['よみうりしんぶん', 'を', 'でぃ', 'すっ', 'てる', 'の', 'か', 'E'],
#  ['いしば', 'ひととして', 'しんよう', 'でき', 'ない', 'みんしんとう', 'に', 'よく', 'いる', 'たいぷ', 'E'],
#  ['こいつ',
#   'まじで',
#   'うる',
#   'せ',
#   'な',
#   'ふつうに',
#   'はんとうこうい',
#   'じゃ',
#   'ね',
#   'とういん',
#   'ひゃくにん',
#   'しゅう',
#   'まて',
#   'なかっ',
#   'たら',
#   'おもい',
#   'を',
#   'かし',
#   'て',
#   'やれ',
#   'E'],
#  ['こいつ', 'じみん', 'から', 'で', 'た', 'ほう', 'が', 'いい', 'だろ', 'う', 'E'],
#  ['いしば',
#   'も',
#   'かんぜん',
#   'に',
#   'せろん',
#   'を',
#   'よみ',
#   'ちがえ',
#   'てる',
#   'ばかもの',
#   'な',
#   'ん',
#   'だ',
#   'よ',
#   'なあ',
#   'E'],
#  ['さいきん',
#   'の',
#   'いしば',
#   'みんしんとう',
#   'いん',
#   'みたい',
#   'に',
#   'なっ',
#   'てる',
#   'ん',
#   'だ',
#   'けど',
#   'だいじょうぶ',
#   'な',
#   'の',
#   'か',
#   'E'],
#  ['が', 'あさひ', 'E'],
#  ['めでぃあ',
#   'は',
#   'ここ',
#   'ぞ',
#   'とばかり',
#   'に',
#   'いしば',
#   'おし',
#   'てる',
#   'けど',
#   'むり',
#   'だ',
#   'と',
#   'おもう',
#   'よ',
#   'E'],
#  ['はたして', 'そうかな', 'E'],
#  ['なんで', 'やとう', 'の', 'しじりつ', 'は', 'あがら', 'ない', 'ん', 'です', 'か', 'ねぇ', 'E'],
#  ['ますこみ', 'ふしん', 'が', 'たかまっ', 'た', 'だけ', 'だ', 'わ', 'E'],
#  ['でも',
#   'た',
#   'の',
#   'せいとう',
#   'は',
#   'のきなみ',
#   'いち',
#   'けた',
#   'じゃん',
#   'しじりつ',
#   'けっきょく',
#   'あべ',
#   'から',
#   'かわる',
#   'こと',
#   'は',
#   'ない',
#   'よ',
#   'E'],
#  ['かわり',
#   'が',
#   'みえ',
#   'ない',
#   'のに',
#   'とうかく',
#   'うんどう',
#   'とか',
#   'うける',
#   'ん',
#   'です',
#   'けど',
#   'E'],
#  ['こんげつ', 'に', 'はいっ', 'た', 'あたり', 'から', 'の', 'しじりつ', 'の', 'きゅうらく', 'ぶり', 'E'],
#  ['ますこみ', 'は', 'とっく', 'に', 'にっぽんじん', 'ばなれ', 'し', 'てる', 'もん', 'な', 'E'],
#  ['また', 'ちょん', 'の', 'か', 'E'],
#  ['いじょう', 'な', 'ねがきゃん', 'E'],
#  ['ごみ',
#   'が',
#   'ゆうどう',
#   'する',
#   'よう',
#   'な',
#   'ほうどう',
#   'し',
#   'てる',
#   'から',
#   'な',
#   'つじもと',
#   'れんほう',
#   'あたり',
#   'の',
#   'はなし',
#   'も',
#   'もっと',
#   'とりあげ',
#   'て',
#   'みろ',
#   'E'],
#  ['せろん',
#   'って',
#   'どうして',
#   'いつも',
#   'おいら',
#   'の',
#   'いけん',
#   'は',
#   'はいっ',
#   'て',
#   'ない',
#   'の',
#   'おめが',
#   'E'],
#  ['また', 'がんぼう', 'で', 'か', 'E'],
#  ['せろん', 'の', 'あべばなれ', 'すすむ', 'がんぼう', 'E'],
#  ['そう',
#   'か',
#   'せけん',
#   'は',
#   'やっぱり',
#   'あべしじ',
#   'やめ',
#   'た',
#   'ん',
#   'だ',
#   'ね',
#   'わたし',
#   'も',
#   'やめよ',
#   'う',
#   'と',
#   'なに',
#   'も',
#   'かんがえ',
#   'て',
#   'い',
#   'ない',
#   'ひと',
#   'は',
#   'せんどう',
#   'さ',
#   'れ',
#   'ちゃう',
#   'ね',
#   'E'],
#  ['ないかくしじりつ',
#   'ろく',
#   'わり',
#   'って',
#   'の',
#   'が',
#   'いじょう',
#   'だっ',
#   'た',
#   'だけ',
#   'で',
#   'さん',
#   'わり',
#   'ぜんご',
#   'が',
#   'ふつう',
#   'の',
#   'じょうたい',
#   'を',
#   'もっ',
#   'て',
#   'に',
#   'わり',
#   'だい',
#   'とか',
#   'どやがお',
#   'し',
#   'ちゃう',
#   'じじつうしん',
#   'は',
#   'わらいもの',
#   'E'],
#  ['じみんとう',
#   'の',
#   'しじりつ',
#   'が',
#   'さがっ',
#   'て',
#   'も',
#   'やとう',
#   'の',
#   'しじりつ',
#   'は',
#   'どこ',
#   'も',
#   'いち',
#   'けた',
#   'だい',
#   'にっぽんじん',
#   'の',
#   'たいはん',
#   'が',
#   'やとう',
#   'を',
#   'しじ',
#   'し',
#   'て',
#   'ない',
#   'こと',
#   'だけ',
#   'は',
#   'あきらか',
#   'E'],
#  ['でも',
#   'みんしゅとう',
#   'しじりつ',
#   'は',
#   'じゅんちょう',
#   'に',
#   'おり',
#   'つづけ',
#   'て',
#   'いる',
#   'な',
#   'しじ',
#   'なし',
#   'そう',
#   'が',
#   'ふえ',
#   'て',
#   'いる',
#   'だけ',
#   'で',
#   'せんきょ',
#   'じ',
#   'は',
#   'けっきょく',
#   'じみんとう',
#   'しか',
#   'せんたくし',
#   'が',
#   'ない',
#   'ん',
#   'だ',
#   'よ',
#   'な',
#   'E'],
#  ['しょうめつ', 'E'],
#  ['さよく', 'の', 'うちげば', 'E'],
#  ['さすが', 'うごうのしゅう', 'E'],
#  ['わろた', 'E'],
#  ['れきしてき', 'って', 'くろれきし', 'です', 'か', 'E'],
#  ['れきしてき', 'やくわり', 'って', 'なに', 'E'],
#  ['かいとう', 'し', 'て', 'ぜんいん', 'ぎいんじしょく', 'しろ', 'E'],
#  ['せいけんこうたい', 'しか', 'あたま', 'に', 'なかっ', 'た', 'れんちゅう', 'だ', 'から', 'ね', 'E'],
#  ['かいとう',
#   'とか',
#   'とんでも',
#   'ない',
#   'ごみ',
#   'は',
#   'ちゃんと',
#   'し',
#   'た',
#   'ごみばこ',
#   'に',
#   'まとめ',
#   'て',
#   'くれ',
#   'ない',
#   'と',
#   'こまる',
#   'E'],
#  ['そうかつ', 'きた', 'ああああああああああ', 'E'],
#  ['やくわり', 'なんて', 'なに', 'も', 'なかっ', 'た', 'E'],
#  ['ただただ', 'はんにち', 'ばいこく', 'だっ', 'た', 'ね', 'E'],
#  ['れきしてき', 'やくわり', 'と', 'は', 'おおきく', 'で', 'た', 'もん', 'だ', 'わ', 'えみ', 'E'],
#  ['さぎ', 'かいしゃ', 'は', 'よく', 'なまえ', 'を', 'かえる', 'E'],
#  ['なに',
#   'の',
#   'しんねん',
#   'も',
#   'ない',
#   'ごみ',
#   'くず',
#   'の',
#   'あつまり',
#   'ある',
#   'の',
#   'は',
#   'へ',
#   'の',
#   'ほうし',
#   'のみ',
#   'E'],
#  ['にっぽん',
#   'に',
#   'を',
#   'あたえる',
#   'という',
#   'しめい',
#   'は',
#   'じゅうぶん',
#   'すぎる',
#   'ほど',
#   'うまく',
#   'やっ',
#   'た',
#   'と',
#   'おもう',
#   'ぞ',
#   'E'],
#  ['こいけ', 'の', 'とこ', 'に', 'いき', 'たい', 'ん', 'だろ', 'E'],
#  ['こい',
#   'つら',
#   'が',
#   'こくせい',
#   'に',
#   'くる',
#   'さい',
#   'の',
#   'に',
#   'はいり',
#   'たい',
#   'ん',
#   'だろ',
#   'E'],
#  ['え', 'この', 'ぜん', 'けっとう', 'し', 'た', 'ばっかり', 'や', 'ないか', 'E'],
#  ['かいとう',
#   'する',
#   'と',
#   'いま',
#   'まで',
#   'やらかし',
#   'た',
#   'もんだい',
#   'の',
#   'せきにん',
#   'が',
#   'きえる',
#   'という',
#   'こと',
#   'に',
#   'なる',
#   'の',
#   'か',
#   'E'],
#  ['みんしんとう',
#   'しじしゃ',
#   'の',
#   'みなさん',
#   'ちょっと',
#   'お',
#   'やいと',
#   'を',
#   'すえ',
#   'た',
#   'ほう',
#   'が',
#   'いい',
#   'と',
#   'おもい',
#   'ます',
#   'よ',
#   'E'],
#  ['また', 'なまえがえ', 'えたい', 'だけ', 'じゃ', 'ねえ', 'か', 'E'],
#  ['かいとう',
#   'し',
#   'た',
#   'あと',
#   'は',
#   'どう',
#   'する',
#   'つもり',
#   'けっきょく',
#   'おなじ',
#   'で',
#   'やっ',
#   'て',
#   'いく',
#   'ん',
#   'でしょ',
#   'E'],
#  ['あじあけい',
#   'がいこくじん',
#   'ね',
#   'え',
#   'とうなんあじあ',
#   'みなみあじあ',
#   'か',
#   'ね',
#   'え',
#   'じこく',
#   'で',
#   'やっ',
#   'てる',
#   'こと',
#   'と',
#   'おなじ',
#   'こと',
#   'を',
#   'し',
#   'た',
#   'ん',
#   'だろ',
#   'E'],
#  ['わな', 'だ', 'な', 'E'],
#  ['れいぷ', 'じゃ', 'ない', 'の', 'か', 'ちょうせんじん', 'で', 'は', 'ない', 'かも', 'な', 'E'],
#  ['ずっと', 'たおれ', 'た', 'まま', 'えもの', 'まっ', 'て', 'た', 'の', 'か', 'E'],
#  ['ぜんい', 'を', 'きゅう', 'で', 'かえす', 'と', 'は', 'E'],
#  ['か', 'よ', 'E'],
#  ['こわ', 'すぎる', 'E'],
#  ['なに', 'これ', 'こわい', 'E'],
#  ['いみん', 'を', 'いれる', 'から', 'E'],
#  ['どういう',
#   'こと',
#   'や',
#   'ねん',
#   'こんな',
#   'きちがい',
#   'は',
#   'とっと',
#   'とさつ',
#   'しょぶん',
#   'しろ',
#   'E'],
#  ['あべ', 'する', 'の', 'これ', 'E'],
#  ['やっぱ', 'がいじん', 'は', 'きけん', 'や', 'な', 'E'],
#  ['よる', 'であるく', 'の', 'が', 'きけん', 'に', 'なっ', 'て', 'き', 'た', 'ね', 'E'],
#  ['むやみ', 'に', 'がいじん', 'を', 'いれる', 'から', 'E'],
#  ['あんな',
#   'のどか',
#   'な',
#   'いなか',
#   'に',
#   'も',
#   'こくせきふめい',
#   'の',
#   'きょうぼう',
#   'な',
#   'はんざい',
#   'しゃ',
#   'が',
#   'うろうろ',
#   'しとる',
#   'の',
#   'か',
#   'にっぽん',
#   'は',
#   'もう',
#   'お',
#   'おわり',
#   'い',
#   'だ',
#   'なあ',
#   'E'],
#  ['なぞ', 'の', 'E'],
#  ['どこ', 'の', 'かいしゃ', 'が', 'やとい', 'いれ', 'た', 'ん', 'だろ', 'う', 'な', 'E'],
#  ['こわっ', 'ひがいしゃ', 'とらうま', 'もん', 'だ', 'な', 'これ', 'E'],
#  ['ひどい',
#   'な',
#   'これ',
#   'は',
#   'き',
#   'に',
#   'なっ',
#   'て',
#   'も',
#   'くるま',
#   'から',
#   'おり',
#   'ず',
#   'に',
#   'けいさつ',
#   'に',
#   'でんわ',
#   'する',
#   'べき',
#   'だっ',
#   'た',
#   'な',
#   'E'],
#  ['こ',
#   'ええええ',
#   'なんで',
#   'くまもと',
#   'に',
#   'こんな',
#   'の',
#   'が',
#   'せいそく',
#   'し',
#   'てる',
#   'ん',
#   'だろ',
#   'う',
#   'E'],
#  ['しんせつしん', 'が', 'きゅう', 'に', 'なる', 'か', 'こ', 'E'],
#  ['きんせいけん', 'を', 'ほうしゅつ', 'きんせいけん', 'が', 'ほうしゅつ', 'E'],
#  ['し', 'て', 'こんな', 'の', 'ばっかり', 'だ', 'な', 'かんこく', 'は', 'E'],
#  ['ほうしゅつ', 'さ', 'せ', 'たら', 'だめ', 'だろ', 'E'],
#  ['りせい', 'が', 'ちょっと', 'たら', 'ない', 'の', 'か', 'な', 'E'],
#  ['だりつ', 'だてん', 'とうるい', 'E'],
#  ['しこりあん', 'に', 'ことかか', 'ない', 'かんこく', 'E'],
#  ['また',
#   'しこりあん',
#   'か',
#   'これ',
#   'で',
#   'せんしんこく',
#   'たろ',
#   'う',
#   'と',
#   'する',
#   'こと',
#   'に',
#   'いじょう',
#   'な',
#   'かかわり',
#   'を',
#   'もっ',
#   'て',
#   'いる',
#   'の',
#   'だ',
#   'から',
#   'あきれる',
#   'ほか',
#   'ない',
#   'E'],
#  ['いっしゅん',
#   'で',
#   'こうふん',
#   'し',
#   'て',
#   'できる',
#   'なんて',
#   'みんぞく',
#   'の',
#   'ほこり',
#   'で',
#   'は',
#   'ない',
#   'か',
#   'E'],
#  ['どこ', 'でも', 'しこ', 'る', 'ちょうせんじん', 'さる', 'か', 'よ', 'E'],
#  ['かんこく',
#   'の',
#   'あたらしい',
#   'こくぎ',
#   'を',
#   'けいもう',
#   'する',
#   'りっぱ',
#   'な',
#   'にんげん',
#   'じゃ',
#   'ない',
#   'か',
#   'E'],
#  ['なん',
#   'で',
#   'そんなに',
#   'し',
#   'て',
#   'ない',
#   'と',
#   'いけ',
#   'ない',
#   'の',
#   'かんこくじん',
#   'とくゆう',
#   'の',
#   'びょうき',
#   'なら',
#   'つみ',
#   'に',
#   'とえ',
#   'ない',
#   'ん',
#   'じゃ',
#   'ね',
#   'E'],
#  ['いつも', 'の', 'かんこく', 'E'],
#  ['ちしょう', 'みんぞく', 'なのか', 'E'],
#  ['すりゃ', 'そりゃ', 'ほうしゅつ', 'だ', 'わ', 'な', 'E'],
#  ['れいぷ', 'じゃ', 'ない', 'から', 'りょうしん', 'てき', 'かんこくじん', 'だろ', 'E'],
#  ['みすず', 'がくえん', 'の', 'こうこく', 'か', 'E'],
#  ['こすぷれ', 'に', 'しか', 'みえ', 'ん', 'E'],
#  ['だれ', 'が', 'みる', 'の', 'E'],
#  ['うちゅう',
#   'みらいえすえふ',
#   'な',
#   'のに',
#   'にっぽんじん',
#   'しか',
#   'で',
#   'ない',
#   'とか',
#   'とんでも',
#   'じゃ',
#   'ない',
#   'こと',
#   'だけ',
#   'いのる',
#   'わ',
#   'E'],
#  ['ふじ',
#   'の',
#   'どらま',
#   'は',
#   'かんこくねた',
#   'を',
#   'はさん',
#   'で',
#   'くる',
#   'から',
#   'み',
#   'ない',
#   'E'],
#  ['かんこく', 'ようそ', 'いれ', 'そう', 'な', 'かんじ', 'E'],
#  ['しゅつえんしゃ', 'に', 'にっぽんじん', 'いない', 'って', 'かんじ', 'に', 'みえる', 'おれ', 'E'],
#  ['ちょん',
#   'が',
#   'しゅやく',
#   'の',
#   'せんたいもの',
#   'と',
#   'いわ',
#   'れ',
#   'て',
#   'も',
#   'いわかん',
#   'が',
#   'ない',
#   'E'],
#  ['かいがい', 'かんこく', 'どらま', 'E'],
#  ['かいがい', 'にっぽん', 'E'],
#  ['まず',
#   'いちまいめ',
#   'の',
#   'から',
#   'し',
#   'て',
#   'しろうと',
#   'さく',
#   'に',
#   'しか',
#   'みえ',
#   'ない',
#   'E'],
#  ['なんで', 'ふつう', 'の', 'かっこう', 'が', 'でき', 'ない', 'か', 'な', 'E'],
#  ['この', 'れべる', 'じゃ', 'ぎゃぐ', 'どらま', 'に', 'する', 'しか', 'ない', 'だろ', 'E'],
#  ['あまちゅあ', 'が', 'つくっ', 'た', 'の', 'E'],
#  ['しゅやく', 'の', 'おっさん', 'かんこくじん', 'E'],
#  ['が', 'ちょん', 'な', 'の', 'な', 'E'],
#  ['じょうだん', 'だろ', 'しゃしん', 'だけ', 'で', 'だめ', 'すぎる', 'わ', 'E'],
#  ['これ', 'は', 'はやる', 'よかん', 'が', 'いち', 'も', 'し', 'ない', 'E'],
#  ['いしば', 'に', 'ふりまわさ', 'れる', 'みんしん', 'E'],
#  ['にげ', 'て', 'んじゃ', 'ねぇ', 'ぞ', 'E'],
#  ['いしば', 'E'],
#  ['は', 'よ', 'りとう', 'しろ', 'E'],
#  ['なんで',
#   'ちゅうし',
#   'な',
#   'ん',
#   'だ',
#   'よ',
#   'いしば',
#   'あ',
#   'りき',
#   'の',
#   'べんきょうかい',
#   'か',
#   'よ',
#   'E'],
#  ['なに',
#   'を',
#   'し',
#   'たい',
#   'の',
#   'か',
#   'まったく',
#   'わから',
#   'ない',
#   'しんよう',
#   'でき',
#   'ない',
#   'だろ',
#   'こんな',
#   'やつ',
#   'E'],
#  ['なん', 'なん', 'こいつ', 'は', 'E'],
#  ['みずから',
#   'せっきょくてき',
#   'に',
#   'じぶん',
#   'の',
#   'いばしょ',
#   'を',
#   'けずっ',
#   'て',
#   'いく',
#   'すたいる',
#   'E'],
#  ['えんりょ', 'しない', 'で', 'しゅっせき', 'しろ', 'や', 'くそ', 'やろう', 'E'],
#  ['べんきょうかい', 'ちゅうし', 'って', 'しゅひん', 'か', 'よ', 'いしば', 'E'],
#  ['なに', 'を', 'やっ', 'とる', 'ん', 'だ', 'と', 'E'],
#  ['しょうじき',
#   'いしば',
#   'さん',
#   'こういう',
#   'ひと',
#   'だ',
#   'と',
#   'は',
#   'おもっ',
#   'て',
#   'なかっ',
#   'た',
#   'なぁ',
#   'E'],
#  ['げる', 'の', 'こうどう', 'しこう', 'は', 'おざわいちろう', 'に', 'そっくり', 'E'],
#  ['あんまり', 'みんしん', 'を', 'おちょくら', 'ない', 'で', 'あげ', 'て', 'E'],
#  ['うしろ',
#   'から',
#   'みかた',
#   'を',
#   'うつ',
#   'やつ',
#   'は',
#   'ぜったい',
#   'に',
#   'しじ',
#   'さ',
#   'れ',
#   'ない',
#   'E'],
#  ['じみん', 'は', 'さっさと', 'こいつ', 'おいだせ', 'よ', 'E'],
#  ['いしば', 'なんて', 'しよく', 'の', 'かたまり', 'だ', 'から', 'な', 'みんしん', 'に', 'ふさわしい', 'E'],
#  ['げる', 'あほ', 'や', 'なあ', 'もう', 'おそい', 'わ', 'E'],
#  ['ふらふら',
#   'と',
#   'おちつか',
#   'ない',
#   'こもの',
#   'だ',
#   'な',
#   'すっかり',
#   'そこ',
#   'が',
#   'みえ',
#   'た',
#   'な',
#   'この',
#   'ひと',
#   'も',
#   'E'],
#  ['いしば',
#   'けっせき',
#   'で',
#   'も',
#   'べんきょうかい',
#   'は',
#   'できる',
#   'だろ',
#   'こども',
#   'の',
#   'しゅうだん',
#   'じゃ',
#   'ない',
#   'ん',
#   'だ',
#   'から',
#   'E'],
#  ['と',
#   'いう',
#   'か',
#   'いしば',
#   'が',
#   'い',
#   'ない',
#   'と',
#   'だめ',
#   'だめ',
#   'な',
#   'みんしん',
#   'ほしゅ',
#   'って',
#   'E'],
#  ['ちょっと',
#   'って',
#   'へたれ',
#   'すぎ',
#   'ない',
#   'むほん',
#   'より',
#   'も',
#   'ほしん',
#   'って',
#   'かんじ',
#   'だ',
#   'な',
#   'E'],
#  ['これ', 'で', 'こいつ', 'の', 'そうり', 'の', 'め', 'は', 'なくなっ', 'た', 'な', 'E'],
#  ['いまさら', 'とりつくろっ', 'たって', 'むだ', 'だろ', 'いしば', 'は', 'はやく', 'で', 'て', 'いけ', 'E'],
#  ['うわ', 'さいあく', 'な', 'たいぷ', 'E'],
#  ['げる',
#   'が',
#   'へたれ',
#   'な',
#   'の',
#   'は',
#   'いまさら',
#   'だ',
#   'けど',
#   'その',
#   'げる',
#   'が',
#   'い',
#   'ない',
#   'と',
#   'けんぽう',
#   'の',
#   'こと',
#   'わから',
#   'ない',
#   'みんしん',
#   'も',
#   'どう',
#   'よ',
#   'E'],
#  ['なみだめ', 'すぱい', 'って', 'いわ', 'れ', 'ちゃっ', 'た', 'E'],
#  ['これ',
#   'は',
#   'だい',
#   'もんだい',
#   'だ',
#   'ぞ',
#   'くに',
#   'の',
#   'こんかん',
#   'に',
#   'かかわる',
#   'こと',
#   'だ',
#   'から',
#   'へいわぼけ',
#   'し',
#   'すぎ',
#   'だ',
#   'わ',
#   'にほんのこっかいぎいん',
#   'は',
#   'E'],
#  ['こくせきほう',
#   'に',
#   'いはん',
#   'し',
#   'て',
#   'い',
#   'ない',
#   'こと',
#   'を',
#   'しょうめい',
#   'できる',
#   'の',
#   'は',
#   'こくせき',
#   'の',
#   'せんたく',
#   'び',
#   'が',
#   'きさい',
#   'さ',
#   'れ',
#   'て',
#   'いる',
#   'こせきとうほん',
#   'のみ',
#   'です',
#   'や',
#   'さべつ',
#   'の',
#   'はなし',
#   'なんか',
#   'だれ',
#   'も',
#   'し',
#   'て',
#   'い',
#   'ない',
#   'こうしょくせんきょほう',
#   'および',
#   'こくせきほう',
#   'に',
#   'いはん',
#   'し',
#   'て',
#   'いる',
#   'か',
#   'どう',
#   'か',
#   'はんざい',
#   'を',
#   'おかし',
#   'て',
#   'いる',
#   'か',
#   'どう',
#   'か',
#   'の',
#   'はなし',
#   'を',
#   'し',
#   'て',
#   'い',
#   'ます',
#   'です',
#   'よ',
#   'ね',
#   'だれ',
#   'も',
#   'さべつ',
#   'なんか',
#   'し',
#   'て',
#   'ない',
#   'ほう',
#   'の',
#   'はなし',
#   'てる',
#   'の',
#   'に',
#   'さべつ',
#   'に',
#   'すりかえる',
#   'とか',
#   'こそく',
#   'です',
#   'よ',
#   'ね',
#   'E'],
#  ['これ',
#   'が',
#   'まじ',
#   'なら',
#   'やばい',
#   'ん',
#   'じゃ',
#   'ねえ',
#   'の',
#   'ほうりつ',
#   'を',
#   'かいせい',
#   'し',
#   'て',
#   'よ',
#   'E'],
#  ['おしえ',
#   'て',
#   'くれ',
#   'て',
#   'ありがとう',
#   'じかい',
#   'こっかい',
#   'で',
#   'の',
#   'こくせき',
#   'りれき',
#   'きさい',
#   'ほうれい',
#   'りっぽう',
#   'か',
#   'まっ',
#   'て',
#   'ます',
#   'E'],
#  ['れんほう',
#   'は',
#   'たいわん',
#   'へ',
#   'の',
#   'りだつ',
#   'しんせい',
#   'しょ',
#   'の',
#   'うつし',
#   'を',
#   'ていしゅつ',
#   'する',
#   'と',
#   'か',
#   'そう',
#   'いっ',
#   'て',
#   'い',
#   'た',
#   'よう',
#   'な',
#   'き',
#   'が',
#   'する',
#   'E'],
#  ['じゅう',
#   'こくせき',
#   'を',
#   'ふくむ',
#   'がいこくせき',
#   'の',
#   'にんげん',
#   'が',
#   'こっかいぎいん',
#   'やる',
#   'の',
#   'は',
#   'やはり',
#   'もんだい',
#   'だろ',
#   'う',
#   'はいがいしゅぎ',
#   'うんぬん',
#   'と',
#   'は',
#   'かんけい',
#   'なく',
#   'こっかのどくりつ',
#   'を',
#   'いじ',
#   'する',
#   'ため',
#   'に',
#   'も',
#   'ほうてき',
#   'に',
#   'きんし',
#   'し',
#   'じっこう',
#   'りょく',
#   'の',
#   'ある',
#   'ぼうしさく',
#   'を',
#   'ようい',
#   'す',
#   'べき',
#   'E'],
#  ['れんほう',
# ...
#   'よさん',
#   'さくげん',
#   'なんきょく',
#   'かんそく',
#   'の',
#   'よさん',
#   'が',
#   'おおはば',
#   'に',
#   'あっしゅく',
#   'きち',
#   'の',
#   'びちく',
#   'ねんりょう',
#   'きき',
#   'に',
#   'きゅう',
#   'しんこう',
#   'ききん',
#   'しわけ',
#   'よさん',
#   'おおはば',
#   'かっと',
#   'せきゆ',
#   'と',
#   'しお',
#   'の',
#   'びちく',
#   'れんほう',
#   'こめんと',
#   'つなみ',
#   'なんて',
#   'じっさい',
#   'に',
#   'くる',
#   'まで',
#   'に',
#   'じかん',
#   'さ',
#   'が',
#   'ある',
#   'から',
#   'その',
#   'じかん',
#   'で',
#   'できる',
#   'たいおう',
#   'を',
#   'すれ',
#   'ば',
#   'すむ',
#   'こと',
#   'あした',
#   'くる',
#   'の',
#   'か',
#   'ひゃくねんご',
#   'に',
#   'くる',
#   'の',
#   'か',
#   'にひゃくねん',
#   'ご',
#   'に',
#   'くる',
#   'の',
#   'か',
#   'こ',
#   'ない',
#   'の',
#   'か',
#   'わから',
#   'ない',
#   'たいさく',
#   'ひ',
#   'を',
#   'つかう',
#   'の',
#   'は',
#   'むだづかい',
#   'E'],
#  ['ぐたい',
#   'てき',
#   'に',
#   'こくせきはくだつ',
#   'できる',
#   'の',
#   'しなじん',
#   'が',
#   'さつ',
#   'じん',
#   'を',
#   'おかし',
#   'て',
#   'も',
#   'しゃくほう',
#   'する',
#   'にっぽん',
#   'で',
#   'はやく',
#   'ぎいん',
#   'じしょく',
#   'し',
#   'て',
#   'くれ',
#   'た',
#   'ほう',
#   'が',
#   'いい',
#   'にじゅうこくせき',
#   'はら',
#   'が',
#   'たつ',
#   'E'],
#  ['どんどん',
#   'やれ',
#   'ば',
#   'いい',
#   'その',
#   'たび',
#   'に',
#   'はんざいしゃ',
#   'れんほう',
#   'を',
#   'おもいだす',
#   'たとえ',
#   'すうねん',
#   'ご',
#   'に',
#   'ほうりつ',
#   'が',
#   'かわっ',
#   'た',
#   'として',
#   'も',
#   'はんざいしゃ',
#   'れんほう',
#   'の',
#   'つみ',
#   'は',
#   'かわら',
#   'ない',
#   'E'],
#  ['どうして',
#   'れんほう',
#   'さん',
#   'の',
#   'つごう',
#   'で',
#   'ほうりつ',
#   'を',
#   'かえ',
#   'ない',
#   'と',
#   'いけ',
#   'ない',
#   'の',
#   'でしょ',
#   'う',
#   'か',
#   'にっぽん',
#   'の',
#   'ほうりつ',
#   'を',
#   'まもれ',
#   'ない',
#   'なら',
#   'お',
#   'かえり',
#   'に',
#   'なれ',
#   'ば',
#   'よい',
#   'だけ',
#   'よけいなおせわ',
#   'です',
#   'よ',
#   'E'],
#  ['なら', 'けんぽう', 'も', 'じだい', 'に', 'そくし', 'て', 'かえ', 'ない', 'と', 'な', 'E'],
#  ['この', 'すりかえ', 'に', 'おおく', 'の', 'こくみん', 'は', 'いかり', 'を', 'かんじ', 'たろ', 'E'],
#  ['にっぽんこくせき',
#   'なんて',
#   'すぐ',
#   'に',
#   'むいみ',
#   'な',
#   'もの',
#   'に',
#   'なる',
#   'なん',
#   'で',
#   'かっ',
#   'て',
#   'にっぽん',
#   'なんて',
#   'くに',
#   'は',
#   'きえ',
#   'て',
#   'なくなる',
#   'からだ',
#   'E'],
#  ['ただ', 'の', 'てろりすと', 'です', 'やん', 'E'],
#  ['じぶん',
#   'じゃなくて',
#   'ほうりつ',
#   'が',
#   'わるい',
#   'これ',
#   'が',
#   'りっぽう',
#   'や',
#   'ばあい',
#   'によって',
#   'は',
#   'ぎょうせい',
#   'に',
#   'かかわる',
#   'にんげん',
#   'の',
#   'だいし',
#   'だって',
#   'いう',
#   'から',
#   'すごい',
#   'よ',
#   'ね',
#   'E'],
#  ['この',
#   'まさに',
#   'まるで',
#   'はんせい',
#   'し',
#   'て',
#   'い',
#   'ない',
#   'を',
#   'たいげん',
#   'し',
#   'た',
#   'ふるまい',
#   'よ',
#   'E'],
#  ['まさに', 'その', 'とおり', 'E'],
#  ['ただ', 'の', 'どくさいしゃ', 'やん', 'け', 'E'],
#  ['にっぽんこくせき',
#   'が',
#   'ない',
#   'とき',
#   'に',
#   'どんだけ',
#   'しわけ',
#   'やっ',
#   'た',
#   'ん',
#   'です',
#   'か',
#   'がいこくじん',
#   'こうさくいん',
#   'です',
#   'ね',
#   'まさに',
#   'E'],
#  ['あ',
#   'こうしょくせんきょほういはん',
#   'だ',
#   'から',
#   'せんじん',
#   'きっ',
#   'て',
#   'さっさと',
#   'ぎいん',
#   'じしょく',
#   'し',
#   'て',
#   'どうぞ',
#   'E'],
#  ['ほうりつ', 'まもれ', 'や', 'E'],
#  ['そこく', 'で', 'やれ', 'や', 'E'],
#  ['なん', 'な', 'ん', 'だ', 'こいつ', 'E'],
#  ['ちじょうは',
#   'の',
#   'は',
#   'ぜんぜん',
#   'ほうどう',
#   'し',
#   'て',
#   'ない',
#   'な',
#   'ひどい',
#   'もん',
#   'だ',
#   'E'],
#  ['しかく',
#   'が',
#   'なかっ',
#   'た',
#   'ひと',
#   'が',
#   'こくみん',
#   'あざむい',
#   'て',
#   'ぎいん',
#   'に',
#   'なっ',
#   'て',
#   'その',
#   'せきにん',
#   'も',
#   'とら',
#   'ず',
#   'に',
#   'ほうりつ',
#   'を',
#   'かいせい',
#   'する',
#   'こと',
#   'に',
#   'いよく',
#   'とか',
#   'かんぜん',
#   'に',
#   'こくみん',
#   'なめ',
#   'てる',
#   'こいつ',
#   'だけ',
#   'は',
#   'ゆるさ',
#   'ん',
#   'E'],
#  ['もくてき', 'は', 'にっぽん', 'のっとり', 'やん', 'やっぱり', 'ちゅうごくきょうさんとう', 'の', 'すぱい', 'E'],
#  ['こども', 'の', 'こくせき', 'は', 'おそらく', 'にじゅうこくせき', 'だろ', 'う', 'な', 'E'],
#  ['そら',
#   'こんな',
#   'やつ',
#   'が',
#   'とうしゅ',
#   'やっ',
#   'てる',
#   'ん',
#   'じゃ',
#   'うさんくさく',
#   'て',
#   'いれる',
#   'やつ',
#   'なんて',
#   'おら',
#   'ん',
#   'わ',
#   'E'],
#  ['そう',
#   'だ',
#   'な',
#   'まずは',
#   'みんしんとう',
#   'いん',
#   'の',
#   'にじゅうとうせき',
#   'から',
#   'だ',
#   'な',
#   'きょうさんとう',
#   'の',
#   'とうせき',
#   'を',
#   'のこし',
#   'た',
#   'まま',
#   'で',
#   'みんしんとう',
#   'の',
#   'やくしょく',
#   'に',
#   'つけ',
#   'ます',
#   'と',
#   'か',
#   'ね',
#   'E'],
#  ['まず',
#   'ご',
#   'じしん',
#   'が',
#   'はんざいしゃ',
#   'だとう',
#   'いう',
#   'じかく',
#   'を',
#   'おねがい',
#   'し',
#   'ます',
#   'E'],
#  ['かきょう', 'の', 'いちいん', 'として', 'にっぽんこく', 'を', 'しきり', 'ます', 'E'],
#  ['あべそうり',
#   'けんぽう',
#   'で',
#   'じえいたい',
#   'の',
#   'たちいち',
#   'はっきり',
#   'さ',
#   'せよ',
#   'う',
#   'ぜ',
#   'ますごみ',
#   'けんりょく',
#   'の',
#   'しぶつか',
#   'あべ',
#   'どくさい',
#   'れんほう',
#   'こくせきほう',
#   'いはん',
#   'ほうりつ',
#   'が',
#   'じだい',
#   'に',
#   'あっ',
#   'て',
#   'ない',
#   'かえる',
#   'べき',
#   'ますごみ',
#   'れんほう',
#   'さん',
#   'の',
#   'こくせき',
#   'を',
#   'どうこう',
#   'いう',
#   'の',
#   'は',
#   'さべつ',
#   'E'],
#  ['さんけい',
#   'も',
#   'もうちょい',
#   'まとも',
#   'な',
#   'しつもん',
#   'しろ',
#   'よ',
#   'ほう',
#   'に',
#   'はんし',
#   'てる',
#   'こと',
#   'にたいして',
#   'の',
#   'せきにん',
#   'を',
#   'ついきゅう',
#   'する',
#   'とか',
#   'あっ',
#   'た',
#   'だろ',
#   'ねっと',
#   'に',
#   'げいごう',
#   'し',
#   'て',
#   'かす',
#   'みたい',
#   'な',
#   'しつもん',
#   'する',
#   'な',
#   'よ',
#   'E'],
#  ['ほうりつ',
#   'が',
#   'あっ',
#   'て',
#   'ない',
#   'の',
#   'は',
#   'おまえ',
#   'だけ',
#   'おまえ',
#   'の',
#   'つごう',
#   'が',
#   'わるく',
#   'なる',
#   'たび',
#   'に',
#   'ほうりつ',
#   'かえる',
#   'ん',
#   'か',
#   'あほ',
#   'こうしょくせんきょほういはん',
#   'の',
#   'がい',
#   'じん',
#   'だろ',
#   'う',
#   'が',
#   'ほう',
#   'を',
#   'かえる',
#   'いぜん',
#   'の',
#   'もんだい',
#   'だろ',
#   'う',
#   'が',
#   'とっとと',
#   'たいほ',
#   'しろ',
#   'や',
#   'ぼけ',
#   'E'],
#  ['はんざいしゃ',
#   'に',
#   'やさしい',
#   'むほう',
#   'な',
#   'くに',
#   'に',
#   'し',
#   'ます',
#   'って',
#   'にっぽんじん',
#   'の',
#   'てき',
#   'だ',
#   'と',
#   'しか',
#   'おもえ',
#   'ない',
#   'に',
#   'は',
#   'なに',
#   'の',
#   'しかく',
#   'も',
#   'ない',
#   'さっさと',
#   'きえ',
#   'て',
#   'しまえ',
#   'E'],
#  ['こうさくいん', 'ただし', 'むのう', 'E'],
#  ['つまり', 'にじゅうすぱい', 'E'],
#  ['すべて', 'は', 'の', 'にんめいせきにん', 'だ', 'と', 'かくしん', 'し', 'た', 'E'],
#  ['かじん', 'じゃなくて', 'かきょう', 'です', 'かぁ', 'あうと', 'です', 'なぁ', 'E'],
#  ['もう',
#   'はんざいしゃ',
#   'はんざいしゃ',
#   'が',
#   'せいじか',
#   'の',
#   'くに',
#   'が',
#   'あっ',
#   'た',
#   'ね',
#   'すぐ',
#   'そこ',
#   'に',
#   'E'],
#  ['の', 'ぺっと', 'はやく', 'あいつ', 'を', 'にっぽん', 'から', 'ついほう', 'し', 'て', 'E'],
#  ['これ',
#   'まじで',
#   'だい',
#   'もんだい',
#   'だ',
#   'と',
#   'おもう',
#   'ん',
#   'だ',
#   'けど',
#   'れんじつ',
#   'で',
#   'とりあげ',
#   'られ',
#   'なきゃ',
#   'おかしい',
#   'あした',
#   'いこう',
#   'ちょっと',
#   'さわる',
#   'だけ',
#   'ていど',
#   'で',
#   'おわっ',
#   'たら',
#   'まちがい',
#   'なく',
#   'そんたく',
#   'E'],
#  ['むのう', 'E'],
#  ['こいつ',
#   'はんざいしゃ',
#   'やん',
#   'さべつ',
#   'が',
#   'どう',
#   'とかいう',
#   'はなし',
#   'じゃ',
#   'ぜんく',
#   'ない',
#   'で',
#   'E'],
#  ['すぱい', 'は', 'E'],
#  ['ぱよく', 'は', 'くに', 'に', 'かえれ', 'E'],
#  ['れんほう',
#   'さん',
#   'が',
#   'ちょくせつ',
#   'きじ',
#   'を',
#   'かい',
#   'た',
#   'わけ',
#   'で',
#   'は',
#   'ない',
#   'でしょ',
#   'う',
#   'にだ',
#   'きしゃ',
#   'の',
#   'おくそく',
#   'や',
#   'きき',
#   'まちがい',
#   'で',
#   'かき',
#   'しそんじ',
#   'た',
#   'かのうせい',
#   'が',
#   'ないと',
#   'は',
#   'いえ',
#   'ない',
#   'から',
#   'これ',
#   'が',
#   'あうと',
#   'だ',
#   'と',
#   'おもう',
#   'れんちゅう',
#   'の',
#   'あたま',
#   'が',
#   'しんぱい',
#   'E'],
#  ['へんこう',
#   'ますめでぃあ',
#   'の',
#   'すべて',
#   'が',
#   'こうさくいん',
#   'なかま',
#   'だ',
#   'から',
#   'もう',
#   'てっていてき',
#   'に',
#   'ようご',
#   'し',
#   'まくっ',
#   'てる',
#   'わけ',
#   'で',
#   'E'],
#  ['がいかんゆうちざい',
#   'で',
#   'しけい',
#   'に',
#   'なっ',
#   'て',
#   'もらわ',
#   'なけれ',
#   'ば',
#   'なり',
#   'ませ',
#   'ん',
#   'きねん',
#   'す',
#   'べき',
#   'しけい',
#   'だい',
#   'いち',
#   'ごう',
#   'は',
#   'かも',
#   'しれ',
#   'ませ',
#   'ん',
#   'ね',
#   'にばん',
#   'じゃ',
#   'だめ',
#   'な',
#   'ん',
#   'です',
#   'よ',
#   'E'],
#  ['ますこみ',
#   'の',
#   'へんこうほうどう',
#   'こく',
#   'すぎ',
#   'ますこみ',
#   'が',
#   'すぱい',
#   'じゃ',
#   'ない',
#   'の',
#   'E'],
#  ['だぶる',
#   'すぱい',
#   'ろけん',
#   'で',
#   'そうほう',
#   'から',
#   'しんよう',
#   'を',
#   'うしなっ',
#   'た',
#   'もう',
#   'ちきゅう',
#   'じょう',
#   'で',
#   'いき',
#   'て',
#   'いけ',
#   'ない',
#   'な',
#   'E'],
#  ['こうじん',
#   'が',
#   'かきょう',
#   'て',
#   'どんどん',
#   'ねんりょう',
#   'とうか',
#   'しとる',
#   'やん',
#   'け',
#   'ぎいんしかく',
#   'はくだつ',
#   'たいほ',
#   'さ',
#   'れる',
#   'の',
#   'か',
#   'どこ',
#   'に',
#   'つうほう',
#   'すれ',
#   'ば',
#   'いい',
#   'E'],
#  ['みえ', 'こくせき', 'じゃ', 'ない', 'の', 'E'],
#  ['かきょう', 'E'],
#  ['たにけい', 'かきょ', 'ん', 'E'],
#  ['です', 'E'],
#  ['ねっとうよく',
#   'は',
#   'たいわん',
#   'が',
#   'ちゅうごく',
#   'だ',
#   'と',
#   'おもっ',
#   'て',
#   'いる',
#   'の',
#   'か',
#   'やっぱり',
#   'あたま',
#   'わるい',
#   'な',
#   'E'],
#  ['むかし',
#   'みんしゅとう',
#   'の',
#   'こがじゅんいちろう',
#   'は',
#   'だして',
#   'も',
#   'い',
#   'ない',
#   'あめりか',
#   'の',
#   'だいがく',
#   'を',
#   'そつぎょう',
#   'と',
#   'しるし',
#   'て',
#   'い',
#   'て',
#   'がくれきさしょう',
#   'で',
#   'ぎいんじしょく',
#   'に',
#   'おいこま',
#   'れ',
#   'た',
#   'E'],
#  ['れんほう',
#   'さん',
#   'の',
#   'いっけん',
#   'で',
#   'すぱいぼうしほう',
#   'の',
#   'じゅうようせい',
#   'が',
#   'にんしき',
#   'さ',
#   'れ',
#   'た',
#   'という',
#   'こと',
#   'でしょ',
#   'う',
#   'か',
#   'つぎ',
#   'の',
#   'こっかい',
#   'で',
#   'は',
#   'ぜったい',
#   'に',
#   'せいりつ',
#   'し',
#   'て',
#   'ほしい',
#   'です',
#   'E'],
#  ['へんこう',
#   'ほうそうきょく',
#   'で',
#   'を',
#   'ながし',
#   'て',
#   'いる',
#   'すべて',
#   'の',
#   'きぎょう',
#   'に',
#   'しゃかいてきせきにん',
#   'および',
#   'に',
#   'ろく',
#   'ぜろ',
#   'ぜろ',
#   'ぜろ',
#   'について',
#   'といあわせ',
#   'じどうしゃ',
#   'しょくひん',
#   'いんりょう',
#   'かし',
#   'にちようひん',
#   'けしょうひん',
#   'びよう',
#   'せいけい',
#   'いやくひん',
#   'いりょうきき',
#   'けんこうきぐ',
#   'ほけん',
#   'つうしん',
#   'でんき',
#   'じゅうたく',
#   'ふどうさん',
#   'けんせつ',
#   'ぎんこう',
#   'しょうけん',
#   'でんりょく',
#   'がす',
#   'りょこう',
#   'こうくう',
#   'てつどう',
#   'えとせとら',
#   'へんこうほうどう',
#   'せいじてき',
#   'こうへい',
#   'ほうそうほう',
#   'よん',
#   'じょう',
#   'ほうりつ',
#   'いはん',
#   'いほうこうい',
#   'こうこくしゅっこう',
#   'ほうそう',
#   'しきんていきょう',
#   'いほうこうい',
#   'へ',
#   'の',
#   'かたん',
#   'ほうれいじゅんしゅ',
#   'きぎょうのしゃかいてきせきにん',
#   'に',
#   'ろく',
#   'ぜろ',
#   'ぜろ',
#   'ぜろ',
#   'かぶぬし',
#   'かぶか',
#   'めさき',
#   'の',
#   'りえき',
#   'ちょうき',
#   'てき',
#   'な',
#   'しんよう',
#   'こうこくだいりてん',
#   'の',
#   'せきにん',
#   'きぎょうめい',
#   'お',
#   'といあわせ',
#   'けんさく',
#   'お',
#   'といあわせ',
#   'そうしん',
#   'てる',
#   'きぎょう',
#   'あかうんと',
#   'りぷらい',
#   'しつもん',
#   'E'],
#  ['かきょう', 'なら', 'なおさら', 'で', 'て', 'っ', 'て', 'ください', 'E'],
#  ['でも',
#   'きちんと',
#   'しゃざい',
#   'し',
#   'てる',
#   'ん',
#   'だ',
#   'から',
#   'ゆるす',
#   'べき',
#   'でしょ',
#   'べつに',
#   'れんほう',
#   'さん',
#   'が',
#   'にじゅうこくせき',
#   'だっ',
#   'た',
#   'こと',
#   'で',
#   'じつがい',
#   'が',
#   'あっ',
#   'た',
#   'わけ',
#   'で',
#   'も',
#   'ある',
#   'まい',
#   'し',
#   'それどころか',
#   'れんほう',
#   'さん',
#   'は',
#   'いま',
#   'まで',
#   'じぎょうしわけ',
#   'など',
#   'で',
#   'かつやく',
#   'し',
#   'て',
#   'にっぽん',
#   'の',
#   'こくえき',
#   'に',
#   'こうけん',
#   'し',
#   'て',
#   'き',
#   'た',
#   'じゃん',
#   'にじゅうこくせき',
#   'くらい',
#   'で',
#   'じにん',
#   'しろ',
#   'とか',
#   'いっ',
#   'てる',
#   'ひと',
#   'は',
#   'さすが',
#   'に',
#   'あたま',
#   'が',
#   'おかしい',
#   'と',
#   'おもう',
#   'E'],
#  ['だいじん',
#   'の',
#   'とき',
#   'に',
#   'にじゅうこくせき',
#   'だっ',
#   'た',
#   'わけ',
#   'ね',
#   'はい',
#   'ぎいんじしょく',
#   'かくてい',
#   'E'],
#  ['どう',
#   'み',
#   'て',
#   'も',
#   'こうさくいん',
#   'こども',
#   'の',
#   'こと',
#   'を',
#   'かんがえる',
#   'なら',
#   'しろぬり',
#   'こせき',
#   'の',
#   'ていしゅつ',
#   'を',
#   'おしむ',
#   'より',
#   'ぎわく',
#   'を',
#   'はらす',
#   'の',
#   'が',
#   'とうぜん',
#   'こども',
#   'を',
#   'たて',
#   'に',
#   'する',
#   'おや',
#   'の',
#   'くず',
#   'E'],
#  ['かきょう',
#   'って',
#   'とうなんあじあ',
#   'で',
#   'げんち',
#   'じん',
#   'さくしゅ',
#   'し',
#   'て',
#   'もうけ',
#   'て',
#   'ちゅうごく',
#   'より',
#   'に',
#   'し',
#   'てる',
#   'しゅうだん',
#   'じゃん',
#   'ゆうこう',
#   'とか',
#   'いっ',
#   'て',
#   'さいご',
#   'は',
#   'にっぽん',
#   'を',
#   'のっとる',
#   'つもり',
#   'の',
#   'れんちゅう',
#   'だ',
#   'E'],
#  ['せいじか',
#   'の',
#   'ことば',
#   'は',
#   'かるい',
#   'むかし',
#   'は',
#   'おもいっ',
#   'て',
#   'いっ',
#   'て',
#   'た',
#   'のに',
#   'E'],
#  ['にっぽん',
#   'の',
#   'ますこみ',
#   'が',
#   'まとも',
#   'に',
#   'きのう',
#   'し',
#   'て',
#   'い',
#   'たら',
#   'れんほう',
#   'は',
#   'いま',
#   'ごろ',
#   'ぎいんじしょく',
#   'に',
#   'おいこま',
#   'れ',
#   'て',
#   'いる',
#   'E'],
#  ['あ', 'ぱか', 'はっけん', 'たいわん', 'を', 'しな', 'と', 'おもいこん', 'でる', 'ぱか', 'はっけん', 'E'],
#  ['あいでぃ', 'E'],
#  ['ねつぞう',
#   'し',
#   'て',
#   'まで',
#   'あべばっしんぐ',
#   'に',
#   'あけくれ',
#   'て',
#   'いる',
#   'はんにち',
#   'ますごみ',
#   'は',
#   'ばいこく',
#   'ぎいん',
#   'の',
#   'あくじ',
#   'や',
#   'くに',
#   'うり',
#   'こうい',
#   'に',
#   'は',
#   'ことごとく',
#   'か',
#   'ようご',
#   'な',
#   'ん',
#   'だ',
#   'よ',
#   'な',
#   'E'],
#  ['ひるおび',
#   'の',
#   'いとう',
#   'あつお',
#   'が',
#   'あべ',
#   'にたいして',
#   'いっ',
#   'て',
#   'い',
#   'た',
#   'けれど',
#   'いんしょう',
#   'と',
#   'いっぱんじょうしき',
#   'から',
#   'し',
#   'て',
#   'おかしけれ',
#   'ば',
#   'あく',
#   'な',
#   'ん',
#   'です',
#   'よ',
#   'ね',
#   'れんほう',
#   'は',
#   'いっぱんじょうしき',
#   'から',
#   'いっ',
#   'て',
#   'おかしい',
#   'ので',
#   'あく',
#   'です',
#   'いんしょう',
#   'は',
#   'まっくろ',
#   'けいれきさしょう',
#   'で',
#   'せんきょ',
#   'に',
#   'だして',
#   'ゆうけんしゃ',
#   'を',
#   'だまし',
#   'た',
#   'という',
#   'じじつ',
#   'が',
#   'ある',
#   'あく',
#   'E'],
#  ['こいつ', 'は', 'がいかんゆうちざい', 'で', 'いい', 'よ', 'E'],
#  ['それ',
#   'は',
#   'こっかいぎいん',
#   'で',
#   'なく',
#   'て',
#   'も',
#   'できる',
#   'はず',
#   'いま',
#   'まで',
#   'にじゅうこくせき',
#   'みえ',
#   'な',
#   'の',
#   'を',
#   'いい',
#   'こと',
#   'に',
#   'きみつじょうほう',
#   'りゅう',
#   'を',
#   'し',
#   'て',
#   'い',
#   'た',
#   'の',
#   'で',
#   'は',
#   'どう',
#   'かんがえ',
#   'て',
#   'も',
#   'あんぜんほしょう',
#   'じょう',
#   'まず',
#   'いよ',
#   'ね',
#   'E'],
#  ['だれ',
#   'もん',
#   'な',
#   'こと',
#   'おもっ',
#   'て',
#   'ない',
#   'のに',
#   'やっぱり',
#   'おまえ',
#   'とう',
#   'わるい',
#   'な',
#   'E'],
#  ['で',
#   'どう',
#   'しょばつ',
#   'すん',
#   'の',
#   'このまま',
#   'ぎいん',
#   'じゃ',
#   'しゃかい',
#   'にたいする',
#   'ぎゃくさべつ',
#   'でしょ',
#   'E'],
#  ['れんほう',
#   'さん',
#   'は',
#   'いぜん',
#   'たいわん',
#   'は',
#   'こっか',
#   'で',
#   'は',
#   'ない',
#   'と',
#   'はつげん',
#   'し',
#   'て',
#   'たいわん',
#   'から',
#   'おこら',
#   'れ',
#   'て',
#   'い',
#   'まし',
#   'た',
#   'けど',
#   'ね',
#   'E'],
#  ['ゆるさ',
#   'ない',
#   'そもそも',
#   'れんほう',
#   'は',
#   'じぎょうしわけ',
#   'で',
#   'にっぽん',
#   'を',
#   'ずたずた',
#   'に',
#   'した',
#   'だろ',
#   'へいき',
#   'で',
#   'うそ',
#   'を',
#   'はく',
#   'おまえ',
#   'が',
#   'いくら',
#   'ようご',
#   'し',
#   'た',
#   'ところ',
#   'で',
#   'むいみ',
#   'だ',
#   'おまえ',
#   'みたい',
#   'な',
#   'きちがい',
#   'に',
#   'たにん',
#   'を',
#   'あたま',
#   'おかしい',
#   'よばわり',
#   'する',
#   'けんり',
#   'など',
#   'ない',
#   'みのほど',
#   'を',
#   'わきまえろ',
#   'がいちゅう',
#   'E'],
#  ['かじん',
#   'ちゅうごくせき',
#   'で',
#   'は',
#   'ない',
#   'ざいがい',
#   'ちゅうごくけい',
#   'かきょう',
#   'ちゅうごくせき',
#   'を',
#   'ゆうする',
#   'ざいがいちゅうごくじん',
#   'はい',
#   'ここ',
#   'だいじ',
#   'です',
#   'よ',
#   'てすと',
#   'に',
#   'で',
#   'ます',
#   'から',
#   'ちなみに',
#   'れんほう',
#   'は',
#   'こうしゃ',
#   'です',
#   'から',
#   'ながねん',
#   'にわたり',
#   'ちゅうごくしゃかい',
#   'と',
#   'せってん',
#   'が',
#   'あっ',
#   'て',
#   'しら',
#   'ない',
#   'はず',
#   'は',
#   'ありません',
#   'から',
#   'E'],
#  ['あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'あか',
#   'しな',
#   'すぱい',
#   'に',
#   'やさしい',
#   'くに',
#   'それ',
#   'が',
#   'にっぽん',
#   'E'],
#  ['ちゅうごく',
#   'おおやけ',
#   'せん',
#   'が',
#   'あちこち',
#   'で',
#   'にっぽん',
#   'かいいき',
#   'で',
#   'しんにゅう',
#   'し',
#   'て',
#   'いる',
#   'が',
#   'めでぃあ',
#   'は',
#   'おおく',
#   'は',
#   'とりあげ',
#   'ない',
#   'なぜ',
#   'いま',
#   'この',
#   'よう',
#   'な',
#   'こうどう',
#   'を',
#   'とる',
#   'の',
#   'か',
#   'それ',
#   'は',
#   'いま',
#   'ますめでぃあ',
#   'が',
#   'ひっし',
#   'に',
#   'なっ',
#   'て',
#   'あべせいけん',
#   'はたき',
#   'を',
#   'やっ',
#   'て',
#   'もくてき',
#   'どおり',
#   'あべせいけん',
#   'しじ',
#   'りつ',
#   'を',
#   'さげ',
#   'て',
#   'にっぽんのせいじ',
#   'こんらん',
#   'を',
#   'まねい',
#   'て',
#   'いる',
#   'ところ',
#   'を',
#   'ちゅうごく',
#   'は',
#   'いろいろ',
#   'な',
#   'ちょうさ',
#   'かつどう',
#   'を',
#   'やっ',
#   'て',
#   'いる',
#   'これ',
#   'いじょう',
#   'せいじ',
#   'こんらん',
#   'は',
#   'にっぽん',
#   'の',
#   'ため',
#   'に',
#   'も',
#   'このましく',
#   'ない',
#   'E'],
#  ['とうきょうしんぶん', 'の', 'ほう', 'です', 'か', 'E'],
#  ['べつに',
#   'れんほう',
#   'さん',
#   'が',
#   'にじゅうこくせき',
#   'だっ',
#   'た',
#   'こと',
#   'で',
#   'じつがい',
#   'が',
#   'あっ',
#   'た',
#   'わけ',
#   'で',
#   'も',
#   'ある',
#   'まい',
#   'し',
#   'それどころか',
#   'れんほう',
#   'さん',
#   'は',
#   'いま',
#   'まで',
#   'じぎょうしわけ',
#   'など',
#   'で',
#   'かつやく',
#   'し',
#   'て',
#   'にっぽん',
#   'の',
#   'こくえき',
#   'に',
#   'こうけん',
#   'し',
#   'て',
#   'き',
#   'た',
#   'じゃん',
#   'それ',
#   'が',
#   'じつがい',
#   'だ',
#   'よ',
#   'が',
#   'さすが',
#   'あたま',
#   'おかしい',
#   'は',
#   'しこう',
#   'が',
#   'ひと',
#   'の',
#   'それ',
#   'と',
#   'は',
#   'ちがう',
#   'E'],
#  ['かきょう',
#   'が',
#   'たじゅうこくせき',
#   'の',
#   'まま',
#   'かんぶ',
#   'や',
#   'だいひょう',
#   'を',
#   'し',
#   'て',
#   'い',
#   'た',
#   'とう',
#   'それ',
#   'が',
#   'みんしんとう',
#   'みんしゅとう',
#   'こっか',
#   'てき',
#   'きぼ',
#   'で',
#   'の',
#   'きょういてき',
#   'きょうい',
#   'てき',
#   'もんだい',
#   'だ',
#   'な',
#   'にっぽんこく',
#   'の',
#   'しゅけん',
#   'にっぽんこく',
#   'の',
#   'あんぜんほしょう',
#   'にっぽんこく',
#   'の',
#   'そんりつ',
#   'にっぽんじん',
#   'ぜんいん',
#   'の',
#   'せいめい',
#   'ざいさん',
#   'の',
#   'そんぞく',
#   'に',
#   'かかわる',
#   'だいきぼ',
#   'じけん',
#   'だ',
#   'か',
#   'の',
#   'みんしゅとうせいけん',
#   'じだい',
#   'だいきぼ',
#   'で',
#   'こうはん',
#   'な',
#   'はんざいこうい',
#   'が',
#   'じっこう',
#   'さ',
#   'れ',
#   'た',
#   'うたがい',
#   'が',
#   'さらに',
#   'げんじつみ',
#   'を',
#   'まし',
#   'た',
#   'おそろしい',
#   'じょうきょう',
#   'が',
#   'にちじょうてき',
#   'に',
#   'くりひろげ',
#   'られ',
#   'て',
#   'い',
#   'た',
#   'かのうせい',
#   'が',
#   'ある',
#   'それ',
#   'も',
#   'にっぽんじん',
#   'の',
#   'しら',
#   'ぬ',
#   'で',
#   'こくみん',
#   'よ',
#   'め',
#   'を',
#   'さませ',
#   'ぼうえいしき',
#   'を',
#   'もて',
#   'ぼうえい',
#   'を',
#   'とぎ',
#   'すませろ',
#   'そして',
#   'じっこう',
#   'せよ',
#   'かんぜん',
#   'なる',
#   'きょひ',
#   'を',
#   'E'],
#  ['あなた', 'が', 'おかしい', 'でしょ', 'E'],
#  ...]

# %%
'''
全単語の辞書とword2vec作成
'''

all_word = []
for s in all_data:
    all_word.extend(s)
    
# 全単語ベクトル
word_id_dict = {k:v for v,k in enumerate(list(set(all_word)))}
id_word_dict = {k:v for v,k in word_id_dict.items()}
word_num = len(word_id_dict)

with open("corpus.txt","w") as f:
    for i in all_word:
        f.write(i+" ")

# word2vec
from gensim.models import word2vec

sentences = word2vec.Text8Corpus('corpus.txt')

word_model = word2vec.Word2Vec(sentences,
                          sg=1,
                          size=200,
                          min_count=1,
                          window=10,
                          hs=1,
                          negative=0)

# %%
# sentenceごと，trigramのx_dataと次の単語のy_data生成

x_data = []
y_data = []
for s in all_data:
    s_len = len(s)
    if s_len < 4:
        continue
    trigram = []
    next_word = []
    for i in range(s_len - 3):
        trigram.append(s[i:i+3])
        next_word.append(word_id_dict[s[i+3]])
    print(s)
    print(trigram)
    x_data.extend([[word_model[y] for y in x] for x in trigram])
    y_data.extend(next_word)
x_data = np.array(x_data)
y_data = np.array(y_data)
# Out:
# ['とうとう', 'みんしん', 'は', 'たてまえ', 'さえ', 'も', 'ほうかい', 'し', 'た', 'の', 'か', 'じぶん', 'の', 'かんがえ', 'に', 'じしん', 'が', 'もて', 'ない', 'とう', 'に', 'めいしょう', 'かえろ', 'よ', 'E']
# [['とうとう', 'みんしん', 'は'], ['みんしん', 'は', 'たてまえ'], ['は', 'たてまえ', 'さえ'], ['たてまえ', 'さえ', 'も'], ['さえ', 'も', 'ほうかい'], ['も', 'ほうかい', 'し'], ['ほうかい', 'し', 'た'], ['し', 'た', 'の'], ['た', 'の', 'か'], ['の', 'か', 'じぶん'], ['か', 'じぶん', 'の'], ['じぶん', 'の', 'かんがえ'], ['の', 'かんがえ', 'に'], ['かんがえ', 'に', 'じしん'], ['に', 'じしん', 'が'], ['じしん', 'が', 'もて'], ['が', 'もて', 'ない'], ['もて', 'ない', 'とう'], ['ない', 'とう', 'に'], ['とう', 'に', 'めいしょう'], ['に', 'めいしょう', 'かえろ'], ['めいしょう', 'かえろ', 'よ']]
# ['じえいたい', 'ぐんたい', 'みとめ', 'て', 'よい', 'はやく', 'みとめよ', 'う', 'E']
# [['じえいたい', 'ぐんたい', 'みとめ'], ['ぐんたい', 'みとめ', 'て'], ['みとめ', 'て', 'よい'], ['て', 'よい', 'はやく'], ['よい', 'はやく', 'みとめよ'], ['はやく', 'みとめよ', 'う']]
# ['がいじん', 'なんて', 'もの', 'が', 'そんざい', 'する', 'みん', 'しんとう', 'が', 'あんぜんほしょう', 'かたっ', 'て', 'はずかしく', 'ない', 'の', 'か', 'よ', 'E']
# [['がいじん', 'なんて', 'もの'], ['なんて', 'もの', 'が'], ['もの', 'が', 'そんざい'], ['が', 'そんざい', 'する'], ['そんざい', 'する', 'みん'], ['する', 'みん', 'しんとう'], ['みん', 'しんとう', 'が'], ['しんとう', 'が', 'あんぜんほしょう'], ['が', 'あんぜんほしょう', 'かたっ'], ['あんぜんほしょう', 'かたっ', 'て'], ['かたっ', 'て', 'はずかしく'], ['て', 'はずかしく', 'ない'], ['はずかしく', 'ない', 'の'], ['ない', 'の', 'か'], ['の', 'か', 'よ']]
# ['まだ', 'みたい', 'な', 'こと', 'いっ', 'て', 'て', 'びっくり', 'だ', 'わ', 'E']
# [['まだ', 'みたい', 'な'], ['みたい', 'な', 'こと'], ['な', 'こと', 'いっ'], ['こと', 'いっ', 'て'], ['いっ', 'て', 'て'], ['て', 'て', 'びっくり'], ['て', 'びっくり', 'だ'], ['びっくり', 'だ', 'わ']]
# ['おんけんほしゅ', 'わろた', 'おまえ', 'ら', 'みんきょう', 'がったい', 'の', 'きょくさせいとう', 'だろ', 'う', 'が', 'みんきょう', 'がったい', 'で', 'とくあ', 'だ', 'E']
# [['おんけんほしゅ', 'わろた', 'おまえ'], ['わろた', 'おまえ', 'ら'], ['おまえ', 'ら', 'みんきょう'], ['ら', 'みんきょう', 'がったい'], ['みんきょう', 'がったい', 'の'], ['がったい', 'の', 'きょくさせいとう'], ['の', 'きょくさせいとう', 'だろ'], ['きょくさせいとう', 'だろ', 'う'], ['だろ', 'う', 'が'], ['う', 'が', 'みんきょう'], ['が', 'みんきょう', 'がったい'], ['みんきょう', 'がったい', 'で'], ['がったい', 'で', 'とくあ'], ['で', 'とくあ', 'だ']]
# ['いま', 'まで', 'みんしんとう', 'が', 'どういう', 'かぜ', 'に', 'しゅちょう', 'し', 'て', 'こっかい', 'を', 'くうてん', 'さ', 'せ', 'て', 'き', 'た', 'か', 'わすれ', 'た', 'の', 'ぶれ', 'てる', 'どころ', 'の', 'はなし', 'じゃ', 'ない', 'ばっち', 'を', 'つけ', 'たい', 'だけ', 'の', 'ぎいん', 'なんか', 'いら', 'ねぇ', 'E']
# [['いま', 'まで', 'みんしんとう'], ['まで', 'みんしんとう', 'が'], ['みんしんとう', 'が', 'どういう'], ['が', 'どういう', 'かぜ'], ['どういう', 'かぜ', 'に'], ['かぜ', 'に', 'しゅちょう'], ['に', 'しゅちょう', 'し'], ['しゅちょう', 'し', 'て'], ['し', 'て', 'こっかい'], ['て', 'こっかい', 'を'], ['こっかい', 'を', 'くうてん'], ['を', 'くうてん', 'さ'], ['くうてん', 'さ', 'せ'], ['さ', 'せ', 'て'], ['せ', 'て', 'き'], ['て', 'き', 'た'], ['き', 'た', 'か'], ['た', 'か', 'わすれ'], ['か', 'わすれ', 'た'], ['わすれ', 'た', 'の'], ['た', 'の', 'ぶれ'], ['の', 'ぶれ', 'てる'], ['ぶれ', 'てる', 'どころ'], ['てる', 'どころ', 'の'], ['どころ', 'の', 'はなし'], ['の', 'はなし', 'じゃ'], ['はなし', 'じゃ', 'ない'], ['じゃ', 'ない', 'ばっち'], ['ない', 'ばっち', 'を'], ['ばっち', 'を', 'つけ'], ['を', 'つけ', 'たい'], ['つけ', 'たい', 'だけ'], ['たい', 'だけ', 'の'], ['だけ', 'の', 'ぎいん'], ['の', 'ぎいん', 'なんか'], ['ぎいん', 'なんか', 'いら'], ['なんか', 'いら', 'ねぇ']]
# ['いま', 'の', 'しじしゃ', 'が', 'そんな', 'こと', 'のぞん', 'で', 'ん', 'の', 'あたらしい', 'しじしゃ', 'が', 'その', 'ほうほう', 'で', 'え', 'られる', 'と', 'おもっ', 'て', 'ん', 'の', 'E']
# [['いま', 'の', 'しじしゃ'], ['の', 'しじしゃ', 'が'], ['しじしゃ', 'が', 'そんな'], ['が', 'そんな', 'こと'], ['そんな', 'こと', 'のぞん'], ['こと', 'のぞん', 'で'], ['のぞん', 'で', 'ん'], ['で', 'ん', 'の'], ['ん', 'の', 'あたらしい'], ['の', 'あたらしい', 'しじしゃ'], ['あたらしい', 'しじしゃ', 'が'], ['しじしゃ', 'が', 'その'], ['が', 'その', 'ほうほう'], ['その', 'ほうほう', 'で'], ['ほうほう', 'で', 'え'], ['で', 'え', 'られる'], ['え', 'られる', 'と'], ['られる', 'と', 'おもっ'], ['と', 'おもっ', 'て'], ['おもっ', 'て', 'ん'], ['て', 'ん', 'の']]
# ['だっ', 'たら', 'まず', 'みんしんとう', 'から', 'ありたよしふ', 'を', 'はたき', 'ださ', 'ない', 'と', 'E']
# [['だっ', 'たら', 'まず'], ['たら', 'まず', 'みんしんとう'], ['まず', 'みんしんとう', 'から'], ['みんしんとう', 'から', 'ありたよしふ'], ['から', 'ありたよしふ', 'を'], ['ありたよしふ', 'を', 'はたき'], ['を', 'はたき', 'ださ'], ['はたき', 'ださ', 'ない'], ['ださ', 'ない', 'と']]
# ['とうない', 'まとめ', 'て', 'から', 'に', 'し', 'て', 'くん', 'ない', 'か', 'な', 'E']
# [['とうない', 'まとめ', 'て'], ['まとめ', 'て', 'から'], ['て', 'から', 'に'], ['から', 'に', 'し'], ['に', 'し', 'て'], ['し', 'て', 'くん'], ['て', 'くん', 'ない'], ['くん', 'ない', 'か'], ['ない', 'か', 'な']]
# ['さいしょ', 'から', 'です', 'やん', 'あさひ', 'は', 'なに', 'を', 'ゆう', 'て', 'ん', 'の', 'E']
# [['さいしょ', 'から', 'です'], ['から', 'です', 'やん'], ['です', 'やん', 'あさひ'], ['やん', 'あさひ', 'は'], ['あさひ', 'は', 'なに'], ['は', 'なに', 'を'], ['なに', 'を', 'ゆう'], ['を', 'ゆう', 'て'], ['ゆう', 'て', 'ん'], ['て', 'ん', 'の']]
# ['なにをいまさら', 'くん', 'ら', 'の', 'しゃぜ', 'です', 'やん', 'E']
# [['なにをいまさら', 'くん', 'ら'], ['くん', 'ら', 'の'], ['ら', 'の', 'しゃぜ'], ['の', 'しゃぜ', 'です'], ['しゃぜ', 'です', 'やん']]
# ['もはや', 'へんこう', 'を', 'かくし', 'も', 'し', 'なく', 'なっ', 'た', 'か', 'E']
# [['もはや', 'へんこう', 'を'], ['へんこう', 'を', 'かくし'], ['を', 'かくし', 'も'], ['かくし', 'も', 'し'], ['も', 'し', 'なく'], ['し', 'なく', 'なっ'], ['なく', 'なっ', 'た'], ['なっ', 'た', 'か']]
# ['いや', 'さいしょ', 'から', 'てっとうてつび', 'あべせいけん', 'ふしじ', 'を', 'どうどう', 'と', 'かかげ', 'て', 'ただ', 'ろ', 'E']
# [['いや', 'さいしょ', 'から'], ['さいしょ', 'から', 'てっとうてつび'], ['から', 'てっとうてつび', 'あべせいけん'], ['てっとうてつび', 'あべせいけん', 'ふしじ'], ['あべせいけん', 'ふしじ', 'を'], ['ふしじ', 'を', 'どうどう'], ['を', 'どうどう', 'と'], ['どうどう', 'と', 'かかげ'], ['と', 'かかげ', 'て'], ['かかげ', 'て', 'ただ'], ['て', 'ただ', 'ろ']]
# ['ふしじ', 'は', 'いい', 'が', 'だれ', 'を', 'しじ', 'する', 'ん', 'だ', 'E']
# [['ふしじ', 'は', 'いい'], ['は', 'いい', 'が'], ['いい', 'が', 'だれ'], ['が', 'だれ', 'を'], ['だれ', 'を', 'しじ'], ['を', 'しじ', 'する'], ['しじ', 'する', 'ん'], ['する', 'ん', 'だ']]
# ['じぶん', 'ら', 'の', 'おもい', 'どうり', 'が', 'せいぎ', 'ふるく', 'て', 'ふるく', 'て', 'E']
# [['じぶん', 'ら', 'の'], ['ら', 'の', 'おもい'], ['の', 'おもい', 'どうり'], ['おもい', 'どうり', 'が'], ['どうり', 'が', 'せいぎ'], ['が', 'せいぎ', 'ふるく'], ['せいぎ', 'ふるく', 'て'], ['ふるく', 'て', 'ふるく'], ['て', 'ふるく', 'て']]
# ['はあ', 'なにいってんだこいつ', 'まえ', 'から', 'ふしじ', 'ひょうめい', 'なんて', 'できる', 'だろ', 'E']
# [['はあ', 'なにいってんだこいつ', 'まえ'], ['なにいってんだこいつ', 'まえ', 'から'], ['まえ', 'から', 'ふしじ'], ['から', 'ふしじ', 'ひょうめい'], ['ふしじ', 'ひょうめい', 'なんて'], ['ひょうめい', 'なんて', 'できる'], ['なんて', 'できる', 'だろ']]
# ['いま', 'まで', 'ず', 'うう', 'う', 'うう', 'っと', 'いい', 'たい', 'ほうだい', 'し', 'てる', 'だろ', 'E']
# [['いま', 'まで', 'ず'], ['まで', 'ず', 'うう'], ['ず', 'うう', 'う'], ['うう', 'う', 'うう'], ['う', 'うう', 'っと'], ['うう', 'っと', 'いい'], ['っと', 'いい', 'たい'], ['いい', 'たい', 'ほうだい'], ['たい', 'ほうだい', 'し'], ['ほうだい', 'し', 'てる'], ['し', 'てる', 'だろ']]
# ['けんりょく', 'の', 'しぶつか', 'それ', 'は', 'あん', 'たら', 'ます', 'ごみ', 'じゃ', 'ね', 'E']
# [['けんりょく', 'の', 'しぶつか'], ['の', 'しぶつか', 'それ'], ['しぶつか', 'それ', 'は'], ['それ', 'は', 'あん'], ['は', 'あん', 'たら'], ['あん', 'たら', 'ます'], ['たら', 'ます', 'ごみ'], ['ます', 'ごみ', 'じゃ'], ['ごみ', 'じゃ', 'ね']]
# ['あさひ', 'は', 'しゅうしいっかん', 'あべ', 'ふ', 'しじ', 'だっ', 'た', 'だろ', 'なん', 'たっ', 'て', 'それ', 'が', 'しゃぜ', 'な', 'ん', 'だ', 'から', 'E']
# [['あさひ', 'は', 'しゅうしいっかん'], ['は', 'しゅうしいっかん', 'あべ'], ['しゅうしいっかん', 'あべ', 'ふ'], ['あべ', 'ふ', 'しじ'], ['ふ', 'しじ', 'だっ'], ['しじ', 'だっ', 'た'], ['だっ', 'た', 'だろ'], ['た', 'だろ', 'なん'], ['だろ', 'なん', 'たっ'], ['なん', 'たっ', 'て'], ['たっ', 'て', 'それ'], ['て', 'それ', 'が'], ['それ', 'が', 'しゃぜ'], ['が', 'しゃぜ', 'な'], ['しゃぜ', 'な', 'ん'], ['な', 'ん', 'だ'], ['ん', 'だ', 'から']]
# ['に', 'の', 'と', 'おなじ', 'こと', 'いっ', 'てる', 'E']
# [['に', 'の', 'と'], ['の', 'と', 'おなじ'], ['と', 'おなじ', 'こと'], ['おなじ', 'こと', 'いっ'], ['こと', 'いっ', 'てる']]
# ['ようやく', 'じゃ', 'ない', 'だろ', 'あさひしんぶん', 'が', 'そんざい', 'する', 'こと', 'が', 'ふけんぜん', 'で', 'は', 'E']
# [['ようやく', 'じゃ', 'ない'], ['じゃ', 'ない', 'だろ'], ['ない', 'だろ', 'あさひしんぶん'], ['だろ', 'あさひしんぶん', 'が'], ['あさひしんぶん', 'が', 'そんざい'], ['が', 'そんざい', 'する'], ['そんざい', 'する', 'こと'], ['する', 'こと', 'が'], ['こと', 'が', 'ふけんぜん'], ['が', 'ふけんぜん', 'で'], ['ふけんぜん', 'で', 'は']]
# ['あさひしんぶん', 'ふしじ', 'を', 'どうどう', 'と', 'ひょうめい', 'できる', 'けんぜん', 'な', 'にほんしゃかい', 'です', 'が', 'なに', 'か', 'E']
# [['あさひしんぶん', 'ふしじ', 'を'], ['ふしじ', 'を', 'どうどう'], ['を', 'どうどう', 'と'], ['どうどう', 'と', 'ひょうめい'], ['と', 'ひょうめい', 'できる'], ['ひょうめい', 'できる', 'けんぜん'], ['できる', 'けんぜん', 'な'], ['けんぜん', 'な', 'にほんしゃかい'], ['な', 'にほんしゃかい', 'です'], ['にほんしゃかい', 'です', 'が'], ['です', 'が', 'なに'], ['が', 'なに', 'か']]
# ['まいにち', 'いっ', 'て', 'ます', 'やん', 'のうない', 'とうそう', 'せってい', 'きも', 'すぎ', 'E']
# [['まいにち', 'いっ', 'て'], ['いっ', 'て', 'ます'], ['て', 'ます', 'やん'], ['ます', 'やん', 'のうない'], ['やん', 'のうない', 'とうそう'], ['のうない', 'とうそう', 'せってい'], ['とうそう', 'せってい', 'きも'], ['せってい', 'きも', 'すぎ']]
# ['ちょんもめん', 'と', 'しこう', 'ろじっく', 'が', 'まったく', 'おなじ', 'な', 'ん', 'だ', 'な', 'E']
# [['ちょんもめん', 'と', 'しこう'], ['と', 'しこう', 'ろじっく'], ['しこう', 'ろじっく', 'が'], ['ろじっく', 'が', 'まったく'], ['が', 'まったく', 'おなじ'], ['まったく', 'おなじ', 'な'], ['おなじ', 'な', 'ん'], ['な', 'ん', 'だ'], ['ん', 'だ', 'な']]
# ['いや', 'ちゅうりつ', 'を', 'よそおわ', 'ず', 'かくさ', 'ず', 'に', 'どうどう', 'と', 'ひょうめい', 'し', 'て', 'から', 'やれ', 'や', 'E']
# [['いや', 'ちゅうりつ', 'を'], ['ちゅうりつ', 'を', 'よそおわ'], ['を', 'よそおわ', 'ず'], ['よそおわ', 'ず', 'かくさ'], ['ず', 'かくさ', 'ず'], ['かくさ', 'ず', 'に'], ['ず', 'に', 'どうどう'], ['に', 'どうどう', 'と'], ['どうどう', 'と', 'ひょうめい'], ['と', 'ひょうめい', 'し'], ['ひょうめい', 'し', 'て'], ['し', 'て', 'から'], ['て', 'から', 'やれ'], ['から', 'やれ', 'や']]
# ['あかひしんぶん', 'なんか', 'もともと', 'しじ', 'すら', 'さ', 'れ', 'て', 'ない', 'もん', 'な', 'E']
# [['あかひしんぶん', 'なんか', 'もともと'], ['なんか', 'もともと', 'しじ'], ['もともと', 'しじ', 'すら'], ['しじ', 'すら', 'さ'], ['すら', 'さ', 'れ'], ['さ', 'れ', 'て'], ['れ', 'て', 'ない'], ['て', 'ない', 'もん'], ['ない', 'もん', 'な']]
# ['ばか', 'だ', 'な', 'こんな', 'こと', 'かか', 'なきゃ', 'いい', 'のに', 'E']
# [['ばか', 'だ', 'な'], ['だ', 'な', 'こんな'], ['な', 'こんな', 'こと'], ['こんな', 'こと', 'かか'], ['こと', 'かか', 'なきゃ'], ['かか', 'なきゃ', 'いい'], ['なきゃ', 'いい', 'のに']]
# ['あさひ', 'の', 'きしゃ', 'の', 'この', 'ようち', 'さ', 'そりゃ', 'とうだいせい', 'が', 'くん', 'わけ', 'だ', 'わ', 'E']
# [['あさひ', 'の', 'きしゃ'], ['の', 'きしゃ', 'の'], ['きしゃ', 'の', 'この'], ['の', 'この', 'ようち'], ['この', 'ようち', 'さ'], ['ようち', 'さ', 'そりゃ'], ['さ', 'そりゃ', 'とうだいせい'], ['そりゃ', 'とうだいせい', 'が'], ['とうだいせい', 'が', 'くん'], ['が', 'くん', 'わけ'], ['くん', 'わけ', 'だ'], ['わけ', 'だ', 'わ']]
# ['あさひ', 'の', 'きしゃ', 'って', 'こんな', 'の', 'しか', 'い', 'ない', 'の', 'か', 'E']
# [['あさひ', 'の', 'きしゃ'], ['の', 'きしゃ', 'って'], ['きしゃ', 'って', 'こんな'], ['って', 'こんな', 'の'], ['こんな', 'の', 'しか'], ['の', 'しか', 'い'], ['しか', 'い', 'ない'], ['い', 'ない', 'の'], ['ない', 'の', 'か']]
# ['また', 'やん', 'の', 'か', 'よ', 'E']
# [['また', 'やん', 'の'], ['やん', 'の', 'か'], ['の', 'か', 'よ']]
# ['および', 'で', 'ない', 'ひと', 'が', 'で', 'て', 'き', 'ちゃっ', 'た', 'よ', 'E']
# [['および', 'で', 'ない'], ['で', 'ない', 'ひと'], ['ない', 'ひと', 'が'], ['ひと', 'が', 'で'], ['が', 'で', 'て'], ['で', 'て', 'き'], ['て', 'き', 'ちゃっ'], ['き', 'ちゃっ', 'た'], ['ちゃっ', 'た', 'よ']]
# ['こいつ', 'は', 'せいきょく', 'しか', 'かんがえ', 'て', 'な', 'E']
# [['こいつ', 'は', 'せいきょく'], ['は', 'せいきょく', 'しか'], ['せいきょく', 'しか', 'かんがえ'], ['しか', 'かんがえ', 'て'], ['かんがえ', 'て', 'な']]
# ['おまえ', 'それ', 'まえ', 'に', 'も', 'やっ', 'たろ', 'やっ', 'て', 'いま', 'どう', 'なっ', 'てる', 'の', 'E']
# [['おまえ', 'それ', 'まえ'], ['それ', 'まえ', 'に'], ['まえ', 'に', 'も'], ['に', 'も', 'やっ'], ['も', 'やっ', 'たろ'], ['やっ', 'たろ', 'やっ'], ['たろ', 'やっ', 'て'], ['やっ', 'て', 'いま'], ['て', 'いま', 'どう'], ['いま', 'どう', 'なっ'], ['どう', 'なっ', 'てる'], ['なっ', 'てる', 'の']]
# ['ま', 'た', 'おなじ', 'こと', 'いっ', 'てる', 'E']
# [['ま', 'た', 'おなじ'], ['た', 'おなじ', 'こと'], ['おなじ', 'こと', 'いっ'], ['こと', 'いっ', 'てる']]
# ['おまえ', 'じゃ', 'むり', 'だ', 'E']
# [['おまえ', 'じゃ', 'むり'], ['じゃ', 'むり', 'だ']]
# ['なんかい', 'め', 'だ', 'E']
# [['なんかい', 'め', 'だ']]
# ['ほら', 'また', 'かつ', 'こと', 'が', 'じこ', 'もくてき', 'か', 'し', 'てる', 'うそっぱち', 'で', 'も', 'まにふぇすと', 'だして', 'た', 'みんしゅ', 'じだい', 'より', 'も', 'たいか', 'し', 'てん', 'な', 'E']
# [['ほら', 'また', 'かつ'], ['また', 'かつ', 'こと'], ['かつ', 'こと', 'が'], ['こと', 'が', 'じこ'], ['が', 'じこ', 'もくてき'], ['じこ', 'もくてき', 'か'], ['もくてき', 'か', 'し'], ['か', 'し', 'てる'], ['し', 'てる', 'うそっぱち'], ['てる', 'うそっぱち', 'で'], ['うそっぱち', 'で', 'も'], ['で', 'も', 'まにふぇすと'], ['も', 'まにふぇすと', 'だして'], ['まにふぇすと', 'だして', 'た'], ['だして', 'た', 'みんしゅ'], ['た', 'みんしゅ', 'じだい'], ['みんしゅ', 'じだい', 'より'], ['じだい', 'より', 'も'], ['より', 'も', 'たいか'], ['も', 'たいか', 'し'], ['たいか', 'し', 'てん'], ['し', 'てん', 'な']]
# ['やとう', 'が', 'いっぽん', 'か', 'する', 'わけ', 'だろ', 'ばか', 'じゃ', 'の', 'E']
# [['やとう', 'が', 'いっぽん'], ['が', 'いっぽん', 'か'], ['いっぽん', 'か', 'する'], ['か', 'する', 'わけ'], ['する', 'わけ', 'だろ'], ['わけ', 'だろ', 'ばか'], ['だろ', 'ばか', 'じゃ'], ['ばか', 'じゃ', 'の']]
# ['これだけ', 'にっぽん', 'が', 'すいたい', 'し', 'た', 'のに', 'まだ', 'あほ', 'みたい', 'な', 'こと', 'やり', 'たい', 'の', 'か', 'E']
# [['これだけ', 'にっぽん', 'が'], ['にっぽん', 'が', 'すいたい'], ['が', 'すいたい', 'し'], ['すいたい', 'し', 'た'], ['し', 'た', 'のに'], ['た', 'のに', 'まだ'], ['のに', 'まだ', 'あほ'], ['まだ', 'あほ', 'みたい'], ['あほ', 'みたい', 'な'], ['みたい', 'な', 'こと'], ['な', 'こと', 'やり'], ['こと', 'やり', 'たい'], ['やり', 'たい', 'の'], ['たい', 'の', 'か']]
# ['きたな', 'さわ', 'は', 'せいきょく', 'が', 'だいいち', 'な', 'だけ', 'だ', 'から', 'ほんき', 'で', 'そう', 'おもっ', 'て', 'いる', 'ん', 'だろ', 'う', 'な', 'だれ', 'だ', 'よ', 'いまだに', 'こんな', 'に', 'とうひょう', 'し', 'てん', 'の', 'は', 'E']
# [['きたな', 'さわ', 'は'], ['さわ', 'は', 'せいきょく'], ['は', 'せいきょく', 'が'], ['せいきょく', 'が', 'だいいち'], ['が', 'だいいち', 'な'], ['だいいち', 'な', 'だけ'], ['な', 'だけ', 'だ'], ['だけ', 'だ', 'から'], ['だ', 'から', 'ほんき'], ['から', 'ほんき', 'で'], ['ほんき', 'で', 'そう'], ['で', 'そう', 'おもっ'], ['そう', 'おもっ', 'て'], ['おもっ', 'て', 'いる'], ['て', 'いる', 'ん'], ['いる', 'ん', 'だろ'], ['ん', 'だろ', 'う'], ['だろ', 'う', 'な'], ['う', 'な', 'だれ'], ['な', 'だれ', 'だ'], ['だれ', 'だ', 'よ'], ['だ', 'よ', 'いまだに'], ['よ', 'いまだに', 'こんな'], ['いまだに', 'こんな', 'に'], ['こんな', 'に', 'とうひょう'], ['に', 'とうひょう', 'し'], ['とうひょう', 'し', 'てん'], ['し', 'てん', 'の'], ['てん', 'の', 'は']]
# ['もくてき', 'の', 'ため', 'に', 'は', 'しゅだん', 'を', 'えらば', 'ず', 'そして', 'もくてき', 'を', 'わすれる', 'E']
# [['もくてき', 'の', 'ため'], ['の', 'ため', 'に'], ['ため', 'に', 'は'], ['に', 'は', 'しゅだん'], ['は', 'しゅだん', 'を'], ['しゅだん', 'を', 'えらば'], ['を', 'えらば', 'ず'], ['えらば', 'ず', 'そして'], ['ず', 'そして', 'もくてき'], ['そして', 'もくてき', 'を'], ['もくてき', 'を', 'わすれる']]
# ['なんか', 'はっそう', 'が', 'ふるい', 'と', 'いう', 'か', 'まとはずれ', 'と', 'いう', 'か', 'せそう', 'が', 'よめ', 'なく', 'なっ', 'たら', 'せいじか', 'は', 'おわり', 'だ', 'な', 'E']
# [['なんか', 'はっそう', 'が'], ['はっそう', 'が', 'ふるい'], ['が', 'ふるい', 'と'], ['ふるい', 'と', 'いう'], ['と', 'いう', 'か'], ['いう', 'か', 'まとはずれ'], ['か', 'まとはずれ', 'と'], ['まとはずれ', 'と', 'いう'], ['と', 'いう', 'か'], ['いう', 'か', 'せそう'], ['か', 'せそう', 'が'], ['せそう', 'が', 'よめ'], ['が', 'よめ', 'なく'], ['よめ', 'なく', 'なっ'], ['なく', 'なっ', 'たら'], ['なっ', 'たら', 'せいじか'], ['たら', 'せいじか', 'は'], ['せいじか', 'は', 'おわり'], ['は', 'おわり', 'だ'], ['おわり', 'だ', 'な']]
# ['みんしんとう', 'と', 'きょうさんとう', 'の', 'きょうとう', 'で', 'せいこう', 'まちがい', 'なし', 'しっぱい', 'でし', 'た', 'E']
# [['みんしんとう', 'と', 'きょうさんとう'], ['と', 'きょうさんとう', 'の'], ['きょうさんとう', 'の', 'きょうとう'], ['の', 'きょうとう', 'で'], ['きょうとう', 'で', 'せいこう'], ['で', 'せいこう', 'まちがい'], ['せいこう', 'まちがい', 'なし'], ['まちがい', 'なし', 'しっぱい'], ['なし', 'しっぱい', 'でし'], ['しっぱい', 'でし', 'た']]
# ['もう', 'それ', 'くりかえし', 'た', 'けっか', 'きそん', 'の', 'やとう', 'に', 'だれ', 'も', 'きたい', 'し', 'なく', 'なっ', 'た', 'の', 'が', 'げんじょう', 'だろ', 'う', 'に', 'E']
# [['もう', 'それ', 'くりかえし'], ['それ', 'くりかえし', 'た'], ['くりかえし', 'た', 'けっか'], ['た', 'けっか', 'きそん'], ['けっか', 'きそん', 'の'], ['きそん', 'の', 'やとう'], ['の', 'やとう', 'に'], ['やとう', 'に', 'だれ'], ['に', 'だれ', 'も'], ['だれ', 'も', 'きたい'], ['も', 'きたい', 'し'], ['きたい', 'し', 'なく'], ['し', 'なく', 'なっ'], ['なく', 'なっ', 'た'], ['なっ', 'た', 'の'], ['た', 'の', 'が'], ['の', 'が', 'げんじょう'], ['が', 'げんじょう', 'だろ'], ['げんじょう', 'だろ', 'う'], ['だろ', 'う', 'に']]
# ['じみん', 'に', 'ふまん', 'が', 'ある', 'から', 'って', 'じゃあ', 'みんしん', 'や', 'きょうさんとう', 'に', 'いれる', 'か', 'おまえ', 'ん', 'と', 'この', 'じゆうとう', 'とか', 'もってのほか', 'だろ', 'ばいこくど', 'が', 'E']
# [['じみん', 'に', 'ふまん'], ['に', 'ふまん', 'が'], ['ふまん', 'が', 'ある'], ['が', 'ある', 'から'], ['ある', 'から', 'って'], ['から', 'って', 'じゃあ'], ['って', 'じゃあ', 'みんしん'], ['じゃあ', 'みんしん', 'や'], ['みんしん', 'や', 'きょうさんとう'], ['や', 'きょうさんとう', 'に'], ['きょうさんとう', 'に', 'いれる'], ['に', 'いれる', 'か'], ['いれる', 'か', 'おまえ'], ['か', 'おまえ', 'ん'], ['おまえ', 'ん', 'と'], ['ん', 'と', 'この'], ['と', 'この', 'じゆうとう'], ['この', 'じゆうとう', 'とか'], ['じゆうとう', 'とか', 'もってのほか'], ['とか', 'もってのほか', 'だろ'], ['もってのほか', 'だろ', 'ばいこくど'], ['だろ', 'ばいこくど', 'が']]
# ['さん', 'とか', 'しい', 'さん', 'と', 'れんほう', 'さん', 'とか', 'いる', 'かぎり', 'そりゃ', 'E']
# [['さん', 'とか', 'しい'], ['とか', 'しい', 'さん'], ['しい', 'さん', 'と'], ['さん', 'と', 'れんほう'], ['と', 'れんほう', 'さん'], ['れんほう', 'さん', 'とか'], ['さん', 'とか', 'いる'], ['とか', 'いる', 'かぎり'], ['いる', 'かぎり', 'そりゃ']]
# ['どう', 'かんがえ', 'て', 'も', 'ともだおれ', 'いがい', 'の', 'けつまつ', 'ない', 'だろ', 'E']
# [['どう', 'かんがえ', 'て'], ['かんがえ', 'て', 'も'], ['て', 'も', 'ともだおれ'], ['も', 'ともだおれ', 'いがい'], ['ともだおれ', 'いがい', 'の'], ['いがい', 'の', 'けつまつ'], ['の', 'けつまつ', 'ない'], ['けつまつ', 'ない', 'だろ']]
# ['おざわ', 'ぬき', 'で', 'ね', 'E']
# [['おざわ', 'ぬき', 'で'], ['ぬき', 'で', 'ね']]
# ['せいさく', 'が', 'はんじみん', 'E']
# [['せいさく', 'が', 'はんじみん']]
# ['それでも', 'まとま', 'れ', 'ない', 'やとう', 'E']
# [['それでも', 'まとま', 'れ'], ['まとま', 'れ', 'ない'], ['れ', 'ない', 'やとう']]
# ['せいさく', 'で', 'かたら', 'なきゃ', 'いみ', 'が', 'ない', 'って', 'いう', 'E']
# [['せいさく', 'で', 'かたら'], ['で', 'かたら', 'なきゃ'], ['かたら', 'なきゃ', 'いみ'], ['なきゃ', 'いみ', 'が'], ['いみ', 'が', 'ない'], ['が', 'ない', 'って'], ['ない', 'って', 'いう']]
# ['せいこうたいけん', 'が', 'わすれ', 'られ', 'ない', 'ひと', 'が', 'ここ', 'に', 'も', 'E']
# [['せいこうたいけん', 'が', 'わすれ'], ['が', 'わすれ', 'られ'], ['わすれ', 'られ', 'ない'], ['られ', 'ない', 'ひと'], ['ない', 'ひと', 'が'], ['ひと', 'が', 'ここ'], ['が', 'ここ', 'に'], ['ここ', 'に', 'も']]
# ['やとう', 'ぜんぶ', 'あわせ', 'た', 'しじりつ', 'って', 'いくつ', 'でし', 'た', 'っけ', 'E']
# [['やとう', 'ぜんぶ', 'あわせ'], ['ぜんぶ', 'あわせ', 'た'], ['あわせ', 'た', 'しじりつ'], ['た', 'しじりつ', 'って'], ['しじりつ', 'って', 'いくつ'], ['って', 'いくつ', 'でし'], ['いくつ', 'でし', 'た'], ['でし', 'た', 'っけ']]
# ['やとう', 'を', 'ひとつ', 'に', 'って', 'きょうさんとう', 'に', 'いっぽん', 'か', 'する', 'しか', 'ない', 'だろ', 'きょうさんとう', 'が', 'とうめい', 'かえる', 'わけ', 'ない', 'から', 'E']
# [['やとう', 'を', 'ひとつ'], ['を', 'ひとつ', 'に'], ['ひとつ', 'に', 'って'], ['に', 'って', 'きょうさんとう'], ['って', 'きょうさんとう', 'に'], ['きょうさんとう', 'に', 'いっぽん'], ['に', 'いっぽん', 'か'], ['いっぽん', 'か', 'する'], ['か', 'する', 'しか'], ['する', 'しか', 'ない'], ['しか', 'ない', 'だろ'], ['ない', 'だろ', 'きょうさんとう'], ['だろ', 'きょうさんとう', 'が'], ['きょうさんとう', 'が', 'とうめい'], ['が', 'とうめい', 'かえる'], ['とうめい', 'かえる', 'わけ'], ['かえる', 'わけ', 'ない'], ['わけ', 'ない', 'から']]
# ['がくしゅう', 'のうりょく', 'ない', 'の', 'か', 'この', 'ばか', 'は', 'E']
# [['がくしゅう', 'のうりょく', 'ない'], ['のうりょく', 'ない', 'の'], ['ない', 'の', 'か'], ['の', 'か', 'この'], ['か', 'この', 'ばか'], ['この', 'ばか', 'は']]
# ['いま', 'の', 'やとう', 'に', 'うけざら', 'に', 'なる', 'とこ', 'が', 'ある', 'か', 'よ', 'E']
# [['いま', 'の', 'やとう'], ['の', 'やとう', 'に'], ['やとう', 'に', 'うけざら'], ['に', 'うけざら', 'に'], ['うけざら', 'に', 'なる'], ['に', 'なる', 'とこ'], ['なる', 'とこ', 'が'], ['とこ', 'が', 'ある'], ['が', 'ある', 'か'], ['ある', 'か', 'よ']]
# ['しぶとい', 'はんにち', 'すぱい', 'だ', 'な', 'E']
# [['しぶとい', 'はんにち', 'すぱい'], ['はんにち', 'すぱい', 'だ'], ['すぱい', 'だ', 'な']]
# ['せいじ', 'を', 'しろ', 'せいじ', 'を', 'うけざら', 'とか', 'じゃなくて', 'さ', 'E']
# [['せいじ', 'を', 'しろ'], ['を', 'しろ', 'せいじ'], ['しろ', 'せいじ', 'を'], ['せいじ', 'を', 'うけざら'], ['を', 'うけざら', 'とか'], ['うけざら', 'とか', 'じゃなくて'], ['とか', 'じゃなくて', 'さ']]
# ['おざわ', 'と', 'きょうさん', 'が', 'くん', 'で', 'だとう', 'じみん', 'とか', 'わらいばなし', 'に', 'も', 'なら', 'ん', 'わ', 'E']
# [['おざわ', 'と', 'きょうさん'], ['と', 'きょうさん', 'が'], ['きょうさん', 'が', 'くん'], ['が', 'くん', 'で'], ['くん', 'で', 'だとう'], ['で', 'だとう', 'じみん'], ['だとう', 'じみん', 'とか'], ['じみん', 'とか', 'わらいばなし'], ['とか', 'わらいばなし', 'に'], ['わらいばなし', 'に', 'も'], ['に', 'も', 'なら'], ['も', 'なら', 'ん'], ['なら', 'ん', 'わ']]
# ['たし', 'て', 'も', 'に', 'なら', 'ない', 'よ', 'ね', 'E']
# [['たし', 'て', 'も'], ['て', 'も', 'に'], ['も', 'に', 'なら'], ['に', 'なら', 'ない'], ['なら', 'ない', 'よ'], ['ない', 'よ', 'ね']]
# ['ばかさよ', 'はっきょう', 'みんす', 'かいめつ', 'E']
# [['ばかさよ', 'はっきょう', 'みんす'], ['はっきょう', 'みんす', 'かいめつ']]
# ['これ', 'で', 'さよく', 'は', 'せんきょせん', 'たたかう', 'つもり', 'な', 'ん', 'だ', 'E']
# [['これ', 'で', 'さよく'], ['で', 'さよく', 'は'], ['さよく', 'は', 'せんきょせん'], ['は', 'せんきょせん', 'たたかう'], ['せんきょせん', 'たたかう', 'つもり'], ['たたかう', 'つもり', 'な'], ['つもり', 'な', 'ん'], ['な', 'ん', 'だ']]
# ['こんな', 'もん', 'さ', 'ばかさよ', 'とう', 'なんて', 'えらぶ', 'わけ', 'ない', 'わ', 'E']
# [['こんな', 'もん', 'さ'], ['もん', 'さ', 'ばかさよ'], ['さ', 'ばかさよ', 'とう'], ['ばかさよ', 'とう', 'なんて'], ['とう', 'なんて', 'えらぶ'], ['なんて', 'えらぶ', 'わけ'], ['えらぶ', 'わけ', 'ない'], ['わけ', 'ない', 'わ']]
# ['どれ', 'だけ', 'せいけん', 'こうげき', 'し', 'て', 'も', 'じぶんたち', 'の', 'しじりつ', 'が', 'つながら', 'ない', 'やとう', 'はずかしい', 'と', 'おもわ', 'ない', 'の', 'か', 'ね', 'E']
# [['どれ', 'だけ', 'せいけん'], ['だけ', 'せいけん', 'こうげき'], ['せいけん', 'こうげき', 'し'], ['こうげき', 'し', 'て'], ['し', 'て', 'も'], ['て', 'も', 'じぶんたち'], ['も', 'じぶんたち', 'の'], ['じぶんたち', 'の', 'しじりつ'], ['の', 'しじりつ', 'が'], ['しじりつ', 'が', 'つながら'], ['が', 'つながら', 'ない'], ['つながら', 'ない', 'やとう'], ['ない', 'やとう', 'はずかしい'], ['やとう', 'はずかしい', 'と'], ['はずかしい', 'と', 'おもわ'], ['と', 'おもわ', 'ない'], ['おもわ', 'ない', 'の'], ['ない', 'の', 'か'], ['の', 'か', 'ね']]
# ['この', 'き', 'に', 'およん', 'で', 'も', 'とにかく', 'みんしん', 'だけ', 'は', 'もる', 'ん', 'だ', 'ね', 'E']
# [['この', 'き', 'に'], ['き', 'に', 'およん'], ['に', 'およん', 'で'], ['およん', 'で', 'も'], ['で', 'も', 'とにかく'], ['も', 'とにかく', 'みんしん'], ['とにかく', 'みんしん', 'だけ'], ['みんしん', 'だけ', 'は'], ['だけ', 'は', 'もる'], ['は', 'もる', 'ん'], ['もる', 'ん', 'だ'], ['ん', 'だ', 'ね']]
# ['みんしん', 'たかい', 'な', 'これ', 'じゃ', 'せんきょ', 'で', 'いい', 'しょうぶ', 'する', 'ん', 'じゃ', 'ない', 'の', 'E']
# [['みんしん', 'たかい', 'な'], ['たかい', 'な', 'これ'], ['な', 'これ', 'じゃ'], ['これ', 'じゃ', 'せんきょ'], ['じゃ', 'せんきょ', 'で'], ['せんきょ', 'で', 'いい'], ['で', 'いい', 'しょうぶ'], ['いい', 'しょうぶ', 'する'], ['しょうぶ', 'する', 'ん'], ['する', 'ん', 'じゃ'], ['ん', 'じゃ', 'ない'], ['じゃ', 'ない', 'の']]
# ['うけざら', 'が', 'ない', 'みんしんとう', 'きょうさんとう', 'しん', 'で', 'も', 'E']
# [['うけざら', 'が', 'ない'], ['が', 'ない', 'みんしんとう'], ['ない', 'みんしんとう', 'きょうさんとう'], ['みんしんとう', 'きょうさんとう', 'しん'], ['きょうさんとう', 'しん', 'で'], ['しん', 'で', 'も']]
# ['まだ', 'みんす', 'を', 'しじ', 'し', 'てる', 'やつ', 'って', 'E']
# [['まだ', 'みんす', 'を'], ['みんす', 'を', 'しじ'], ['を', 'しじ', 'し'], ['しじ', 'し', 'てる'], ['し', 'てる', 'やつ'], ['てる', 'やつ', 'って']]
# ['ばいこく', 'じみん', 'げらく', 'の', 'けいこう', 'は', 'いい', 'ん', 'だ', 'けど', 'いや', 'ほんと', 'とって', 'かわれる', 'まとも', 'な', 'やとう', 'が', 'ない', 'E']
# [['ばいこく', 'じみん', 'げらく'], ['じみん', 'げらく', 'の'], ['げらく', 'の', 'けいこう'], ['の', 'けいこう', 'は'], ['けいこう', 'は', 'いい'], ['は', 'いい', 'ん'], ['いい', 'ん', 'だ'], ['ん', 'だ', 'けど'], ['だ', 'けど', 'いや'], ['けど', 'いや', 'ほんと'], ['いや', 'ほんと', 'とって'], ['ほんと', 'とって', 'かわれる'], ['とって', 'かわれる', 'まとも'], ['かわれる', 'まとも', 'な'], ['まとも', 'な', 'やとう'], ['な', 'やとう', 'が'], ['やとう', 'が', 'ない']]
# ['そもそも', 'うけざら', 'ない', 'やん', 'E']
# [['そもそも', 'うけざら', 'ない'], ['うけざら', 'ない', 'やん']]
# ['ないかくしじりつ', 'が', 'すこし', 'あがっ', 'て', 'き', 'た', 'じゃん', 'さげ', 'すぎ', 'た', 'から', 'りばうんど', 'とおか', 'まえ', 'の', 'じじつうしん', 'ふつか', 'まえ', 'の', 'きょうどうつうしん', 'E']
# [['ないかくしじりつ', 'が', 'すこし'], ['が', 'すこし', 'あがっ'], ['すこし', 'あがっ', 'て'], ['あがっ', 'て', 'き'], ['て', 'き', 'た'], ['き', 'た', 'じゃん'], ['た', 'じゃん', 'さげ'], ['じゃん', 'さげ', 'すぎ'], ['さげ', 'すぎ', 'た'], ['すぎ', 'た', 'から'], ['た', 'から', 'りばうんど'], ['から', 'りばうんど', 'とおか'], ['りばうんど', 'とおか', 'まえ'], ['とおか', 'まえ', 'の'], ['まえ', 'の', 'じじつうしん'], ['の', 'じじつうしん', 'ふつか'], ['じじつうしん', 'ふつか', 'まえ'], ['ふつか', 'まえ', 'の'], ['まえ', 'の', 'きょうどうつうしん']]
# ['これだけ', 'がんばっ', 'て', 'ついきゅう', 'し', 'て', 'も', 'さがる', 'みんしんとう', 'は', 'おもしろい', 'な', 'どんだけ', 'きらわ', 'れ', 'てる', 'ん', 'だ', 'よ', 'E']
# [['これだけ', 'がんばっ', 'て'], ['がんばっ', 'て', 'ついきゅう'], ['て', 'ついきゅう', 'し'], ['ついきゅう', 'し', 'て'], ['し', 'て', 'も'], ['て', 'も', 'さがる'], ['も', 'さがる', 'みんしんとう'], ['さがる', 'みんしんとう', 'は'], ['みんしんとう', 'は', 'おもしろい'], ['は', 'おもしろい', 'な'], ['おもしろい', 'な', 'どんだけ'], ['な', 'どんだけ', 'きらわ'], ['どんだけ', 'きらわ', 'れ'], ['きらわ', 'れ', 'てる'], ['れ', 'てる', 'ん'], ['てる', 'ん', 'だ'], ['ん', 'だ', 'よ']]
# ['この', 'すれ', 'さよく', 'に', 'ふつごう', 'だ', 'から', 'のび', 'ない', 'な', 'さよく', 'どう', 'やっ', 'て', 'せんきょせん', 'たたかう', 'つもり', 'よ', 'E']
# [['この', 'すれ', 'さよく'], ['すれ', 'さよく', 'に'], ['さよく', 'に', 'ふつごう'], ['に', 'ふつごう', 'だ'], ['ふつごう', 'だ', 'から'], ['だ', 'から', 'のび'], ['から', 'のび', 'ない'], ['のび', 'ない', 'な'], ['ない', 'な', 'さよく'], ['な', 'さよく', 'どう'], ['さよく', 'どう', 'やっ'], ['どう', 'やっ', 'て'], ['やっ', 'て', 'せんきょせん'], ['て', 'せんきょせん', 'たたかう'], ['せんきょせん', 'たたかう', 'つもり'], ['たたかう', 'つもり', 'よ']]
# ['こん', 'かいさん', 'そう', 'せんきょ', 'し', 'たら', 'じみんとう', 'あっしょう', 'って', 'こと', 'だけ', 'は', 'わかっ', 'た', 'わ', 'E']
# [['こん', 'かいさん', 'そう'], ['かいさん', 'そう', 'せんきょ'], ['そう', 'せんきょ', 'し'], ['せんきょ', 'し', 'たら'], ['し', 'たら', 'じみんとう'], ['たら', 'じみんとう', 'あっしょう'], ['じみんとう', 'あっしょう', 'って'], ['あっしょう', 'って', 'こと'], ['って', 'こと', 'だけ'], ['こと', 'だけ', 'は'], ['だけ', 'は', 'わかっ'], ['は', 'わかっ', 'た'], ['わかっ', 'た', 'わ']]
# ['かん', 'せい', 'だんごう', 'による', 'けっか', 'E']
# [['かん', 'せい', 'だんごう'], ['せい', 'だんごう', 'による'], ['だんごう', 'による', 'けっか']]
# ['これ', 'どう', 'すん', 'の', 'E']
# [['これ', 'どう', 'すん'], ['どう', 'すん', 'の']]
# ['これ', 'こそ', 'まさに', 'お', 'ともだち', 'ゆうぐう', 'な', 'ん', 'だ', 'けど', 'ますこみ', 'は', 'だんまり', 'です', 'か', 'E']
# [['これ', 'こそ', 'まさに'], ['こそ', 'まさに', 'お'], ['まさに', 'お', 'ともだち'], ['お', 'ともだち', 'ゆうぐう'], ['ともだち', 'ゆうぐう', 'な'], ['ゆうぐう', 'な', 'ん'], ['な', 'ん', 'だ'], ['ん', 'だ', 'けど'], ['だ', 'けど', 'ますこみ'], ['けど', 'ますこみ', 'は'], ['ますこみ', 'は', 'だんまり'], ['は', 'だんまり', 'です'], ['だんまり', 'です', 'か']]
# ['えこ', 'えこ', 'さぎ', 'が', 'ばれ', 'まし', 'た', 'ね', 'E']
# [['えこ', 'えこ', 'さぎ'], ['えこ', 'さぎ', 'が'], ['さぎ', 'が', 'ばれ'], ['が', 'ばれ', 'まし'], ['ばれ', 'まし', 'た'], ['まし', 'た', 'ね']]
# ['やっぱり', 'げんぱつ', 'かどう', 'さ', 'せ', 'ない', 'と', 'むり', 'か', 'E']
# [['やっぱり', 'げんぱつ', 'かどう'], ['げんぱつ', 'かどう', 'さ'], ['かどう', 'さ', 'せ'], ['さ', 'せ', 'ない'], ['せ', 'ない', 'と'], ['ない', 'と', 'むり'], ['と', 'むり', 'か']]
# ['これ', 'は', 'みんす', 'の', 'せきにん', 'だろ', 'かいとりかかく', 'を', 'たかく', 'せってい', 'し', 'すぎ', 'だ', 'わ', 'E']
# [['これ', 'は', 'みんす'], ['は', 'みんす', 'の'], ['みんす', 'の', 'せきにん'], ['の', 'せきにん', 'だろ'], ['せきにん', 'だろ', 'かいとりかかく'], ['だろ', 'かいとりかかく', 'を'], ['かいとりかかく', 'を', 'たかく'], ['を', 'たかく', 'せってい'], ['たかく', 'せってい', 'し'], ['せってい', 'し', 'すぎ'], ['し', 'すぎ', 'だ'], ['すぎ', 'だ', 'わ']]
# ['これ', 'こそ', 'はしご', 'はずし', 'だ', 'わ', 'E']
# [['これ', 'こそ', 'はしご'], ['こそ', 'はしご', 'はずし'], ['はしご', 'はずし', 'だ'], ['はずし', 'だ', 'わ']]
# ['みんしゅとう', 'が', 'もじどおり', 'お', 'ともだち', 'の', 'ため', 'に', 'おしすすめ', 'た', 'せいさく', 'だ', 'もん', 'なぁ', 'E']
# [['みんしゅとう', 'が', 'もじどおり'], ['が', 'もじどおり', 'お'], ['もじどおり', 'お', 'ともだち'], ['お', 'ともだち', 'の'], ['ともだち', 'の', 'ため'], ['の', 'ため', 'に'], ['ため', 'に', 'おしすすめ'], ['に', 'おしすすめ', 'た'], ['おしすすめ', 'た', 'せいさく'], ['た', 'せいさく', 'だ'], ['せいさく', 'だ', 'もん'], ['だ', 'もん', 'なぁ']]
# ['そもそも', 'さいしょ', 'に', 'せってい', 'し', 'た', 'かいとりかかく', 'が', 'こう', 'すぎ', 'な', 'ん', 'だ', 'よ', 'E']
# [['そもそも', 'さいしょ', 'に'], ['さいしょ', 'に', 'せってい'], ['に', 'せってい', 'し'], ['せってい', 'し', 'た'], ['し', 'た', 'かいとりかかく'], ['た', 'かいとりかかく', 'が'], ['かいとりかかく', 'が', 'こう'], ['が', 'こう', 'すぎ'], ['こう', 'すぎ', 'な'], ['すぎ', 'な', 'ん'], ['な', 'ん', 'だ'], ['ん', 'だ', 'よ']]
# ['ほじょきん', 'だけ', 'で', 'は', 'きょうそう', 'が', 'おこら', 'ず', 'ぎょうかい', 'が', 'くさっ', 'て', 'いく', 'いい', 'みほん', 'だ', 'な', 'E']
# [['ほじょきん', 'だけ', 'で'], ['だけ', 'で', 'は'], ['で', 'は', 'きょうそう'], ['は', 'きょうそう', 'が'], ['きょうそう', 'が', 'おこら'], ['が', 'おこら', 'ず'], ['おこら', 'ず', 'ぎょうかい'], ['ず', 'ぎょうかい', 'が'], ['ぎょうかい', 'が', 'くさっ'], ['が', 'くさっ', 'て'], ['くさっ', 'て', 'いく'], ['て', 'いく', 'いい'], ['いく', 'いい', 'みほん'], ['いい', 'みほん', 'だ'], ['みほん', 'だ', 'な']]
# ['きんじょ', 'の', 'はたけ', 'が', 'いちめん', 'たいようこうぱねる', 'に', 'かわっ', 'た', 'ものの', 'ひかり', 'の', 'はんしゃ', 'とか', 'で', 'きんじょ', 'の', 'かべ', 'が', 'こげる', 'とか', 'しつない', 'に', 'まぶしい', 'ひかり', 'が', 'はいっ', 'て', 'くる', 'と', 'くじょう', 'が', 'さっとう', 'し', 'て', 'よくしゅう', 'に', 'てっきょ', 'さ', 'れ', 'て', 'て', 'わろた', 'E']
# [['きんじょ', 'の', 'はたけ'], ['の', 'はたけ', 'が'], ['はたけ', 'が', 'いちめん'], ['が', 'いちめん', 'たいようこうぱねる'], ['いちめん', 'たいようこうぱねる', 'に'], ['たいようこうぱねる', 'に', 'かわっ'], ['に', 'かわっ', 'た'], ['かわっ', 'た', 'ものの'], ['た', 'ものの', 'ひかり'], ['ものの', 'ひかり', 'の'], ['ひかり', 'の', 'はんしゃ'], ['の', 'はんしゃ', 'とか'], ['はんしゃ', 'とか', 'で'], ['とか', 'で', 'きんじょ'], ['で', 'きんじょ', 'の'], ['きんじょ', 'の', 'かべ'], ['の', 'かべ', 'が'], ['かべ', 'が', 'こげる'], ['が', 'こげる', 'とか'], ['こげる', 'とか', 'しつない'], ['とか', 'しつない', 'に'], ['しつない', 'に', 'まぶしい'], ['に', 'まぶしい', 'ひかり'], ['まぶしい', 'ひかり', 'が'], ['ひかり', 'が', 'はいっ'], ['が', 'はいっ', 'て'], ['はいっ', 'て', 'くる'], ['て', 'くる', 'と'], ['くる', 'と', 'くじょう'], ['と', 'くじょう', 'が'], ['くじょう', 'が', 'さっとう'], ['が', 'さっとう', 'し'], ['さっとう', 'し', 'て'], ['し', 'て', 'よくしゅう'], ['て', 'よくしゅう', 'に'], ['よくしゅう', 'に', 'てっきょ'], ['に', 'てっきょ', 'さ'], ['てっきょ', 'さ', 'れ'], ['さ', 'れ', 'て'], ['れ', 'て', 'て'], ['て', 'て', 'わろた']]
# ['ぎょうせい', 'が', 'むせきにん', 'すぎる', 'E']
# [['ぎょうせい', 'が', 'むせきにん'], ['が', 'むせきにん', 'すぎる']]
# ['とりあえず', 'いつも', 'の', 'E']
# [['とりあえず', 'いつも', 'の']]
# ['やっぱり', 'げんぱつ', 'や', 'な', 'E']
# [['やっぱり', 'げんぱつ', 'や'], ['げんぱつ', 'や', 'な']]
# ['ぱねる', 'ある', 'いえ', 'は', 'かも', 'か', 'さぎし', 'さっとう', 'E']
# [['ぱねる', 'ある', 'いえ'], ['ある', 'いえ', 'は'], ['いえ', 'は', 'かも'], ['は', 'かも', 'か'], ['かも', 'か', 'さぎし'], ['か', 'さぎし', 'さっとう']]
# ['かんなおと', 'の', 'おき', 'みやげ', 'が', 'なん', 'じゅう', 'ねん', 'も', 'もつ', 'わけ', 'ない', 'だろ', 'さいしょ', 'の', 'すうねん', 'で', 'うり', 'にげ', 'し', 'なかっ', 'た', 'きぎょう', 'は', 'ばか', 'E']
# [['かんなおと', 'の', 'おき'], ['の', 'おき', 'みやげ'], ['おき', 'みやげ', 'が'], ['みやげ', 'が', 'なん'], ['が', 'なん', 'じゅう'], ['なん', 'じゅう', 'ねん'], ['じゅう', 'ねん', 'も'], ['ねん', 'も', 'もつ'], ['も', 'もつ', 'わけ'], ['もつ', 'わけ', 'ない'], ['わけ', 'ない', 'だろ'], ['ない', 'だろ', 'さいしょ'], ['だろ', 'さいしょ', 'の'], ['さいしょ', 'の', 'すうねん'], ['の', 'すうねん', 'で'], ['すうねん', 'で', 'うり'], ['で', 'うり', 'にげ'], ['うり', 'にげ', 'し'], ['にげ', 'し', 'なかっ'], ['し', 'なかっ', 'た'], ['なかっ', 'た', 'きぎょう'], ['た', 'きぎょう', 'は'], ['きぎょう', 'は', 'ばか']]
# ['とうしょ', 'から', 'わかっ', 'て', 'た', 'だろ', 'こう', 'なる', 'の', 'E']
# [['とうしょ', 'から', 'わかっ'], ['から', 'わかっ', 'て'], ['わかっ', 'て', 'た'], ['て', 'た', 'だろ'], ['た', 'だろ', 'こう'], ['だろ', 'こう', 'なる'], ['こう', 'なる', 'の']]
# ['みんしゅとう', 'が', 'お', 'ともだち', 'に', 'そんたく', 'し', 'た', 'けっか', 'でしょ', 'う', 'E']
# [['みんしゅとう', 'が', 'お'], ['が', 'お', 'ともだち'], ['お', 'ともだち', 'に'], ['ともだち', 'に', 'そんたく'], ['に', 'そんたく', 'し'], ['そんたく', 'し', 'た'], ['し', 'た', 'けっか'], ['た', 'けっか', 'でしょ'], ['けっか', 'でしょ', 'う']]
# ['てれび', 'を', 'みる', 'と', 'ばかに', 'なる', 'から', 'E']
# [['てれび', 'を', 'みる'], ['を', 'みる', 'と'], ['みる', 'と', 'ばかに'], ['と', 'ばかに', 'なる'], ['ばかに', 'なる', 'から']]
# ['そのうち', 'てれび', 'って', 'せだい', 'ばかり', 'に', 'なる', 'な', 'E']
# [['そのうち', 'てれび', 'って'], ['てれび', 'って', 'せだい'], ['って', 'せだい', 'ばかり'], ['せだい', 'ばかり', 'に'], ['ばかり', 'に', 'なる'], ['に', 'なる', 'な']]
# ['みんぽう', 'の', 'ちじょうは', 'は', 'まず', 'み', 'ない', 'な', 'E']
# [['みんぽう', 'の', 'ちじょうは'], ['の', 'ちじょうは', 'は'], ['ちじょうは', 'は', 'まず'], ['は', 'まず', 'み'], ['まず', 'み', 'ない'], ['み', 'ない', 'な']]
# ['てれび', 'み', 'てる', 'と', 'うそ', 'ばっか', 'で', 'ほんとうに', 'なかみ', 'すっからかん', 'の', 'ばか', 'に', 'なる', 'E']
# [['てれび', 'み', 'てる'], ['み', 'てる', 'と'], ['てる', 'と', 'うそ'], ['と', 'うそ', 'ばっか'], ['うそ', 'ばっか', 'で'], ['ばっか', 'で', 'ほんとうに'], ['で', 'ほんとうに', 'なかみ'], ['ほんとうに', 'なかみ', 'すっからかん'], ['なかみ', 'すっからかん', 'の'], ['すっからかん', 'の', 'ばか'], ['の', 'ばか', 'に'], ['ばか', 'に', 'なる']]
# ['へんこうほうどう', 'ばっか', 'だ', 'し', 'くだらない', 'おわらい', 'とか', 'みる', 'かち', 'ない', 'わ', 'E']
# [['へんこうほうどう', 'ばっか', 'だ'], ['ばっか', 'だ', 'し'], ['だ', 'し', 'くだらない'], ['し', 'くだらない', 'おわらい'], ['くだらない', 'おわらい', 'とか'], ['おわらい', 'とか', 'みる'], ['とか', 'みる', 'かち'], ['みる', 'かち', 'ない'], ['かち', 'ない', 'わ']]
# ['いみ', 'の', 'ない', 'ところ', 'で', 'ちょうせんじん', 'を', 'もちあげる', 'とか', 'てれびきょく', 'に', 'ちょうせんじん', 'が', 'いる', 'の', 'が', 'ばればれ', 'E']
# [['いみ', 'の', 'ない'], ['の', 'ない', 'ところ'], ['ない', 'ところ', 'で'], ['ところ', 'で', 'ちょうせんじん'], ['で', 'ちょうせんじん', 'を'], ['ちょうせんじん', 'を', 'もちあげる'], ['を', 'もちあげる', 'とか'], ['もちあげる', 'とか', 'てれびきょく'], ['とか', 'てれびきょく', 'に'], ['てれびきょく', 'に', 'ちょうせんじん'], ['に', 'ちょうせんじん', 'が'], ['ちょうせんじん', 'が', 'いる'], ['が', 'いる', 'の'], ['いる', 'の', 'が'], ['の', 'が', 'ばればれ']]
# ['きまっ', 'た', 'じかん', 'に', 'しか', 'みれ', 'ない', 'てれび', 'すき', 'な', 'とき', 'に', 'みれる', 'ねっと', 'E']
# [['きまっ', 'た', 'じかん'], ['た', 'じかん', 'に'], ['じかん', 'に', 'しか'], ['に', 'しか', 'みれ'], ['しか', 'みれ', 'ない'], ['みれ', 'ない', 'てれび'], ['ない', 'てれび', 'すき'], ['てれび', 'すき', 'な'], ['すき', 'な', 'とき'], ['な', 'とき', 'に'], ['とき', 'に', 'みれる'], ['に', 'みれる', 'ねっと']]
# ['そりゃそうだ', 'ろ', 'てれび', 'は', 'うそ', 'や', 'すてま', 'ばんぐみ', 'だらけ', 'だ', 'から', 'な', 'E']
# [['そりゃそうだ', 'ろ', 'てれび'], ['ろ', 'てれび', 'は'], ['てれび', 'は', 'うそ'], ['は', 'うそ', 'や'], ['うそ', 'や', 'すてま'], ['や', 'すてま', 'ばんぐみ'], ['すてま', 'ばんぐみ', 'だらけ'], ['ばんぐみ', 'だらけ', 'だ'], ['だらけ', 'だ', 'から'], ['だ', 'から', 'な']]
# ['いや', 'どう', 'かんがえ', 'て', 'も', 'てれび', 'の', 'ほう', 'が', 'わかい', 'やつら', 'から', 'はなれ', 'て', 'おこなっ', 'てる', 'だろ', 'E']
# [['いや', 'どう', 'かんがえ'], ['どう', 'かんがえ', 'て'], ['かんがえ', 'て', 'も'], ['て', 'も', 'てれび'], ['も', 'てれび', 'の'], ['てれび', 'の', 'ほう'], ['の', 'ほう', 'が'], ['ほう', 'が', 'わかい'], ['が', 'わかい', 'やつら'], ['わかい', 'やつら', 'から'], ['やつら', 'から', 'はなれ'], ['から', 'はなれ', 'て'], ['はなれ', 'て', 'おこなっ'], ['て', 'おこなっ', 'てる'], ['おこなっ', 'てる', 'だろ']]
# ['しゃいんしょくどう', 'で', 'めし', 'くっ', 'てる', 'とき', 'しか', 'み', 'ない', 'わ', 'E']
# [['しゃいんしょくどう', 'で', 'めし'], ['で', 'めし', 'くっ'], ['めし', 'くっ', 'てる'], ['くっ', 'てる', 'とき'], ['てる', 'とき', 'しか'], ['とき', 'しか', 'み'], ['しか', 'み', 'ない'], ['み', 'ない', 'わ']]
# ['もはや', 'いえ', 'に', 'てれび', 'ない', 'し', 'E']
# [['もはや', 'いえ', 'に'], ['いえ', 'に', 'てれび'], ['に', 'てれび', 'ない'], ['てれび', 'ない', 'し']]
# ['いやならみるな', 'を', 'じっこう', 'し', 'てる', 'まで', 'E']
# [['いやならみるな', 'を', 'じっこう'], ['を', 'じっこう', 'し'], ['じっこう', 'し', 'てる'], ['し', 'てる', 'まで']]
# ['この', 'ちょうし', 'で', 'ますごみ', 'ども', 'の', 'ちから', 'が', 'おちる', 'ほう', 'が', 'しゃかい', 'の', 'ため', 'に', 'なる', 'な', 'E']
# [['この', 'ちょうし', 'で'], ['ちょうし', 'で', 'ますごみ'], ['で', 'ますごみ', 'ども'], ['ますごみ', 'ども', 'の'], ['ども', 'の', 'ちから'], ['の', 'ちから', 'が'], ['ちから', 'が', 'おちる'], ['が', 'おちる', 'ほう'], ['おちる', 'ほう', 'が'], ['ほう', 'が', 'しゃかい'], ['が', 'しゃかい', 'の'], ['しゃかい', 'の', 'ため'], ['の', 'ため', 'に'], ['ため', 'に', 'なる'], ['に', 'なる', 'な']]
# ['しんじつ', 'は', 'ねっと', 'に', 'ある', 'から', 'な', 'E']
# [['しんじつ', 'は', 'ねっと'], ['は', 'ねっと', 'に'], ['ねっと', 'に', 'ある'], ['に', 'ある', 'から'], ['ある', 'から', 'な']]
# ['むかし', 'って', 'てれび', 'み', 'た', 'さ', 'に', 'いえ', 'に', 'かえっ', 'て', 'たり', 'し', 'た', 'よ', 'な', 'いま', 'じゃ', 'E']
# [['むかし', 'って', 'てれび'], ['って', 'てれび', 'み'], ['てれび', 'み', 'た'], ['み', 'た', 'さ'], ['た', 'さ', 'に'], ['さ', 'に', 'いえ'], ['に', 'いえ', 'に'], ['いえ', 'に', 'かえっ'], ['に', 'かえっ', 'て'], ['かえっ', 'て', 'たり'], ['て', 'たり', 'し'], ['たり', 'し', 'た'], ['し', 'た', 'よ'], ['た', 'よ', 'な'], ['よ', 'な', 'いま'], ['な', 'いま', 'じゃ']]
# ['てれび', 'みる', 'に', 'せよ', 'りあるたいむ', 'で', 'みる', 'こと', 'は', 'おおはば', 'に', 'へっ', 'た', 'な', 'ほとんど', 'ろくが', 'し', 'た', 'の', 'み', 'てる', 'わ', 'E']
# [['てれび', 'みる', 'に'], ['みる', 'に', 'せよ'], ['に', 'せよ', 'りあるたいむ'], ['せよ', 'りあるたいむ', 'で'], ['りあるたいむ', 'で', 'みる'], ['で', 'みる', 'こと'], ['みる', 'こと', 'は'], ['こと', 'は', 'おおはば'], ['は', 'おおはば', 'に'], ['おおはば', 'に', 'へっ'], ['に', 'へっ', 'た'], ['へっ', 'た', 'な'], ['た', 'な', 'ほとんど'], ['な', 'ほとんど', 'ろくが'], ['ほとんど', 'ろくが', 'し'], ['ろくが', 'し', 'た'], ['し', 'た', 'の'], ['た', 'の', 'み'], ['の', 'み', 'てる'], ['み', 'てる', 'わ']]
# ['ひまつぶし', 'に', 'も', 'なら', 'ず', 'がいあく', 'で', 'しか', 'ない', 'と', 'みな', 'きづい', 'て', 'しまっ', 'た', 'E']
# [['ひまつぶし', 'に', 'も'], ['に', 'も', 'なら'], ['も', 'なら', 'ず'], ['なら', 'ず', 'がいあく'], ['ず', 'がいあく', 'で'], ['がいあく', 'で', 'しか'], ['で', 'しか', 'ない'], ['しか', 'ない', 'と'], ['ない', 'と', 'みな'], ['と', 'みな', 'きづい'], ['みな', 'きづい', 'て'], ['きづい', 'て', 'しまっ'], ['て', 'しまっ', 'た']]
# ['さん', 'じゅうだい', 'も', 'おとこ', 'は', 'ねっと', 'ゆうせい', 'だろ', 'E']
# [['さん', 'じゅうだい', 'も'], ['じゅうだい', 'も', 'おとこ'], ['も', 'おとこ', 'は'], ['おとこ', 'は', 'ねっと'], ['は', 'ねっと', 'ゆうせい'], ['ねっと', 'ゆうせい', 'だろ']]
# ['でも', 'ねっと', 'の', 'の', 'ほとんど', 'は', 'しんぶん', 'な', 'ん', 'だ', 'よ', 'ね', 'E']
# [['でも', 'ねっと', 'の'], ['ねっと', 'の', 'の'], ['の', 'の', 'ほとんど'], ['の', 'ほとんど', 'は'], ['ほとんど', 'は', 'しんぶん'], ['は', 'しんぶん', 'な'], ['しんぶん', 'な', 'ん'], ['な', 'ん', 'だ'], ['ん', 'だ', 'よ'], ['だ', 'よ', 'ね']]
# ['に', 'なっ', 'てる', 'から', 'な', 'てれび', 'は', 'E']
# [['に', 'なっ', 'てる'], ['なっ', 'てる', 'から'], ['てる', 'から', 'な'], ['から', 'な', 'てれび'], ['な', 'てれび', 'は']]
# ['ねっとじょう', 'で', 'とっく', 'に', 'みやぶら', 'れ', 'てる', 'うそ', 'を', 'えんえんと', 'たれ', 'ながす', 'てれび', 'E']
# [['ねっとじょう', 'で', 'とっく'], ['で', 'とっく', 'に'], ['とっく', 'に', 'みやぶら'], ['に', 'みやぶら', 'れ'], ['みやぶら', 'れ', 'てる'], ['れ', 'てる', 'うそ'], ['てる', 'うそ', 'を'], ['うそ', 'を', 'えんえんと'], ['を', 'えんえんと', 'たれ'], ['えんえんと', 'たれ', 'ながす'], ['たれ', 'ながす', 'てれび']]
# ['てれび', 'って', 'しょっぴんぐ', 'ばかり', 'E']
# [['てれび', 'って', 'しょっぴんぐ'], ['って', 'しょっぴんぐ', 'ばかり']]
# ['こないだ', 'ひさしぶり', 'に', 'てれび', 'み', 'たら', 'あいて', 'の', 'ほけん', 'や', 'けんこうしょくひん', 'の', 'ばっか', 'し', 'て', 'て', 'わろた', 'E']
# [['こないだ', 'ひさしぶり', 'に'], ['ひさしぶり', 'に', 'てれび'], ['に', 'てれび', 'み'], ['てれび', 'み', 'たら'], ['み', 'たら', 'あいて'], ['たら', 'あいて', 'の'], ['あいて', 'の', 'ほけん'], ['の', 'ほけん', 'や'], ['ほけん', 'や', 'けんこうしょくひん'], ['や', 'けんこうしょくひん', 'の'], ['けんこうしょくひん', 'の', 'ばっか'], ['の', 'ばっか', 'し'], ['ばっか', 'し', 'て'], ['し', 'て', 'て'], ['て', 'て', 'わろた']]
# ['せんのう', 'じだい', 'も', 'やっと', 'おわり', 'か', 'やきゅう', 'や', 'おわらい', 'あたり', 'の', 'ふしぜん', 'な', 'もちあげ', 'が', 'なくなる', 'な', 'E']
# [['せんのう', 'じだい', 'も'], ['じだい', 'も', 'やっと'], ['も', 'やっと', 'おわり'], ['やっと', 'おわり', 'か'], ['おわり', 'か', 'やきゅう'], ['か', 'やきゅう', 'や'], ['やきゅう', 'や', 'おわらい'], ['や', 'おわらい', 'あたり'], ['おわらい', 'あたり', 'の'], ['あたり', 'の', 'ふしぜん'], ['の', 'ふしぜん', 'な'], ['ふしぜん', 'な', 'もちあげ'], ['な', 'もちあげ', 'が'], ['もちあげ', 'が', 'なくなる'], ['が', 'なくなる', 'な']]
# ['ねっと', 'より', 'てれび', 'の', 'が', 'おもしろけれ', 'ば', 'もどる', 'でしょ', 'いう', 'ほど', 'てれび', 'じたい', 'から', 'はなれ', 'てる', 'わけ', 'じゃ', 'ない', 'E']
# [['ねっと', 'より', 'てれび'], ['より', 'てれび', 'の'], ['てれび', 'の', 'が'], ['の', 'が', 'おもしろけれ'], ['が', 'おもしろけれ', 'ば'], ['おもしろけれ', 'ば', 'もどる'], ['ば', 'もどる', 'でしょ'], ['もどる', 'でしょ', 'いう'], ['でしょ', 'いう', 'ほど'], ['いう', 'ほど', 'てれび'], ['ほど', 'てれび', 'じたい'], ['てれび', 'じたい', 'から'], ['じたい', 'から', 'はなれ'], ['から', 'はなれ', 'てる'], ['はなれ', 'てる', 'わけ'], ['てる', 'わけ', 'じゃ'], ['わけ', 'じゃ', 'ない']]
# ['さいきん', 'じゃ', 'てれび', 'より', 'どうが', 'み', 'てる', 'ほう', 'が', 'おもしろい', 'もん', 'な', 'じっさい', 'E']
# [['さいきん', 'じゃ', 'てれび'], ['じゃ', 'てれび', 'より'], ['てれび', 'より', 'どうが'], ['より', 'どうが', 'み'], ['どうが', 'み', 'てる'], ['み', 'てる', 'ほう'], ['てる', 'ほう', 'が'], ['ほう', 'が', 'おもしろい'], ['が', 'おもしろい', 'もん'], ['おもしろい', 'もん', 'な'], ['もん', 'な', 'じっさい']]
# ['どこ', 'の', 'くに', 'の', 'てれびきょく', 'か', 'わから', 'ない', 'E']
# [['どこ', 'の', 'くに'], ['の', 'くに', 'の'], ['くに', 'の', 'てれびきょく'], ['の', 'てれびきょく', 'か'], ['てれびきょく', 'か', 'わから'], ['か', 'わから', 'ない']]
# ['ますごみ', 'なんか', 'み', 'ねえ', 'よ', 'E']
# [['ますごみ', 'なんか', 'み'], ['なんか', 'み', 'ねえ'], ['み', 'ねえ', 'よ']]
# ['てれび', 'おい', 'て', 'ない', 'わ', 'E']
# [['てれび', 'おい', 'て'], ['おい', 'て', 'ない'], ['て', 'ない', 'わ']]
# ['うっ', 'すい', 'ねた', 'で', 'しゃく', 'うめ', 'てる', 'の', 'が', 'みえ', 'みえ', 'な', 'の', 'が', 'ばれ', 'た', 'E']
# [['うっ', 'すい', 'ねた'], ['すい', 'ねた', 'で'], ['ねた', 'で', 'しゃく'], ['で', 'しゃく', 'うめ'], ['しゃく', 'うめ', 'てる'], ['うめ', 'てる', 'の'], ['てる', 'の', 'が'], ['の', 'が', 'みえ'], ['が', 'みえ', 'みえ'], ['みえ', 'みえ', 'な'], ['みえ', 'な', 'の'], ['な', 'の', 'が'], ['の', 'が', 'ばれ'], ['が', 'ばれ', 'た']]
# ['てれび', 'は', 'すきっぷ', 'でき', 'ない', 'から', 'たえ', 'れ', 'ない', 'E']
# [['てれび', 'は', 'すきっぷ'], ['は', 'すきっぷ', 'でき'], ['すきっぷ', 'でき', 'ない'], ['でき', 'ない', 'から'], ['ない', 'から', 'たえ'], ['から', 'たえ', 'れ'], ['たえ', 'れ', 'ない']]
# ['これ', 'が', 'せかい', 'の', 'じょうしき', 'だ', 'E']
# [['これ', 'が', 'せかい'], ['が', 'せかい', 'の'], ['せかい', 'の', 'じょうしき'], ['の', 'じょうしき', 'だ']]
# ['れんほう', 'そっと', 'じ', 'すれ', 'E']
# [['れんほう', 'そっと', 'じ'], ['そっと', 'じ', 'すれ']]
# ['にじゅうこくせき', 'すぱい', 'が', 'せかい', 'の', 'じょうしき', 'だっ', 'た', 'か', 'E']
# [['にじゅうこくせき', 'すぱい', 'が'], ['すぱい', 'が', 'せかい'], ['が', 'せかい', 'の'], ['せかい', 'の', 'じょうしき'], ['の', 'じょうしき', 'だっ'], ['じょうしき', 'だっ', 'た'], ['だっ', 'た', 'か']]
# ['わがくに', 'は', 'どう', 'する', 'の', 'か', 'な', 'E']
# [['わがくに', 'は', 'どう'], ['は', 'どう', 'する'], ['どう', 'する', 'の'], ['する', 'の', 'か'], ['の', 'か', 'な']]
# ['じょうしき', 'で', 'かんがえ', 'たら', 'こう', 'だ', 'よ', 'な', 'E']
# [['じょうしき', 'で', 'かんがえ'], ['で', 'かんがえ', 'たら'], ['かんがえ', 'たら', 'こう'], ['たら', 'こう', 'だ'], ['こう', 'だ', 'よ'], ['だ', 'よ', 'な']]
# ['ひがいしゃ', 'めんし', 'て', 'さべつ', 'とか', 'わらえる', 'よ', 'れんほう', 'にっぽん', 'なめ', 'られ', 'すぎ', 'E']
# [['ひがいしゃ', 'めんし', 'て'], ['めんし', 'て', 'さべつ'], ['て', 'さべつ', 'とか'], ['さべつ', 'とか', 'わらえる'], ['とか', 'わらえる', 'よ'], ['わらえる', 'よ', 'れんほう'], ['よ', 'れんほう', 'にっぽん'], ['れんほう', 'にっぽん', 'なめ'], ['にっぽん', 'なめ', 'られ'], ['なめ', 'られ', 'すぎ']]
# ['うむ', 'よい', 'こと', 'だ', 'E']
# [['うむ', 'よい', 'こと'], ['よい', 'こと', 'だ']]
# ['ほうりつ', 'まもっ', 'て', 'ない', 'やつ', 'が', 'さべつ', 'とか', 'に', 'すりかえ', 'て', 'いばっ', 'てる', 'の', 'が', 'すごい', 'よ', 'な', 'E']
# [['ほうりつ', 'まもっ', 'て'], ['まもっ', 'て', 'ない'], ['て', 'ない', 'やつ'], ['ない', 'やつ', 'が'], ['やつ', 'が', 'さべつ'], ['が', 'さべつ', 'とか'], ['さべつ', 'とか', 'に'], ['とか', 'に', 'すりかえ'], ['に', 'すりかえ', 'て'], ['すりかえ', 'て', 'いばっ'], ['て', 'いばっ', 'てる'], ['いばっ', 'てる', 'の'], ['てる', 'の', 'が'], ['の', 'が', 'すごい'], ['が', 'すごい', 'よ'], ['すごい', 'よ', 'な']]
# ['じっさい', 'すぱい', 'だ', 'し', 'がいかん', 'だ', 'ぞ', 'にっぽん', 'の', 'どこ', 'に', 'でも', 'はいりこん', 'でる', 'だろ', 'にっぽんじん', 'の', 'ふり', 'し', 'て', 'な', 'E']
# [['じっさい', 'すぱい', 'だ'], ['すぱい', 'だ', 'し'], ['だ', 'し', 'がいかん'], ['し', 'がいかん', 'だ'], ['がいかん', 'だ', 'ぞ'], ['だ', 'ぞ', 'にっぽん'], ['ぞ', 'にっぽん', 'の'], ['にっぽん', 'の', 'どこ'], ['の', 'どこ', 'に'], ['どこ', 'に', 'でも'], ['に', 'でも', 'はいりこん'], ['でも', 'はいりこん', 'でる'], ['はいりこん', 'でる', 'だろ'], ['でる', 'だろ', 'にっぽんじん'], ['だろ', 'にっぽんじん', 'の'], ['にっぽんじん', 'の', 'ふり'], ['の', 'ふり', 'し'], ['ふり', 'し', 'て'], ['し', 'て', 'な']]
# ['にっぽんこくみん', 'を', 'あざむい', 'た', 'つみ', 'は', 'ちょうえき', 'いち', 'ぜろ', 'ねん', 'が', 'だとう', 'E']
# [['にっぽんこくみん', 'を', 'あざむい'], ['を', 'あざむい', 'た'], ['あざむい', 'た', 'つみ'], ['た', 'つみ', 'は'], ['つみ', 'は', 'ちょうえき'], ['は', 'ちょうえき', 'いち'], ['ちょうえき', 'いち', 'ぜろ'], ['いち', 'ぜろ', 'ねん'], ['ぜろ', 'ねん', 'が'], ['ねん', 'が', 'だとう']]
# ['れんほう', 'すぱい', 'きんこ', 'じゅうねん', 'E']
# [['れんほう', 'すぱい', 'きんこ'], ['すぱい', 'きんこ', 'じゅうねん']]
# ['だって', 'さ', 'れんほう', 'さん', 'どう', 'おもう', 'E']
# [['だって', 'さ', 'れんほう'], ['さ', 'れんほう', 'さん'], ['れんほう', 'さん', 'どう'], ['さん', 'どう', 'おもう']]
# ['せかい', 'で', 'は', 'うんぬん', 'E']
# [['せかい', 'で', 'は'], ['で', 'は', 'うんぬん']]
# ['これ', 'が', 'あたりまえ', 'な', 'ん', 'だ', 'よ', 'E']
# [['これ', 'が', 'あたりまえ'], ['が', 'あたりまえ', 'な'], ['あたりまえ', 'な', 'ん'], ['な', 'ん', 'だ'], ['ん', 'だ', 'よ']]
# ['がいかん', 'あつかい', 'に', 'なっ', 'て', 'しかるべき', 'だ', 'よ', 'な', 'E']
# [['がいかん', 'あつかい', 'に'], ['あつかい', 'に', 'なっ'], ['に', 'なっ', 'て'], ['なっ', 'て', 'しかるべき'], ['て', 'しかるべき', 'だ'], ['しかるべき', 'だ', 'よ'], ['だ', 'よ', 'な']]
# ['こっかいぎいん', 'なんて', 'もってのほか', 'だ', 'な', 'E']
# [['こっかいぎいん', 'なんて', 'もってのほか'], ['なんて', 'もってのほか', 'だ'], ['もってのほか', 'だ', 'な']]
# ['せいじか', 'こうむいん', 'くらい', 'は', 'にじゅうこくせき', 'きんし', 'に', 'し', 'ない', 'と', 'E']
# [['せいじか', 'こうむいん', 'くらい'], ['こうむいん', 'くらい', 'は'], ['くらい', 'は', 'にじゅうこくせき'], ['は', 'にじゅうこくせき', 'きんし'], ['にじゅうこくせき', 'きんし', 'に'], ['きんし', 'に', 'し'], ['に', 'し', 'ない'], ['し', 'ない', 'と']]
# ['にっぽん', 'も', 'みならう', 'べき', 'だ', 'な', 'E']
# [['にっぽん', 'も', 'みならう'], ['も', 'みならう', 'べき'], ['みならう', 'べき', 'だ'], ['べき', 'だ', 'な']]
# ['ふつうのくに', 'なら', 'そう', 'なる', 'わな', 'わっと', 'E']
# [['ふつうのくに', 'なら', 'そう'], ['なら', 'そう', 'なる'], ['そう', 'なる', 'わな'], ['なる', 'わな', 'わっと']]
# ['これ', 'が', 'ふつう', 'ほんと', 'に', 'にっぽん', 'は', 'すぱい', 'てんごく', 'だ', 'わ', 'E']
# [['これ', 'が', 'ふつう'], ['が', 'ふつう', 'ほんと'], ['ふつう', 'ほんと', 'に'], ['ほんと', 'に', 'にっぽん'], ['に', 'にっぽん', 'は'], ['にっぽん', 'は', 'すぱい'], ['は', 'すぱい', 'てんごく'], ['すぱい', 'てんごく', 'だ'], ['てんごく', 'だ', 'わ']]
# ['じじつ', 'じゃ', 'ねえ', 'か', 'E']
# [['じじつ', 'じゃ', 'ねえ'], ['じゃ', 'ねえ', 'か']]
# ['じじつ', 'を', 'いわ', 'れ', 'て', 'なぜ', 'おこる', 'なに', 'が', 'へんけん', 'な', 'の', 'だ', 'せいけいたいこく', 'って', 'ほるほる', 'し', 'て', 'た', 'だろ', 'う', 'E']
# [['じじつ', 'を', 'いわ'], ['を', 'いわ', 'れ'], ['いわ', 'れ', 'て'], ['れ', 'て', 'なぜ'], ['て', 'なぜ', 'おこる'], ['なぜ', 'おこる', 'なに'], ['おこる', 'なに', 'が'], ['なに', 'が', 'へんけん'], ['が', 'へんけん', 'な'], ['へんけん', 'な', 'の'], ['な', 'の', 'だ'], ['の', 'だ', 'せいけいたいこく'], ['だ', 'せいけいたいこく', 'って'], ['せいけいたいこく', 'って', 'ほるほる'], ['って', 'ほるほる', 'し'], ['ほるほる', 'し', 'て'], ['し', 'て', 'た'], ['て', 'た', 'だろ'], ['た', 'だろ', 'う']]
# ['だいがく', 'ごうかく', 'いわい', 'が', 'せいけい', 'な', 'ん', 'でしょ', 'なに', 'を', 'はじる', 'こと', 'ある', 'E']
# [['だいがく', 'ごうかく', 'いわい'], ['ごうかく', 'いわい', 'が'], ['いわい', 'が', 'せいけい'], ['が', 'せいけい', 'な'], ['せいけい', 'な', 'ん'], ['な', 'ん', 'でしょ'], ['ん', 'でしょ', 'なに'], ['でしょ', 'なに', 'を'], ['なに', 'を', 'はじる'], ['を', 'はじる', 'こと'], ['はじる', 'こと', 'ある']]
# ['で', 'せいかい', 'は', 'なに', 'な', 'の', 'です', 'E']
# [['で', 'せいかい', 'は'], ['せいかい', 'は', 'なに'], ['は', 'なに', 'な'], ['なに', 'な', 'の'], ['な', 'の', 'です']]
# ['こんな', 'の', 'が', 'ぶつぎ', 'を', 'かもす', 'って', 'こと', 'は', 'かんこくじん', 'も', 'せいけい', 'にたいして', 'うしろめたい', 'きもち', 'を', 'もっ', 'てる', 'って', 'こと', 'だ', 'よ', 'な', 'E']
# [['こんな', 'の', 'が'], ['の', 'が', 'ぶつぎ'], ['が', 'ぶつぎ', 'を'], ['ぶつぎ', 'を', 'かもす'], ['を', 'かもす', 'って'], ['かもす', 'って', 'こと'], ['って', 'こと', 'は'], ['こと', 'は', 'かんこくじん'], ['は', 'かんこくじん', 'も'], ['かんこくじん', 'も', 'せいけい'], ['も', 'せいけい', 'にたいして'], ['せいけい', 'にたいして', 'うしろめたい'], ['にたいして', 'うしろめたい', 'きもち'], ['うしろめたい', 'きもち', 'を'], ['きもち', 'を', 'もっ'], ['を', 'もっ', 'てる'], ['もっ', 'てる', 'って'], ['てる', 'って', 'こと'], ['って', 'こと', 'だ'], ['こと', 'だ', 'よ'], ['だ', 'よ', 'な']]
# ['ばいしゅん', 'と', 'こたえ', 'なかっ', 'た', 'だけ', 'まし', 'じゃ', 'ない', 'か', 'E']
# [['ばいしゅん', 'と', 'こたえ'], ['と', 'こたえ', 'なかっ'], ['こたえ', 'なかっ', 'た'], ['なかっ', 'た', 'だけ'], ['た', 'だけ', 'まし'], ['だけ', 'まし', 'じゃ'], ['まし', 'じゃ', 'ない'], ['じゃ', 'ない', 'か']]
# ['しばきたい', 'しゅつどう', 'や', 'な', 'E']
# [['しばきたい', 'しゅつどう', 'や'], ['しゅつどう', 'や', 'な']]
# ['いや', 'がる', 'こども', 'に', 'むり', 'に', 'せいけい', 'さ', 'せ', 'たり', 'たんじょうび', 'の', 'ぷれぜんと', 'に', 'おや', 'が', 'しゅじゅつ', 'だい', 'を', 'だす', 'くに', 'が', 'なに', 'を', 'いっ', 'てる', 'ん', 'だ', 'せいかい', 'だろ', 'E']
# [['いや', 'がる', 'こども'], ['がる', 'こども', 'に'], ['こども', 'に', 'むり'], ['に', 'むり', 'に'], ['むり', 'に', 'せいけい'], ['に', 'せいけい', 'さ'], ['せいけい', 'さ', 'せ'], ['さ', 'せ', 'たり'], ['せ', 'たり', 'たんじょうび'], ['たり', 'たんじょうび', 'の'], ['たんじょうび', 'の', 'ぷれぜんと'], ['の', 'ぷれぜんと', 'に'], ['ぷれぜんと', 'に', 'おや'], ['に', 'おや', 'が'], ['おや', 'が', 'しゅじゅつ'], ['が', 'しゅじゅつ', 'だい'], ['しゅじゅつ', 'だい', 'を'], ['だい', 'を', 'だす'], ['を', 'だす', 'くに'], ['だす', 'くに', 'が'], ['くに', 'が', 'なに'], ['が', 'なに', 'を'], ['なに', 'を', 'いっ'], ['を', 'いっ', 'てる'], ['いっ', 'てる', 'ん'], ['てる', 'ん', 'だ'], ['ん', 'だ', 'せいかい'], ['だ', 'せいかい', 'だろ']]
# ['なんで', 'きれる', 'ん', 'だ', 'よ', 'E']
# [['なんで', 'きれる', 'ん'], ['きれる', 'ん', 'だ'], ['ん', 'だ', 'よ']]
# ['かんこく', 'の', 'びじん', 'こんてすと', 'の', 'しゃしん', 'を', 'み', 'たら', 'だれ', 'でも', 'おどろく', 'ぞ', 'E']
# [['かんこく', 'の', 'びじん'], ['の', 'びじん', 'こんてすと'], ['びじん', 'こんてすと', 'の'], ['こんてすと', 'の', 'しゃしん'], ['の', 'しゃしん', 'を'], ['しゃしん', 'を', 'み'], ['を', 'み', 'たら'], ['み', 'たら', 'だれ'], ['たら', 'だれ', 'でも'], ['だれ', 'でも', 'おどろく'], ['でも', 'おどろく', 'ぞ']]
# ['せいけい', 'し', 'て', 'も', 'うまれ', 'て', 'くる', 'こども', 'は', 'ちょん', 'がお', 'E']
# [['せいけい', 'し', 'て'], ['し', 'て', 'も'], ['て', 'も', 'うまれ'], ['も', 'うまれ', 'て'], ['うまれ', 'て', 'くる'], ['て', 'くる', 'こども'], ['くる', 'こども', 'は'], ['こども', 'は', 'ちょん'], ['は', 'ちょん', 'がお']]
# ['はは', 'むすめ', 'で', 'せいけい', 'する', 'って', 'きい', 'てる', 'よ', 'に', 'て', 'なきゃ', 'まずい', 'と', 'する', 'しんけい', 'も', 'もっ', 'てる', 'らしい', 'E']
# [['はは', 'むすめ', 'で'], ['むすめ', 'で', 'せいけい'], ['で', 'せいけい', 'する'], ['せいけい', 'する', 'って'], ['する', 'って', 'きい'], ['って', 'きい', 'てる'], ['きい', 'てる', 'よ'], ['てる', 'よ', 'に'], ['よ', 'に', 'て'], ['に', 'て', 'なきゃ'], ['て', 'なきゃ', 'まずい'], ['なきゃ', 'まずい', 'と'], ['まずい', 'と', 'する'], ['と', 'する', 'しんけい'], ['する', 'しんけい', 'も'], ['しんけい', 'も', 'もっ'], ['も', 'もっ', 'てる'], ['もっ', 'てる', 'らしい']]
# ['じしんまんまん', 'に', 'こたえ', 'てる', 'たいがい', 'の', 'ひと', 'は', 'そう', 'こたえる', 'だろ', 'E']
# [['じしんまんまん', 'に', 'こたえ'], ['に', 'こたえ', 'てる'], ['こたえ', 'てる', 'たいがい'], ['てる', 'たいがい', 'の'], ['たいがい', 'の', 'ひと'], ['の', 'ひと', 'は'], ['ひと', 'は', 'そう'], ['は', 'そう', 'こたえる'], ['そう', 'こたえる', 'だろ']]
# ['よく', 'わかっ', 'てん', 'じゃん', 'E']
# [['よく', 'わかっ', 'てん'], ['わかっ', 'てん', 'じゃん']]
# ['なんで', 'ちょうせんじん', 'って', 'ほんとう', 'の', 'こと', 'いう', 'と', 'おこる', 'の', 'E']
# [['なんで', 'ちょうせんじん', 'って'], ['ちょうせんじん', 'って', 'ほんとう'], ['って', 'ほんとう', 'の'], ['ほんとう', 'の', 'こと'], ['の', 'こと', 'いう'], ['こと', 'いう', 'と'], ['いう', 'と', 'おこる'], ['と', 'おこる', 'の']]
# ['これ', 'は', 'かなりや', 'べ', 'な', 'えみ', 'ついに', 'おおの', 'くん', 'も', 'ねとうよ', 'の', 'なかまいり', 'か', 'E']
# [['これ', 'は', 'かなりや'], ['は', 'かなりや', 'べ'], ['かなりや', 'べ', 'な'], ['べ', 'な', 'えみ'], ['な', 'えみ', 'ついに'], ['えみ', 'ついに', 'おおの'], ['ついに', 'おおの', 'くん'], ['おおの', 'くん', 'も'], ['くん', 'も', 'ねとうよ'], ['も', 'ねとうよ', 'の'], ['ねとうよ', 'の', 'なかまいり'], ['の', 'なかまいり', 'か']]
# ['せいけい', 'の', 'きげんはかんこく', 'E']
# [['せいけい', 'の', 'きげんはかんこく']]
# ['かんこく', 'と', 'いえ', 'ば', 'せいけい', 'と', 'ばいしゅん', 'が', 'しゅようさんぎょう', 'だろ', 'E']
# [['かんこく', 'と', 'いえ'], ['と', 'いえ', 'ば'], ['いえ', 'ば', 'せいけい'], ['ば', 'せいけい', 'と'], ['せいけい', 'と', 'ばいしゅん'], ['と', 'ばいしゅん', 'が'], ['ばいしゅん', 'が', 'しゅようさんぎょう'], ['が', 'しゅようさんぎょう', 'だろ']]
# ['むち', 'でも', 'へんけん', 'で', 'も', 'ない', 'だろ', 'う', 'E']
# [['むち', 'でも', 'へんけん'], ['でも', 'へんけん', 'で'], ['へんけん', 'で', 'も'], ['で', 'も', 'ない'], ['も', 'ない', 'だろ'], ['ない', 'だろ', 'う']]
# ['こんな', 'ばらえてぃ', 'の', 'いち', 'すら', 'のぞきみ', 'する', 'きもち', 'わるい', 'ちょうせんじん', 'E']
# [['こんな', 'ばらえてぃ', 'の'], ['ばらえてぃ', 'の', 'いち'], ['の', 'いち', 'すら'], ['いち', 'すら', 'のぞきみ'], ['すら', 'のぞきみ', 'する'], ['のぞきみ', 'する', 'きもち'], ['する', 'きもち', 'わるい'], ['きもち', 'わるい', 'ちょうせんじん']]
# ['にっぽん', 'で', 'かんこく', 'の', 'いんしょう', 'が', 'よく', 'ない', 'の', 'は', 'かんこく', 'じしん', 'に', 'もんだい', 'が', 'ある', 'と', 'は', 'かんがえ', 'ない', 'の', 'E']
# [['にっぽん', 'で', 'かんこく'], ['で', 'かんこく', 'の'], ['かんこく', 'の', 'いんしょう'], ['の', 'いんしょう', 'が'], ['いんしょう', 'が', 'よく'], ['が', 'よく', 'ない'], ['よく', 'ない', 'の'], ['ない', 'の', 'は'], ['の', 'は', 'かんこく'], ['は', 'かんこく', 'じしん'], ['かんこく', 'じしん', 'に'], ['じしん', 'に', 'もんだい'], ['に', 'もんだい', 'が'], ['もんだい', 'が', 'ある'], ['が', 'ある', 'と'], ['ある', 'と', 'は'], ['と', 'は', 'かんがえ'], ['は', 'かんがえ', 'ない'], ['かんがえ', 'ない', 'の']]
# ['わろた', 'おおのくん', 'よう', 'わかっ', 'て', 'ん', 'じゃ', 'ない', 'か', 'E']
# [['わろた', 'おおのくん', 'よう'], ['おおのくん', 'よう', 'わかっ'], ['よう', 'わかっ', 'て'], ['わかっ', 'て', 'ん'], ['て', 'ん', 'じゃ'], ['ん', 'じゃ', 'ない'], ['じゃ', 'ない', 'か']]
# ['ねん', 'ばっか', 'じゃ', 'の', 'E']
# [['ねん', 'ばっか', 'じゃ'], ['ばっか', 'じゃ', 'の']]
# ['また', 'もっ', 'た', 'の', 'か', 'E']
# [['また', 'もっ', 'た'], ['もっ', 'た', 'の'], ['た', 'の', 'か']]
# ['そもそも', 'かんこく', 'に', 'は', 'ねん', 'まえ', 'の', 'れきし', 'を', 'しるし', 'た', 'きろく', 'が', 'ない', 'だろ', 'E']
# [['そもそも', 'かんこく', 'に'], ['かんこく', 'に', 'は'], ['に', 'は', 'ねん'], ['は', 'ねん', 'まえ'], ['ねん', 'まえ', 'の'], ['まえ', 'の', 'れきし'], ['の', 'れきし', 'を'], ['れきし', 'を', 'しるし'], ['を', 'しるし', 'た'], ['しるし', 'た', 'きろく'], ['た', 'きろく', 'が'], ['きろく', 'が', 'ない'], ['が', 'ない', 'だろ']]
# ['ろくじゅうねん', 'くらい', 'の', 'れきし', 'の', 'くに', 'が', 'そこ', 'に', 'むかし', 'すん', 'で', 'た', 'の', 'は', 'べつ', 'の', 'みんぞく', 'だ', 'ぞ', 'で', 'ない', 'と', 'おまえら', 'の', 'れきし', 'が', 'E']
# [['ろくじゅうねん', 'くらい', 'の'], ['くらい', 'の', 'れきし'], ['の', 'れきし', 'の'], ['れきし', 'の', 'くに'], ['の', 'くに', 'が'], ['くに', 'が', 'そこ'], ['が', 'そこ', 'に'], ['そこ', 'に', 'むかし'], ['に', 'むかし', 'すん'], ['むかし', 'すん', 'で'], ['すん', 'で', 'た'], ['で', 'た', 'の'], ['た', 'の', 'は'], ['の', 'は', 'べつ'], ['は', 'べつ', 'の'], ['べつ', 'の', 'みんぞく'], ['の', 'みんぞく', 'だ'], ['みんぞく', 'だ', 'ぞ'], ['だ', 'ぞ', 'で'], ['ぞ', 'で', 'ない'], ['で', 'ない', 'と'], ['ない', 'と', 'おまえら'], ['と', 'おまえら', 'の'], ['おまえら', 'の', 'れきし'], ['の', 'れきし', 'が']]
# ...
# ['しょうじき', 'いっ', 'て', 'これ', 'たいようこうはつでん', 'すいしん', 'は', 'たる', 'とくあ', 'ぞく', 'と', 'ぎょうしゃ', 'あほ', 'だ', 'と', 'おもう', 'まあ', 'かげ', 'で', 'しゅどう', 'し', 'た', 'ざいにち', 'なんぼくちょうせん', 'ちゅうごくじん', 'や', 'はんにち', 'ばいこく', 'じん', 'ぜんいん', 'に', 'いえる', 'こと', 'な', 'ん', 'だ', 'けど', 'たいようこう', 'すいしん', 'は', 'の', 'さぎ', 'もよう', 'と', 'たいようこう', 'さぎ', 'ひがいしゃ', 'ならびに', 'この', 'ほしゅそくほう', 'とう', 'の', 'せいじょう', 'ねっと', 'えつらんしゃ', 'ぜんいん', 'に', 'はんこう', 'の', 'ぶっしょう', 'や', 'はんにん', 'さらし', 'あげ', 'て', 'じぶん', 'とう', 'みんぞく', 'と', 'はんにち', 'ばいこく', 'じぶん', 'とう', 'の', 'くび', 'しめ', 'て', 'こう', 'なく', 'し', 'て', 'どう', 'する', 'よ', 'ゆうじ', 'だいしょう', 'の', 'うごき', 'で', 'とくあ', 'おとさ', 'れ', 'たら', 'とくあ', 'の', 'なかみなみ', 'ほくせん', 'みかた', 'どこ', 'が', 'が', 'たいしょう', 'に', 'しろ', 'にっぽん', 'の', 'ちゅうおう', 'ちほう', 'ぎょうせい', 'に', 'いる', 'はんにち', 'ばいこく', 'じん', 'も', 'かきださ', 'れ', 'て', 'しょばつ', 'さ', 'れる', 'おそれ', 'が', 'ある', 'と', 'おもう', 'が', 'じぶん', 'とう', 'みんぞく', 'やら', 'の', 'そんざい', 'と', 'あくせい', 'にっぽんじん', 'ぜんいん', 'と', 'これら', 'ほうどう', 'や', 'ほしゅそくほう', 'とう', 'の', 'さいと', 'よめる', 'がいこくじん', 'に', 'ひろめ', 'て', 'けいはつ', 'し', 'て', 'たちば', 'わるく', 'し', 'て', 'いる', 'だけ', 'だろ', 'う', 'に', 'しゃかいとう', 'みんしんとう', 'と', 'どうよう', 'または', 'にち', 'べい', 'ろ', 'ちゅう', 'に', 'ふくろだたき', 'さ', 'れ', 'て', 'けんせん', 'が', 'ひろがっ', 'て', 'いる', 'げんじょう', 'の', 'みなみちょうせん', 'みたい', 'な', 'まつろ', 'に', 'ご', 'であいけい', 'ぜん', 'じむじかん', 'まえかわ', 'し', 'や', 'かけい', 'ぶんしょ', 'かい', 'た', 'という', 'じょせい', 'かんりょう', 'の', 'なまえ', 'と', 'じじょう', 'が', 'で', 'た', 'よう', 'に', 'ちゅうごく', 'と', 'ちょうせん', 'りくかいくう', 'うちゅう', 'はかい', 'と', 'おせん', 'し', 'まくっ', 'て', 'て', 'ちゅうごく', 'が', 'せかい', 'はけん', 'を', 'にぎろ', 'う', 'が', 'べいこく', 'と', 'に', 'だい', 'ならびたてよ', 'う', 'が', 'ちきゅう', 'はかい', 'おせん', 'かつどう', 'とめる', 'と', 'は', 'かんがえ', 'られ', 'ない', 'じてん', 'で', 'はめつ', 'しか', 'ない', 'よう', 'に', 'おもえる', 'ん', 'だ', 'よ', 'ね', 'とめ', 'られ', 'たら', 'じぶん', 'とう', 'の', 'ぼこく', 'を', 'あの', 'よう', 'に', 'はかい', 'おせん', 'し', 'て', 'ない', 'って', 'ちゅうごく', 'なぞ', 'うみ', 'へだて', 'た', 'にっぽん', 'に', 'まで', 'に', 'ご', 'まき', 'ちらし', 'て', 'て', 'しょくりん', 'し', 'て', 'も', 'ばっさい', 'し', 'て', 'たきぎ', 'や', 'きょうさんとういん', 'の', 'いえ', 'だて', 'ちゃっ', 'たり', 'えんがん', 'の', 'かいさんぶつ', 'え', 'り', 'すぎ', 'たり', 'せかいいさん', 'にっぽん', 'おがさわら', 'さんご', 'さえ', 'も', 'ぬすみ', 'とっ', 'て', 'おんだんか', 'の', 'げんいん', 'に', 'なっ', 'てる', 'の', 'は', 'かくじつ', 'だ', 'し', 'あぶらはむのしゅうきょう', 'の', 'あくま', 'だって', 'ちきゅう', 'はかい', 'おせん', 'と', 'じんるいめつぼう', 'は', 'つたなか', 'ろう', 'に', 'な', 'そんな', 'の', 'を', 'あくま', 'が', 'のぞん', 'だ', 'と', 'きい', 'た', 'こと', 'も', 'ない', 'し', 'しょじ', 'し', 'て', 'いる', 'あくま', 'ほん', 'に', 'も', 'のっ', 'て', 'むい', 'から', 'だい', 'なな', 'てん', 'に', 'かえり', 'たい', 'と', 'のぞん', 'だ', 'という', 'きさい', 'は', 'あっ', 'た', 'が', 'E']
# [['しょうじき', 'いっ', 'て'], ['いっ', 'て', 'これ'], ['て', 'これ', 'たいようこうはつでん'], ['これ', 'たいようこうはつでん', 'すいしん'], ['たいようこうはつでん', 'すいしん', 'は'], ['すいしん', 'は', 'たる'], ['は', 'たる', 'とくあ'], ['たる', 'とくあ', 'ぞく'], ['とくあ', 'ぞく', 'と'], ['ぞく', 'と', 'ぎょうしゃ'], ['と', 'ぎょうしゃ', 'あほ'], ['ぎょうしゃ', 'あほ', 'だ'], ['あほ', 'だ', 'と'], ['だ', 'と', 'おもう'], ['と', 'おもう', 'まあ'], ['おもう', 'まあ', 'かげ'], ['まあ', 'かげ', 'で'], ['かげ', 'で', 'しゅどう'], ['で', 'しゅどう', 'し'], ['しゅどう', 'し', 'た'], ['し', 'た', 'ざいにち'], ['た', 'ざいにち', 'なんぼくちょうせん'], ['ざいにち', 'なんぼくちょうせん', 'ちゅうごくじん'], ['なんぼくちょうせん', 'ちゅうごくじん', 'や'], ['ちゅうごくじん', 'や', 'はんにち'], ['や', 'はんにち', 'ばいこく'], ['はんにち', 'ばいこく', 'じん'], ['ばいこく', 'じん', 'ぜんいん'], ['じん', 'ぜんいん', 'に'], ['ぜんいん', 'に', 'いえる'], ['に', 'いえる', 'こと'], ['いえる', 'こと', 'な'], ['こと', 'な', 'ん'], ['な', 'ん', 'だ'], ['ん', 'だ', 'けど'], ['だ', 'けど', 'たいようこう'], ['けど', 'たいようこう', 'すいしん'], ['たいようこう', 'すいしん', 'は'], ['すいしん', 'は', 'の'], ['は', 'の', 'さぎ'], ['の', 'さぎ', 'もよう'], ['さぎ', 'もよう', 'と'], ['もよう', 'と', 'たいようこう'], ['と', 'たいようこう', 'さぎ'], ['たいようこう', 'さぎ', 'ひがいしゃ'], ['さぎ', 'ひがいしゃ', 'ならびに'], ['ひがいしゃ', 'ならびに', 'この'], ['ならびに', 'この', 'ほしゅそくほう'], ['この', 'ほしゅそくほう', 'とう'], ['ほしゅそくほう', 'とう', 'の'], ['とう', 'の', 'せいじょう'], ['の', 'せいじょう', 'ねっと'], ['せいじょう', 'ねっと', 'えつらんしゃ'], ['ねっと', 'えつらんしゃ', 'ぜんいん'], ['えつらんしゃ', 'ぜんいん', 'に'], ['ぜんいん', 'に', 'はんこう'], ['に', 'はんこう', 'の'], ['はんこう', 'の', 'ぶっしょう'], ['の', 'ぶっしょう', 'や'], ['ぶっしょう', 'や', 'はんにん'], ['や', 'はんにん', 'さらし'], ['はんにん', 'さらし', 'あげ'], ['さらし', 'あげ', 'て'], ['あげ', 'て', 'じぶん'], ['て', 'じぶん', 'とう'], ['じぶん', 'とう', 'みんぞく'], ['とう', 'みんぞく', 'と'], ['みんぞく', 'と', 'はんにち'], ['と', 'はんにち', 'ばいこく'], ['はんにち', 'ばいこく', 'じぶん'], ['ばいこく', 'じぶん', 'とう'], ['じぶん', 'とう', 'の'], ['とう', 'の', 'くび'], ['の', 'くび', 'しめ'], ['くび', 'しめ', 'て'], ['しめ', 'て', 'こう'], ['て', 'こう', 'なく'], ['こう', 'なく', 'し'], ['なく', 'し', 'て'], ['し', 'て', 'どう'], ['て', 'どう', 'する'], ['どう', 'する', 'よ'], ['する', 'よ', 'ゆうじ'], ['よ', 'ゆうじ', 'だいしょう'], ['ゆうじ', 'だいしょう', 'の'], ['だいしょう', 'の', 'うごき'], ['の', 'うごき', 'で'], ['うごき', 'で', 'とくあ'], ['で', 'とくあ', 'おとさ'], ['とくあ', 'おとさ', 'れ'], ['おとさ', 'れ', 'たら'], ['れ', 'たら', 'とくあ'], ['たら', 'とくあ', 'の'], ['とくあ', 'の', 'なかみなみ'], ['の', 'なかみなみ', 'ほくせん'], ['なかみなみ', 'ほくせん', 'みかた'], ['ほくせん', 'みかた', 'どこ'], ['みかた', 'どこ', 'が'], ['どこ', 'が', 'が'], ['が', 'が', 'たいしょう'], ['が', 'たいしょう', 'に'], ['たいしょう', 'に', 'しろ'], ['に', 'しろ', 'にっぽん'], ['しろ', 'にっぽん', 'の'], ['にっぽん', 'の', 'ちゅうおう'], ['の', 'ちゅうおう', 'ちほう'], ['ちゅうおう', 'ちほう', 'ぎょうせい'], ['ちほう', 'ぎょうせい', 'に'], ['ぎょうせい', 'に', 'いる'], ['に', 'いる', 'はんにち'], ['いる', 'はんにち', 'ばいこく'], ['はんにち', 'ばいこく', 'じん'], ['ばいこく', 'じん', 'も'], ['じん', 'も', 'かきださ'], ['も', 'かきださ', 'れ'], ['かきださ', 'れ', 'て'], ['れ', 'て', 'しょばつ'], ['て', 'しょばつ', 'さ'], ['しょばつ', 'さ', 'れる'], ['さ', 'れる', 'おそれ'], ['れる', 'おそれ', 'が'], ['おそれ', 'が', 'ある'], ['が', 'ある', 'と'], ['ある', 'と', 'おもう'], ['と', 'おもう', 'が'], ['おもう', 'が', 'じぶん'], ['が', 'じぶん', 'とう'], ['じぶん', 'とう', 'みんぞく'], ['とう', 'みんぞく', 'やら'], ['みんぞく', 'やら', 'の'], ['やら', 'の', 'そんざい'], ['の', 'そんざい', 'と'], ['そんざい', 'と', 'あくせい'], ['と', 'あくせい', 'にっぽんじん'], ['あくせい', 'にっぽんじん', 'ぜんいん'], ['にっぽんじん', 'ぜんいん', 'と'], ['ぜんいん', 'と', 'これら'], ['と', 'これら', 'ほうどう'], ['これら', 'ほうどう', 'や'], ['ほうどう', 'や', 'ほしゅそくほう'], ['や', 'ほしゅそくほう', 'とう'], ['ほしゅそくほう', 'とう', 'の'], ['とう', 'の', 'さいと'], ['の', 'さいと', 'よめる'], ['さいと', 'よめる', 'がいこくじん'], ['よめる', 'がいこくじん', 'に'], ['がいこくじん', 'に', 'ひろめ'], ['に', 'ひろめ', 'て'], ['ひろめ', 'て', 'けいはつ'], ['て', 'けいはつ', 'し'], ['けいはつ', 'し', 'て'], ['し', 'て', 'たちば'], ['て', 'たちば', 'わるく'], ['たちば', 'わるく', 'し'], ['わるく', 'し', 'て'], ['し', 'て', 'いる'], ['て', 'いる', 'だけ'], ['いる', 'だけ', 'だろ'], ['だけ', 'だろ', 'う'], ['だろ', 'う', 'に'], ['う', 'に', 'しゃかいとう'], ['に', 'しゃかいとう', 'みんしんとう'], ['しゃかいとう', 'みんしんとう', 'と'], ['みんしんとう', 'と', 'どうよう'], ['と', 'どうよう', 'または'], ['どうよう', 'または', 'にち'], ['または', 'にち', 'べい'], ['にち', 'べい', 'ろ'], ['べい', 'ろ', 'ちゅう'], ['ろ', 'ちゅう', 'に'], ['ちゅう', 'に', 'ふくろだたき'], ['に', 'ふくろだたき', 'さ'], ['ふくろだたき', 'さ', 'れ'], ['さ', 'れ', 'て'], ['れ', 'て', 'けんせん'], ['て', 'けんせん', 'が'], ['けんせん', 'が', 'ひろがっ'], ['が', 'ひろがっ', 'て'], ['ひろがっ', 'て', 'いる'], ['て', 'いる', 'げんじょう'], ['いる', 'げんじょう', 'の'], ['げんじょう', 'の', 'みなみちょうせん'], ['の', 'みなみちょうせん' ...
# ['よかっ', 'た', 'ほんとうに', 'よかっ', 'た', 'E']
# [['よかっ', 'た', 'ほんとうに'], ['た', 'ほんとうに', 'よかっ'], ['ほんとうに', 'よかっ', 'た']]
# ['ぱねる', 'を', 'つくる', 'の', 'に', 'も', 'ゆそう', 'する', 'に', 'も', 'せっち', 'する', 'に', 'も', 'てっきょ', 'はいき', 'ゆそう', 'する', 'に', 'も', 'せきゆ', 'が', 'ひつよう', 'E']
# [['ぱねる', 'を', 'つくる'], ['を', 'つくる', 'の'], ['つくる', 'の', 'に'], ['の', 'に', 'も'], ['に', 'も', 'ゆそう'], ['も', 'ゆそう', 'する'], ['ゆそう', 'する', 'に'], ['する', 'に', 'も'], ['に', 'も', 'せっち'], ['も', 'せっち', 'する'], ['せっち', 'する', 'に'], ['する', 'に', 'も'], ['に', 'も', 'てっきょ'], ['も', 'てっきょ', 'はいき'], ['てっきょ', 'はいき', 'ゆそう'], ['はいき', 'ゆそう', 'する'], ['ゆそう', 'する', 'に'], ['する', 'に', 'も'], ['に', 'も', 'せきゆ'], ['も', 'せきゆ', 'が'], ['せきゆ', 'が', 'ひつよう']]
# ['こんな', 'の', 'あたりまえ', 'の', 'けっか', 'そもそも', 'げんぱつ', 'さい', 'かどう', 'いがい', 'に', 'にっぽん', 'の', 'でんりょくじゅよう', 'を', 'みたす', 'ほうほう', 'ない', 'に', 'も', 'かかわら', 'ず', 'そんまさよし', 'ら', 'せいしょう', 'と', 'よば', 'れる', 'ごみ', 'くずども', 'が', 'げんぱつ', 'おこし', 'た', 'ぐみん', 'ども', 'に', 'つけこん', 'で', 'はじめ', 'た', 'かねもうけ', 'の', 'ため', 'だけ', 'の', 'じぎょう', 'だっ', 'た', 'ん', 'だ', 'から', 'な', 'E']
# [['こんな', 'の', 'あたりまえ'], ['の', 'あたりまえ', 'の'], ['あたりまえ', 'の', 'けっか'], ['の', 'けっか', 'そもそも'], ['けっか', 'そもそも', 'げんぱつ'], ['そもそも', 'げんぱつ', 'さい'], ['げんぱつ', 'さい', 'かどう'], ['さい', 'かどう', 'いがい'], ['かどう', 'いがい', 'に'], ['いがい', 'に', 'にっぽん'], ['に', 'にっぽん', 'の'], ['にっぽん', 'の', 'でんりょくじゅよう'], ['の', 'でんりょくじゅよう', 'を'], ['でんりょくじゅよう', 'を', 'みたす'], ['を', 'みたす', 'ほうほう'], ['みたす', 'ほうほう', 'ない'], ['ほうほう', 'ない', 'に'], ['ない', 'に', 'も'], ['に', 'も', 'かかわら'], ['も', 'かかわら', 'ず'], ['かかわら', 'ず', 'そんまさよし'], ['ず', 'そんまさよし', 'ら'], ['そんまさよし', 'ら', 'せいしょう'], ['ら', 'せいしょう', 'と'], ['せいしょう', 'と', 'よば'], ['と', 'よば', 'れる'], ['よば', 'れる', 'ごみ'], ['れる', 'ごみ', 'くずども'], ['ごみ', 'くずども', 'が'], ['くずども', 'が', 'げんぱつ'], ['が', 'げんぱつ', 'おこし'], ['げんぱつ', 'おこし', 'た'], ['おこし', 'た', 'ぐみん'], ['た', 'ぐみん', 'ども'], ['ぐみん', 'ども', 'に'], ['ども', 'に', 'つけこん'], ['に', 'つけこん', 'で'], ['つけこん', 'で', 'はじめ'], ['で', 'はじめ', 'た'], ['はじめ', 'た', 'かねもうけ'], ['た', 'かねもうけ', 'の'], ['かねもうけ', 'の', 'ため'], ['の', 'ため', 'だけ'], ['ため', 'だけ', 'の'], ['だけ', 'の', 'じぎょう'], ['の', 'じぎょう', 'だっ'], ['じぎょう', 'だっ', 'た'], ['だっ', 'た', 'ん'], ['た', 'ん', 'だ'], ['ん', 'だ', 'から'], ['だ', 'から', 'な']]
# ['こういう', 'の', 'は', 'ぎょうせい', 'がわ', 'で', 'せっち', 'きじゅん', 'を', 'もうけ', 'せっち', 'の', 'さい', 'に', 'とりのぞく', 'ため', 'に', 'ひつよう', 'な', 'ひよう', 'を', 'さいしょ', 'から', 'あずかっ', 'て', 'おく', 'よう', 'に', 'す', 'べき', 'だ', 'わ', 'ざいにちきぎょう', 'ばかり', 'だ', 'から', 'とうさん', 'し', 'て', 'とん', 'ずらさ', 'れ', 'たら', 'にっぽんじん', 'の', 'けつぜい', 'から', 'しはらう', 'こと', 'に', 'なる', 'E']
# [['こういう', 'の', 'は'], ['の', 'は', 'ぎょうせい'], ['は', 'ぎょうせい', 'がわ'], ['ぎょうせい', 'がわ', 'で'], ['がわ', 'で', 'せっち'], ['で', 'せっち', 'きじゅん'], ['せっち', 'きじゅん', 'を'], ['きじゅん', 'を', 'もうけ'], ['を', 'もうけ', 'せっち'], ['もうけ', 'せっち', 'の'], ['せっち', 'の', 'さい'], ['の', 'さい', 'に'], ['さい', 'に', 'とりのぞく'], ['に', 'とりのぞく', 'ため'], ['とりのぞく', 'ため', 'に'], ['ため', 'に', 'ひつよう'], ['に', 'ひつよう', 'な'], ['ひつよう', 'な', 'ひよう'], ['な', 'ひよう', 'を'], ['ひよう', 'を', 'さいしょ'], ['を', 'さいしょ', 'から'], ['さいしょ', 'から', 'あずかっ'], ['から', 'あずかっ', 'て'], ['あずかっ', 'て', 'おく'], ['て', 'おく', 'よう'], ['おく', 'よう', 'に'], ['よう', 'に', 'す'], ['に', 'す', 'べき'], ['す', 'べき', 'だ'], ['べき', 'だ', 'わ'], ['だ', 'わ', 'ざいにちきぎょう'], ['わ', 'ざいにちきぎょう', 'ばかり'], ['ざいにちきぎょう', 'ばかり', 'だ'], ['ばかり', 'だ', 'から'], ['だ', 'から', 'とうさん'], ['から', 'とうさん', 'し'], ['とうさん', 'し', 'て'], ['し', 'て', 'とん'], ['て', 'とん', 'ずらさ'], ['とん', 'ずらさ', 'れ'], ['ずらさ', 'れ', 'たら'], ['れ', 'たら', 'にっぽんじん'], ['たら', 'にっぽんじん', 'の'], ['にっぽんじん', 'の', 'けつぜい'], ['の', 'けつぜい', 'から'], ['けつぜい', 'から', 'しはらう'], ['から', 'しはらう', 'こと'], ['しはらう', 'こと', 'に'], ['こと', 'に', 'なる']]
# ['かいちゅうでんとう', 'に', 'も', 'ほしい', 'E']
# [['かいちゅうでんとう', 'に', 'も'], ['に', 'も', 'ほしい']]
# ['それ', 'じんこう', 'や', 'きぎょう', 'の', 'ちほう', 'ぶんさん', 'に', 'ものすごく', 'よい', 'ほうほう', 'かも', 'しれ', 'ない', 'E']
# [['それ', 'じんこう', 'や'], ['じんこう', 'や', 'きぎょう'], ['や', 'きぎょう', 'の'], ['きぎょう', 'の', 'ちほう'], ['の', 'ちほう', 'ぶんさん'], ['ちほう', 'ぶんさん', 'に'], ['ぶんさん', 'に', 'ものすごく'], ['に', 'ものすごく', 'よい'], ['ものすごく', 'よい', 'ほうほう'], ['よい', 'ほうほう', 'かも'], ['ほうほう', 'かも', 'しれ'], ['かも', 'しれ', 'ない']]
# ['いぜん', 'ほしゅそくほう', 'で', 'たからづかし', 'の', 'の', 'しゃしん', 'が', 'ひどい', 'と', 'あっぷ', 'さ', 'れ', 'て', 'い', 'た', 'が', 'けんない', 'の', 'さんどう', 'を', 'すこし', 'くるま', 'で', 'はしる', 'と', 'いたる', 'ところ', 'に', 'でき', 'て', 'いる', 'の', 'が', 'わかっ', 'た', 'が', 'おこる', 'の', 'も', 'わかる', 'わ', 'E']
# [['いぜん', 'ほしゅそくほう', 'で'], ['ほしゅそくほう', 'で', 'たからづかし'], ['で', 'たからづかし', 'の'], ['たからづかし', 'の', 'の'], ['の', 'の', 'しゃしん'], ['の', 'しゃしん', 'が'], ['しゃしん', 'が', 'ひどい'], ['が', 'ひどい', 'と'], ['ひどい', 'と', 'あっぷ'], ['と', 'あっぷ', 'さ'], ['あっぷ', 'さ', 'れ'], ['さ', 'れ', 'て'], ['れ', 'て', 'い'], ['て', 'い', 'た'], ['い', 'た', 'が'], ['た', 'が', 'けんない'], ['が', 'けんない', 'の'], ['けんない', 'の', 'さんどう'], ['の', 'さんどう', 'を'], ['さんどう', 'を', 'すこし'], ['を', 'すこし', 'くるま'], ['すこし', 'くるま', 'で'], ['くるま', 'で', 'はしる'], ['で', 'はしる', 'と'], ['はしる', 'と', 'いたる'], ['と', 'いたる', 'ところ'], ['いたる', 'ところ', 'に'], ['ところ', 'に', 'でき'], ['に', 'でき', 'て'], ['でき', 'て', 'いる'], ['て', 'いる', 'の'], ['いる', 'の', 'が'], ['の', 'が', 'わかっ'], ['が', 'わかっ', 'た'], ['わかっ', 'た', 'が'], ['た', 'が', 'おこる'], ['が', 'おこる', 'の'], ['おこる', 'の', 'も'], ['の', 'も', 'わかる'], ['も', 'わかる', 'わ']]
# ['よく', 'えすえふ', 'で', 'こうせい', 'から', 'じかに', 'を', 'とる', 'はなし', 'が', 'でる', 'が', 'その', 'くらい', 'の', 'ぎじゅつ', 'の', 'かくしん', 'が', 'ない', 'と', 'だめ', 'だろ', 'う', 'な', 'E']
# [['よく', 'えすえふ', 'で'], ['えすえふ', 'で', 'こうせい'], ['で', 'こうせい', 'から'], ['こうせい', 'から', 'じかに'], ['から', 'じかに', 'を'], ['じかに', 'を', 'とる'], ['を', 'とる', 'はなし'], ['とる', 'はなし', 'が'], ['はなし', 'が', 'でる'], ['が', 'でる', 'が'], ['でる', 'が', 'その'], ['が', 'その', 'くらい'], ['その', 'くらい', 'の'], ['くらい', 'の', 'ぎじゅつ'], ['の', 'ぎじゅつ', 'の'], ['ぎじゅつ', 'の', 'かくしん'], ['の', 'かくしん', 'が'], ['かくしん', 'が', 'ない'], ['が', 'ない', 'と'], ['ない', 'と', 'だめ'], ['と', 'だめ', 'だろ'], ['だめ', 'だろ', 'う'], ['だろ', 'う', 'な']]
# ['さんせい', 'ふくしまだいいちげんぱつ', 'の', 'かんり', 'が', 'かんこく', 'だっ', 'た', 'そう', 'です', 'にほんきぎょう', 'で', 'にっぽんじん', 'で', 'かんり', 'する', 'から', 'だいじょうぶだよ', 'って', 'せんでん', 'すれ', 'ば', 'どうでしょう', 'ますごみ', 'に', 'まける', 'かな', 'E']
# [['さんせい', 'ふくしまだいいちげんぱつ', 'の'], ['ふくしまだいいちげんぱつ', 'の', 'かんり'], ['の', 'かんり', 'が'], ['かんり', 'が', 'かんこく'], ['が', 'かんこく', 'だっ'], ['かんこく', 'だっ', 'た'], ['だっ', 'た', 'そう'], ['た', 'そう', 'です'], ['そう', 'です', 'にほんきぎょう'], ['です', 'にほんきぎょう', 'で'], ['にほんきぎょう', 'で', 'にっぽんじん'], ['で', 'にっぽんじん', 'で'], ['にっぽんじん', 'で', 'かんり'], ['で', 'かんり', 'する'], ['かんり', 'する', 'から'], ['する', 'から', 'だいじょうぶだよ'], ['から', 'だいじょうぶだよ', 'って'], ['だいじょうぶだよ', 'って', 'せんでん'], ['って', 'せんでん', 'すれ'], ['せんでん', 'すれ', 'ば'], ['すれ', 'ば', 'どうでしょう'], ['ば', 'どうでしょう', 'ますごみ'], ['どうでしょう', 'ますごみ', 'に'], ['ますごみ', 'に', 'まける'], ['に', 'まける', 'かな']]
# ['こころづよい', 'お', 'ことば', 'せっしゃ', 'も', 'この', 'なつやすみ', 'こと', 'ある', 'ごと', 'に', 'ざつだん', 'として', 'こんな', 'はなし', 'あっ', 'た', 'で', 'と', 'しゅうち', 'し', 'て', 'いく', 'しょぞん', 'すこし', 'でも', 'たね', 'を', 'まけ', 'ば', 'いずれ', 'ほうさく', 'に', 'なる', 'でしょ', 'う', 'ぞ', 'E']
# [['こころづよい', 'お', 'ことば'], ['お', 'ことば', 'せっしゃ'], ['ことば', 'せっしゃ', 'も'], ['せっしゃ', 'も', 'この'], ['も', 'この', 'なつやすみ'], ['この', 'なつやすみ', 'こと'], ['なつやすみ', 'こと', 'ある'], ['こと', 'ある', 'ごと'], ['ある', 'ごと', 'に'], ['ごと', 'に', 'ざつだん'], ['に', 'ざつだん', 'として'], ['ざつだん', 'として', 'こんな'], ['として', 'こんな', 'はなし'], ['こんな', 'はなし', 'あっ'], ['はなし', 'あっ', 'た'], ['あっ', 'た', 'で'], ['た', 'で', 'と'], ['で', 'と', 'しゅうち'], ['と', 'しゅうち', 'し'], ['しゅうち', 'し', 'て'], ['し', 'て', 'いく'], ['て', 'いく', 'しょぞん'], ['いく', 'しょぞん', 'すこし'], ['しょぞん', 'すこし', 'でも'], ['すこし', 'でも', 'たね'], ['でも', 'たね', 'を'], ['たね', 'を', 'まけ'], ['を', 'まけ', 'ば'], ['まけ', 'ば', 'いずれ'], ['ば', 'いずれ', 'ほうさく'], ['いずれ', 'ほうさく', 'に'], ['ほうさく', 'に', 'なる'], ['に', 'なる', 'でしょ'], ['なる', 'でしょ', 'う'], ['でしょ', 'う', 'ぞ']]
# ['たいようこうはつでん', 'で', 'せいこう', 'し', 'て', 'いる', 'ところ', 'など', 'ひとつも', 'ない', 'E']
# [['たいようこうはつでん', 'で', 'せいこう'], ['で', 'せいこう', 'し'], ['せいこう', 'し', 'て'], ['し', 'て', 'いる'], ['て', 'いる', 'ところ'], ['いる', 'ところ', 'など'], ['ところ', 'など', 'ひとつも'], ['など', 'ひとつも', 'ない']]
# ['みんしゅとう', 'の', 'ふのいさん', 'E']
# [['みんしゅとう', 'の', 'ふのいさん']]
# ['かん', 'が', 'げんぱつ', 'ばくはつ', 'さ', 'せ', 'た', 'けど', 'とうじ', 'かん', 'が', 'くる', 'まで', 'まて', 'と', 'は', 'げん', 'ってな', 'いって', 'ばなし', 'だっ', 'た', 'けど', 'いま', 'なら', 'そんたく', 'が', 'あっ', 'て', 'ばくはつ', 'し', 'た', 'に', 'なる', 'ん', 'じゃ', 'ない', 'の', 'E']
# [['かん', 'が', 'げんぱつ'], ['が', 'げんぱつ', 'ばくはつ'], ['げんぱつ', 'ばくはつ', 'さ'], ['ばくはつ', 'さ', 'せ'], ['さ', 'せ', 'た'], ['せ', 'た', 'けど'], ['た', 'けど', 'とうじ'], ['けど', 'とうじ', 'かん'], ['とうじ', 'かん', 'が'], ['かん', 'が', 'くる'], ['が', 'くる', 'まで'], ['くる', 'まで', 'まて'], ['まで', 'まて', 'と'], ['まて', 'と', 'は'], ['と', 'は', 'げん'], ['は', 'げん', 'ってな'], ['げん', 'ってな', 'いって'], ['ってな', 'いって', 'ばなし'], ['いって', 'ばなし', 'だっ'], ['ばなし', 'だっ', 'た'], ['だっ', 'た', 'けど'], ['た', 'けど', 'いま'], ['けど', 'いま', 'なら'], ['いま', 'なら', 'そんたく'], ['なら', 'そんたく', 'が'], ['そんたく', 'が', 'あっ'], ['が', 'あっ', 'て'], ['あっ', 'て', 'ばくはつ'], ['て', 'ばくはつ', 'し'], ['ばくはつ', 'し', 'た'], ['し', 'た', 'に'], ['た', 'に', 'なる'], ['に', 'なる', 'ん'], ['なる', 'ん', 'じゃ'], ['ん', 'じゃ', 'ない'], ['じゃ', 'ない', 'の']]
# ['ほんとうに', 'そんまさよし', 'は', 'にっぽん', 'に', 'いらん', 'な', 'だれか', 'とらんぷ', 'の', 'に', 'かきこん', 'で', 'くれ', 'E']
# [['ほんとうに', 'そんまさよし', 'は'], ['そんまさよし', 'は', 'にっぽん'], ['は', 'にっぽん', 'に'], ['にっぽん', 'に', 'いらん'], ['に', 'いらん', 'な'], ['いらん', 'な', 'だれか'], ['な', 'だれか', 'とらんぷ'], ['だれか', 'とらんぷ', 'の'], ['とらんぷ', 'の', 'に'], ['の', 'に', 'かきこん'], ['に', 'かきこん', 'で'], ['かきこん', 'で', 'くれ']]
# ['やすく', 'かいたたく', 'まで', 'が', 'せっと', 'E']
# [['やすく', 'かいたたく', 'まで'], ['かいたたく', 'まで', 'が'], ['まで', 'が', 'せっと']]

# %%
print(np.array(x_data).shape)
print(np.array(y_data).shape)
print(len(word_id_dict))
# Out:
# (222951, 3, 200)
# (222951,)
# 14609

# %%
# one hot vectorize

# x_train = x_data[:10000].reshape(10000,3,1)
# y_train = y_data[:10000]
# x_test = x_data[10000:12000].reshape(2000,3,1)
# y_test = y_data[10000:12000]

x_train = x_data

y_train = y_data

from keras.utils import np_utils

nb_classes = len(word_id_dict)

# x_train = np_utils.to_categorical(y_train, nb_classes)
# x_test = np_utils.to_categorical(y_test, nb_classes)

Y_train = np_utils.to_categorical(y_train, nb_classes)
# Y_test = np_utils.to_categorical(y_test, nb_classes)

print("x_train shape:",x_train.shape)
print("Y_train shape:",Y_train.shape)
# Out:
# x_train shape: (222951, 3, 200)
# Y_train shape: (222951, 14609)

# %%
# LSTM model

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop

model = Sequential()
model.inputs
model.add(LSTM(128, batch_input_shape=(1,3,200), stateful=True))
model.add(Dense(word_num))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (1, 128)                  168448
# _________________________________________________________________
# dense_13 (Dense)             (1, 14609)                1884561
# _________________________________________________________________
# activation_13 (Activation)   (1, 14609)                0
# =================================================================
# Total params: 2,053,009
# Trainable params: 2,053,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
def vec2word(word_vec):
    return word_model.most_similar(positive=[word_vec], topn=1)

# %%
print(vec2word(x_train[0][0]))
print(vec2word(x_train[1][0]))
# Out:
# [('とうとう', 0.9999999403953552)]
# [('みんしん', 1.0)]

# %%
history = model.fit(x_train, Y_train, batch_size=1, epochs=1, shuffle=False)
# Out:
# Epoch 1/1
#    516/213337 [..............................] - ETA: 7483s - loss: 7.5410 - acc: 0.0291
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-221-c38d51f4bedd> in <module>()
# ----> 1 history = model.fit(x_train, Y_train, batch_size=1, epochs=1, shuffle=False)
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     861                               class_weight=class_weight,
#     862                               sample_weight=sample_weight,
# --> 863                               initial_epoch=initial_epoch)
#     864
#     865     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1428                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1429                               callback_metrics=callback_metrics,
# -> 1430                               initial_epoch=initial_epoch)
#    1431
#    1432     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1077                 batch_logs['size'] = len(batch_ids)
#    1078                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1079                 outs = f(ins_batch)
#    1080                 if not isinstance(outs, list):
#    1081                     outs = [outs]
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2266         updated = session.run(self.outputs + [self.updates_op],
#    2267                               feed_dict=feed_dict,
# -> 2268                               **self.session_kwargs)
#    2269         return updated[:len(self.outputs)]
#    2270
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# /Users/kazuki/.pyenv/versions/3.6.1/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# 学習の様子をプロット
loss = history.history['loss']
# val_loss = history.history['val_loss']

acc = history.history['acc']
# val_acc = history.history['val_acc']

plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.title('Loss')
epochs = len(loss)
plt.plot(range(epochs), loss, marker='.', label='loss')
# plt.plot(range(epochs), val_loss, marker='.', label='val_loss')
plt.legend(loc='best')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')

plt.subplot(2,1,2)
plt.title('Accuracy')
plt.plot(range(epochs), acc, marker='.', label='acc')
# plt.plot(range(epochs), val_acc, marker='.', label='val_acc')
plt.legend(loc='best')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('acc')
plt.show()
